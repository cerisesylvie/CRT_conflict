# %%
import os
import re
import csv
import pandas as pd
import numpy as np

import time
import requests
from bs4 import BeautifulSoup

#from langdetect import detect
#from deep_translator import GoogleTranslator

# %%
BASE_URL = "https://www.consiglio.vda.it/app/oggettidelconsiglio/dettaglio?pk_documento={}&versione=R"

OUTPUT_FOLDER = "./downloads"
if not os.path.exists(OUTPUT_FOLDER):
    os.makedirs(OUTPUT_FOLDER)

#funzione per scraperare e salvare i resoconti dal sito del consiglio Valle
def scrape_and_save(doc_id):
    url = BASE_URL.format(doc_id)

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Documento {doc_id} non trovato (HTTP {response.status_code}).")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    page_text = soup.get_text(separator="\n", strip=True)

    output_file = os.path.join(OUTPUT_FOLDER, f"{doc_id}.txt")
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(page_text)
    
    print(f"Documento {doc_id} salvato in: {output_file}")
    return output_file


def main(start_id, end_id):
    csv_data = []
    print(f"Inizio lo scraping per i documenti dal {start_id} al {end_id}...")

    for doc_id in range(start_id, end_id + 1):
        print(f"Processo il documento {doc_id}...")
        file_path = scrape_and_save(doc_id)

        if file_path:
            csv_data.append({"ID_file": doc_id, "path_src": file_path})

        # Pausa per evitare di sovraccaricare il server (ad esempio 2-5 secondi)
        #time.sleep(2 + (3 * doc_id % 5))  # Variamo la pausa per evitare un pattern troppo prevedibile

    # Salvataggio dei risultati nel file CSV
    csv_file = "csv_paths.csv"
    print(f"Salvataggio dei risultati nel file CSV: {csv_file}")
    with open(csv_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["ID_file", "path_src"])
        writer.writeheader()
        writer.writerows(csv_data)

    print("Completato! Tutti i documenti salvati nella cartella:", OUTPUT_FOLDER)

if __name__ == "__main__":
    main(start_id=41367, end_id=42421)
# Out:
# Inizio lo scraping per i documenti dal 40799 al 42421...
# Processo il documento 40799...
# Documento 40799 salvato in: ./downloads/40799.txt
# Processo il documento 40800...
# Documento 40800 salvato in: ./downloads/40800.txt
# Processo il documento 40801...
# Documento 40801 salvato in: ./downloads/40801.txt
# Processo il documento 40802...
# Documento 40802 salvato in: ./downloads/40802.txt
# Processo il documento 40803...
# Documento 40803 salvato in: ./downloads/40803.txt
# Processo il documento 40804...
# Documento 40804 salvato in: ./downloads/40804.txt
# Processo il documento 40805...
# Documento 40805 salvato in: ./downloads/40805.txt
# Processo il documento 40806...
# Documento 40806 salvato in: ./downloads/40806.txt
# Processo il documento 40807...
# Documento 40807 salvato in: ./downloads/40807.txt
# Processo il documento 40808...
# Documento 40808 salvato in: ./downloads/40808.txt
# Processo il documento 40809...
# Documento 40809 salvato in: ./downloads/40809.txt
# Processo il documento 40810...
# Documento 40810 salvato in: ./downloads/40810.txt
# Processo il documento 40811...
# Documento 40811 salvato in: ./downloads/40811.txt
# Processo il documento 40812...
# Documento 40812 salvato in: ./downloads/40812.txt
# Processo il documento 40813...
# Documento 40813 salvato in: ./downloads/40813.txt
# Processo il documento 40814...
# Documento 40814 salvato in: ./downloads/40814.txt
# Processo il documento 40815...
# Documento 40815 salvato in: ./downloads/40815.txt
# Processo il documento 40816...
# Documento 40816 salvato in: ./downloads/40816.txt
# Processo il documento 40817...
# Documento 40817 salvato in: ./downloads/40817.txt
# Processo il documento 40818...
# Documento 40818 salvato in: ./downloads/40818.txt
# Processo il documento 40819...
# Documento 40819 salvato in: ./downloads/40819.txt
# Processo il documento 40820...
# Documento 40820 salvato in: ./downloads/40820.txt
# Processo il documento 40821...
# Documento 40821 salvato in: ./downloads/40821.txt
# Processo il documento 40822...
# Documento 40822 salvato in: ./downloads/40822.txt
# Processo il documento 40823...
# Documento 40823 salvato in: ./downloads/40823.txt
# Processo il documento 40824...
# Documento 40824 salvato in: ./downloads/40824.txt
# Processo il documento 40825...
# Documento 40825 salvato in: ./downloads/40825.txt
# Processo il documento 40826...
# Documento 40826 salvato in: ./downloads/40826.txt
# Processo il documento 40827...
# Documento 40827 salvato in: ./downloads/40827.txt
# Processo il documento 40828...
# Documento 40828 salvato in: ./downloads/40828.txt
# Processo il documento 40829...
# Documento 40829 salvato in: ./downloads/40829.txt
# Processo il documento 40830...
# Documento 40830 salvato in: ./downloads/40830.txt
# Processo il documento 40831...
# Documento 40831 salvato in: ./downloads/40831.txt
# Processo il documento 40832...
# Documento 40832 salvato in: ./downloads/40832.txt
# Processo il documento 40833...
# Documento 40833 salvato in: ./downloads/40833.txt
# Processo il documento 40834...
# Documento 40834 salvato in: ./downloads/40834.txt
# Processo il documento 40835...
# Documento 40835 salvato in: ./downloads/40835.txt
# Processo il documento 40836...
# Documento 40836 non trovato (HTTP 404).
# Processo il documento 40837...
# Documento 40837 non trovato (HTTP 404).
# Processo il documento 40838...
# Documento 40838 non trovato (HTTP 404).
# Processo il documento 40839...
# Documento 40839 non trovato (HTTP 404).
# Processo il documento 40840...
# Documento 40840 non trovato (HTTP 404).
# Processo il documento 40841...
# Documento 40841 salvato in: ./downloads/40841.txt
# Processo il documento 40842...
# Documento 40842 salvato in: ./downloads/40842.txt
# Processo il documento 40843...
# Documento 40843 salvato in: ./downloads/40843.txt
# Processo il documento 40844...
# Documento 40844 salvato in: ./downloads/40844.txt
# Processo il documento 40845...
# Documento 40845 salvato in: ./downloads/40845.txt
# Processo il documento 40846...
# Documento 40846 salvato in: ./downloads/40846.txt
# Processo il documento 40847...
# Documento 40847 non trovato (HTTP 404).
# Processo il documento 40848...
# Documento 40848 non trovato (HTTP 404).
# Processo il documento 40849...
# Documento 40849 non trovato (HTTP 404).
# Processo il documento 40850...
# Documento 40850 non trovato (HTTP 404).
# Processo il documento 40851...
# Documento 40851 non trovato (HTTP 404).
# Processo il documento 40852...
# Documento 40852 non trovato (HTTP 404).
# Processo il documento 40853...
# Documento 40853 non trovato (HTTP 404).
# Processo il documento 40854...
# Documento 40854 non trovato (HTTP 404).
# Processo il documento 40855...
# Documento 40855 non trovato (HTTP 404).
# Processo il documento 40856...
# Documento 40856 non trovato (HTTP 404).
# Processo il documento 40857...
# Documento 40857 non trovato (HTTP 404).
# Processo il documento 40858...
# Documento 40858 non trovato (HTTP 404).
# Processo il documento 40859...
# Documento 40859 non trovato (HTTP 404).
# Processo il documento 40860...
# Documento 40860 non trovato (HTTP 404).
# Processo il documento 40861...
# Documento 40861 salvato in: ./downloads/40861.txt
# Processo il documento 40862...
# Documento 40862 salvato in: ./downloads/40862.txt
# Processo il documento 40863...
# Documento 40863 salvato in: ./downloads/40863.txt
# Processo il documento 40864...
# Documento 40864 salvato in: ./downloads/40864.txt
# Processo il documento 40865...
# Documento 40865 salvato in: ./downloads/40865.txt
# Processo il documento 40866...
# Documento 40866 salvato in: ./downloads/40866.txt
# Processo il documento 40867...
# Documento 40867 salvato in: ./downloads/40867.txt
# Processo il documento 40868...
# Documento 40868 salvato in: ./downloads/40868.txt
# Processo il documento 40869...
# Documento 40869 salvato in: ./downloads/40869.txt
# Processo il documento 40870...
# Documento 40870 salvato in: ./downloads/40870.txt
# Processo il documento 40871...
# Documento 40871 salvato in: ./downloads/40871.txt
# Processo il documento 40872...
# Documento 40872 salvato in: ./downloads/40872.txt
# Processo il documento 40873...
# Documento 40873 non trovato (HTTP 404).
# Processo il documento 40874...
# Documento 40874 non trovato (HTTP 404).
# Processo il documento 40875...
# Documento 40875 non trovato (HTTP 404).
# Processo il documento 40876...
# Documento 40876 non trovato (HTTP 404).
# Processo il documento 40877...
# Documento 40877 non trovato (HTTP 404).
# Processo il documento 40878...
# Documento 40878 non trovato (HTTP 404).
# Processo il documento 40879...
# Documento 40879 non trovato (HTTP 404).
# Processo il documento 40880...
# Documento 40880 non trovato (HTTP 404).
# Processo il documento 40881...
# Documento 40881 salvato in: ./downloads/40881.txt
# Processo il documento 40882...
# Documento 40882 salvato in: ./downloads/40882.txt
# Processo il documento 40883...
# Documento 40883 salvato in: ./downloads/40883.txt
# Processo il documento 40884...
# Documento 40884 salvato in: ./downloads/40884.txt
# Processo il documento 40885...
# Documento 40885 salvato in: ./downloads/40885.txt
# Processo il documento 40886...
# Documento 40886 salvato in: ./downloads/40886.txt
# Processo il documento 40887...
# Documento 40887 salvato in: ./downloads/40887.txt
# Processo il documento 40888...
# Documento 40888 salvato in: ./downloads/40888.txt
# Processo il documento 40889...
# Documento 40889 salvato in: ./downloads/40889.txt
# Processo il documento 40890...
# Documento 40890 salvato in: ./downloads/40890.txt
# Processo il documento 40891...
# Documento 40891 salvato in: ./downloads/40891.txt
# Processo il documento 40892...
# Documento 40892 salvato in: ./downloads/40892.txt
# Processo il documento 40893...
# Documento 40893 non trovato (HTTP 404).
# Processo il documento 40894...
# Documento 40894 non trovato (HTTP 404).
# Processo il documento 40895...
# Documento 40895 non trovato (HTTP 404).
# Processo il documento 40896...
# Documento 40896 non trovato (HTTP 404).
# Processo il documento 40897...
# Documento 40897 non trovato (HTTP 404).
# Processo il documento 40898...
# Documento 40898 non trovato (HTTP 404).
# Processo il documento 40899...
# Documento 40899 non trovato (HTTP 404).
# Processo il documento 40900...
# Documento 40900 non trovato (HTTP 404).
# Processo il documento 40901...
# Documento 40901 salvato in: ./downloads/40901.txt
# Processo il documento 40902...
# Documento 40902 salvato in: ./downloads/40902.txt
# Processo il documento 40903...
# Documento 40903 salvato in: ./downloads/40903.txt
# Processo il documento 40904...
# Documento 40904 salvato in: ./downloads/40904.txt
# Processo il documento 40905...
# Documento 40905 salvato in: ./downloads/40905.txt
# Processo il documento 40906...
# Documento 40906 salvato in: ./downloads/40906.txt
# Processo il documento 40907...
# Documento 40907 salvato in: ./downloads/40907.txt
# Processo il documento 40908...
# Documento 40908 salvato in: ./downloads/40908.txt
# Processo il documento 40909...
# Documento 40909 salvato in: ./downloads/40909.txt
# Processo il documento 40910...
# Documento 40910 non trovato (HTTP 404).
# Processo il documento 40911...
# Documento 40911 non trovato (HTTP 404).
# Processo il documento 40912...
# Documento 40912 non trovato (HTTP 404).
# Processo il documento 40913...
# Documento 40913 non trovato (HTTP 404).
# Processo il documento 40914...
# Documento 40914 non trovato (HTTP 404).
# Processo il documento 40915...
# Documento 40915 non trovato (HTTP 404).
# Processo il documento 40916...
# Documento 40916 non trovato (HTTP 404).
# Processo il documento 40917...
# Documento 40917 non trovato (HTTP 404).
# Processo il documento 40918...
# Documento 40918 non trovato (HTTP 404).
# Processo il documento 40919...
# Documento 40919 non trovato (HTTP 404).
# Processo il documento 40920...
# Documento 40920 non trovato (HTTP 404).
# Processo il documento 40921...
# Documento 40921 salvato in: ./downloads/40921.txt
# Processo il documento 40922...
# Documento 40922 salvato in: ./downloads/40922.txt
# Processo il documento 40923...
# Documento 40923 salvato in: ./downloads/40923.txt
# Processo il documento 40924...
# Documento 40924 salvato in: ./downloads/40924.txt
# Processo il documento 40925...
# Documento 40925 salvato in: ./downloads/40925.txt
# Processo il documento 40926...
# Documento 40926 salvato in: ./downloads/40926.txt
# Processo il documento 40927...
# Documento 40927 salvato in: ./downloads/40927.txt
# Processo il documento 40928...
# Documento 40928 salvato in: ./downloads/40928.txt
# Processo il documento 40929...
# Documento 40929 salvato in: ./downloads/40929.txt
# Processo il documento 40930...
# Documento 40930 non trovato (HTTP 404).
# Processo il documento 40931...
# Documento 40931 non trovato (HTTP 404).
# Processo il documento 40932...
# Documento 40932 non trovato (HTTP 404).
# Processo il documento 40933...
# Documento 40933 non trovato (HTTP 404).
# Processo il documento 40934...
# Documento 40934 non trovato (HTTP 404).
# Processo il documento 40935...
# Documento 40935 non trovato (HTTP 404).
# Processo il documento 40936...
# Documento 40936 non trovato (HTTP 404).
# Processo il documento 40937...
# Documento 40937 non trovato (HTTP 404).
# Processo il documento 40938...
# Documento 40938 non trovato (HTTP 404).
# Processo il documento 40939...
# Documento 40939 non trovato (HTTP 404).
# Processo il documento 40940...
# Documento 40940 non trovato (HTTP 404).
# Processo il documento 40941...
# Documento 40941 salvato in: ./downloads/40941.txt
# Processo il documento 40942...
# Documento 40942 salvato in: ./downloads/40942.txt
# Processo il documento 40943...
# Documento 40943 salvato in: ./downloads/40943.txt
# Processo il documento 40944...
# Documento 40944 salvato in: ./downloads/40944.txt
# Processo il documento 40945...
# Documento 40945 salvato in: ./downloads/40945.txt
# Processo il documento 40946...
# Documento 40946 non trovato (HTTP 404).
# Processo il documento 40947...
# Documento 40947 non trovato (HTTP 404).
# Processo il documento 40948...
# Documento 40948 non trovato (HTTP 404).
# Processo il documento 40949...
# Documento 40949 non trovato (HTTP 404).
# Processo il documento 40950...
# Documento 40950 non trovato (HTTP 404).
# Processo il documento 40951...
# Documento 40951 non trovato (HTTP 404).
# Processo il documento 40952...
# Documento 40952 non trovato (HTTP 404).
# Processo il documento 40953...
# Documento 40953 non trovato (HTTP 404).
# Processo il documento 40954...
# Documento 40954 non trovato (HTTP 404).
# Processo il documento 40955...
# Documento 40955 non trovato (HTTP 404).
# Processo il documento 40956...
# Documento 40956 non trovato (HTTP 404).
# Processo il documento 40957...
# Documento 40957 non trovato (HTTP 404).
# Processo il documento 40958...
# Documento 40958 non trovato (HTTP 404).
# Processo il documento 40959...
# Documento 40959 non trovato (HTTP 404).
# Processo il documento 40960...
# Documento 40960 non trovato (HTTP 404).
# Processo il documento 40961...
# Documento 40961 salvato in: ./downloads/40961.txt
# Processo il documento 40962...
# Documento 40962 salvato in: ./downloads/40962.txt
# Processo il documento 40963...
# Documento 40963 salvato in: ./downloads/40963.txt
# Processo il documento 40964...
# Documento 40964 salvato in: ./downloads/40964.txt
# Processo il documento 40965...
# Documento 40965 salvato in: ./downloads/40965.txt
# Processo il documento 40966...
# Documento 40966 non trovato (HTTP 404).
# Processo il documento 40967...
# Documento 40967 non trovato (HTTP 404).
# Processo il documento 40968...
# Documento 40968 non trovato (HTTP 404).
# Processo il documento 40969...
# Documento 40969 non trovato (HTTP 404).
# Processo il documento 40970...
# Documento 40970 non trovato (HTTP 404).
# Processo il documento 40971...
# Documento 40971 non trovato (HTTP 404).
# Processo il documento 40972...
# Documento 40972 non trovato (HTTP 404).
# Processo il documento 40973...
# Documento 40973 non trovato (HTTP 404).
# Processo il documento 40974...
# Documento 40974 non trovato (HTTP 404).
# Processo il documento 40975...
# Documento 40975 non trovato (HTTP 404).
# Processo il documento 40976...
# Documento 40976 non trovato (HTTP 404).
# Processo il documento 40977...
# Documento 40977 non trovato (HTTP 404).
# Processo il documento 40978...
# Documento 40978 non trovato (HTTP 404).
# Processo il documento 40979...
# Documento 40979 non trovato (HTTP 404).
# Processo il documento 40980...
# Documento 40980 non trovato (HTTP 404).
# Processo il documento 40981...
# Documento 40981 salvato in: ./downloads/40981.txt
# Processo il documento 40982...
# Documento 40982 salvato in: ./downloads/40982.txt
# Processo il documento 40983...
# Documento 40983 salvato in: ./downloads/40983.txt
# Processo il documento 40984...
# Documento 40984 salvato in: ./downloads/40984.txt
# Processo il documento 40985...
# Documento 40985 salvato in: ./downloads/40985.txt
# Processo il documento 40986...
# Documento 40986 salvato in: ./downloads/40986.txt
# Processo il documento 40987...
# Documento 40987 salvato in: ./downloads/40987.txt
# Processo il documento 40988...
# Documento 40988 salvato in: ./downloads/40988.txt
# Processo il documento 40989...
# Documento 40989 salvato in: ./downloads/40989.txt
# Processo il documento 40990...
# Documento 40990 salvato in: ./downloads/40990.txt
# Processo il documento 40991...
# Documento 40991 salvato in: ./downloads/40991.txt
# Processo il documento 40992...
# Documento 40992 salvato in: ./downloads/40992.txt
# Processo il documento 40993...
# Documento 40993 salvato in: ./downloads/40993.txt
# Processo il documento 40994...
# Documento 41122 salvato in: ./downloads/41122.txt
# Processo il documento 41123...
# Documento 41123 salvato in: ./downloads/41123.txt
# Processo il documento 41124...
# Documento 41124 salvato in: ./downloads/41124.txt
# Processo il documento 41125...
# Documento 41125 salvato in: ./downloads/41125.txt
# Processo il documento 41126...
# Documento 41126 non trovato (HTTP 404).
# Processo il documento 41127...
# Documento 41127 non trovato (HTTP 404).
# Processo il documento 41128...
# Documento 41128 non trovato (HTTP 404).
# Processo il documento 41129...
# Documento 41129 non trovato (HTTP 404).
# Processo il documento 41130...
# Documento 41130 non trovato (HTTP 404).
# Processo il documento 41131...
# Documento 41131 non trovato (HTTP 404).
# Processo il documento 41132...
# Documento 41132 non trovato (HTTP 404).
# Processo il documento 41133...
# Documento 41133 non trovato (HTTP 404).
# Processo il documento 41134...
# Documento 41134 non trovato (HTTP 404).
# Processo il documento 41135...
# Documento 41135 non trovato (HTTP 404).
# Processo il documento 41136...
# Documento 41136 non trovato (HTTP 404).
# Processo il documento 41137...
# Documento 41137 non trovato (HTTP 404).
# Processo il documento 41138...
# Documento 41138 non trovato (HTTP 404).
# Processo il documento 41139...
# Documento 41139 non trovato (HTTP 404).
# Processo il documento 41140...
# Documento 41140 non trovato (HTTP 404).
# Processo il documento 41141...
# Documento 41141 non trovato (HTTP 404).
# Processo il documento 41142...
# Documento 41142 non trovato (HTTP 404).
# Processo il documento 41143...
# Documento 41143 non trovato (HTTP 404).
# Processo il documento 41144...
# Documento 41144 non trovato (HTTP 404).
# Processo il documento 41145...
# Documento 41145 non trovato (HTTP 404).
# Processo il documento 41146...
# Documento 41146 non trovato (HTTP 404).
# Processo il documento 41147...
# Documento 41147 non trovato (HTTP 404).
# Processo il documento 41148...
# Documento 41148 non trovato (HTTP 404).
# Processo il documento 41149...
# Documento 41149 non trovato (HTTP 404).
# Processo il documento 41150...
# Documento 41150 non trovato (HTTP 404).
# Processo il documento 41151...
# Documento 41151 non trovato (HTTP 404).
# Processo il documento 41152...
# Documento 41152 non trovato (HTTP 404).
# Processo il documento 41153...
# Documento 41153 non trovato (HTTP 404).
# Processo il documento 41154...
# Documento 41154 non trovato (HTTP 404).
# Processo il documento 41155...
# Documento 41155 non trovato (HTTP 404).
# Processo il documento 41156...
# Documento 41156 non trovato (HTTP 404).
# Processo il documento 41157...
# Documento 41157 non trovato (HTTP 404).
# Processo il documento 41158...
# Documento 41158 non trovato (HTTP 404).
# Processo il documento 41159...
# Documento 41159 non trovato (HTTP 404).
# Processo il documento 41160...
# Documento 41160 non trovato (HTTP 404).
# Processo il documento 41161...
# Documento 41161 non trovato (HTTP 404).
# Processo il documento 41162...
# Documento 41162 non trovato (HTTP 404).
# Processo il documento 41163...
# Documento 41163 non trovato (HTTP 404).
# Processo il documento 41164...
# Documento 41164 non trovato (HTTP 404).
# Processo il documento 41165...
# Documento 41165 non trovato (HTTP 404).
# Processo il documento 41166...
# Documento 41166 non trovato (HTTP 404).
# Processo il documento 41167...
# Documento 41167 non trovato (HTTP 404).
# Processo il documento 41168...
# Documento 41168 non trovato (HTTP 404).
# Processo il documento 41169...
# Documento 41256 salvato in: ./downloads/41256.txt
# Processo il documento 41257...
# Documento 41257 salvato in: ./downloads/41257.txt
# Processo il documento 41258...
# Documento 41258 salvato in: ./downloads/41258.txt
# Processo il documento 41259...
# Documento 41259 salvato in: ./downloads/41259.txt
# Processo il documento 41260...
# Documento 41260 salvato in: ./downloads/41260.txt
# Processo il documento 41261...
# Documento 41261 salvato in: ./downloads/41261.txt
# Processo il documento 41262...
# Documento 41262 salvato in: ./downloads/41262.txt
# Processo il documento 41263...
# Documento 41263 salvato in: ./downloads/41263.txt
# Processo il documento 41264...
# Documento 41264 salvato in: ./downloads/41264.txt
# Processo il documento 41265...
# Documento 41265 salvato in: ./downloads/41265.txt
# Processo il documento 41266...
# Documento 41266 salvato in: ./downloads/41266.txt
# Processo il documento 41267...
# Documento 41267 salvato in: ./downloads/41267.txt
# Processo il documento 41268...
# Documento 41268 salvato in: ./downloads/41268.txt
# Processo il documento 41269...
# Documento 41269 salvato in: ./downloads/41269.txt
# Processo il documento 41270...
# Documento 41270 salvato in: ./downloads/41270.txt
# Processo il documento 41271...
# Documento 41271 salvato in: ./downloads/41271.txt
# Processo il documento 41272...
# Documento 41272 salvato in: ./downloads/41272.txt
# Processo il documento 41273...
# Documento 41273 salvato in: ./downloads/41273.txt
# Processo il documento 41274...
# Documento 41274 salvato in: ./downloads/41274.txt
# Processo il documento 41275...
# Documento 41275 salvato in: ./downloads/41275.txt
# Processo il documento 41276...
# Documento 41276 salvato in: ./downloads/41276.txt
# Processo il documento 41277...
# Documento 41277 salvato in: ./downloads/41277.txt
# Processo il documento 41278...
# Documento 41278 salvato in: ./downloads/41278.txt
# Processo il documento 41279...
# Documento 41279 salvato in: ./downloads/41279.txt
# Processo il documento 41280...
# Documento 41280 salvato in: ./downloads/41280.txt
# Processo il documento 41281...
# Documento 41281 salvato in: ./downloads/41281.txt
# Processo il documento 41282...
# Documento 41282 salvato in: ./downloads/41282.txt
# Processo il documento 41283...
# Documento 41283 salvato in: ./downloads/41283.txt
# Processo il documento 41284...
# Documento 41284 salvato in: ./downloads/41284.txt
# Processo il documento 41285...
# Documento 41285 salvato in: ./downloads/41285.txt
# Processo il documento 41286...
# Documento 41286 non trovato (HTTP 404).
# Processo il documento 41287...
# Documento 41287 non trovato (HTTP 404).
# Processo il documento 41288...
# Documento 41288 non trovato (HTTP 404).
# Processo il documento 41289...
# Documento 41289 non trovato (HTTP 404).
# Processo il documento 41290...
# Documento 41290 non trovato (HTTP 404).
# Processo il documento 41291...
# Documento 41291 non trovato (HTTP 404).
# Processo il documento 41292...
# Documento 41292 non trovato (HTTP 404).
# Processo il documento 41293...
# Documento 41293 non trovato (HTTP 404).
# Processo il documento 41294...
# Documento 41294 non trovato (HTTP 404).
# Processo il documento 41295...
# Documento 41295 non trovato (HTTP 404).
# Processo il documento 41296...
# Documento 41296 non trovato (HTTP 404).
# Processo il documento 41297...
# Documento 41297 non trovato (HTTP 404).
# Processo il documento 41298...
# Documento 41298 non trovato (HTTP 404).
# Processo il documento 41299...
# Documento 41299 non trovato (HTTP 404).
# Documento 41342 salvato in: ./downloads/41342.txt
# Processo il documento 41343...
# Documento 41343 salvato in: ./downloads/41343.txt
# Processo il documento 41344...
# Documento 41344 salvato in: ./downloads/41344.txt
# Processo il documento 41345...
# Documento 41345 salvato in: ./downloads/41345.txt
# Processo il documento 41346...
# Documento 41346 salvato in: ./downloads/41346.txt
# Processo il documento 41347...
# Documento 41347 salvato in: ./downloads/41347.txt
# Processo il documento 41348...
# Documento 41348 salvato in: ./downloads/41348.txt
# Processo il documento 41349...
# Documento 41349 salvato in: ./downloads/41349.txt
# Processo il documento 41350...
# Documento 41350 non trovato (HTTP 404).
# Processo il documento 41351...
# Documento 41351 non trovato (HTTP 404).
# Processo il documento 41352...
# Documento 41352 non trovato (HTTP 404).
# Processo il documento 41353...
# Documento 41353 non trovato (HTTP 404).
# Processo il documento 41354...
# Documento 41354 non trovato (HTTP 404).
# Processo il documento 41355...
# Documento 41355 non trovato (HTTP 404).
# Processo il documento 41356...
# Documento 41356 non trovato (HTTP 404).
# Processo il documento 41357...
# Documento 41357 non trovato (HTTP 404).
# Processo il documento 41358...
# Documento 41358 non trovato (HTTP 404).
# Processo il documento 41359...
# Documento 41359 non trovato (HTTP 404).
# Processo il documento 41360...
# Documento 41360 non trovato (HTTP 404).
# Processo il documento 41361...
# Documento 41361 salvato in: ./downloads/41361.txt
# Processo il documento 41362...
# Documento 41362 salvato in: ./downloads/41362.txt
# Processo il documento 41363...
# Documento 41363 salvato in: ./downloads/41363.txt
# Processo il documento 41364...
# Documento 41364 salvato in: ./downloads/41364.txt
# Processo il documento 41365...
# Documento 41365 salvato in: ./downloads/41365.txt
# Processo il documento 41366...
# Documento 41366 salvato in: ./downloads/41366.txt
# Processo il documento 41367...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 52
#      49     print("Completato! Tutti i documenti salvati nella cartella:", OUTPUT_FOLDER)
#      51 if __name__ == "__main__":
# ---> 52     main(start_id=40799, end_id=42421)
#
# Cell In[5], line 33, in main(start_id, end_id)
#      31 for doc_id in range(start_id, end_id + 1):
#      32     print(f"Processo il documento {doc_id}...")
# ---> 33     file_path = scrape_and_save(doc_id)
#      35     if file_path:
#      36         csv_data.append({"ID_file": doc_id, "path_src": file_path})
#
# Cell In[5], line 11, in scrape_and_save(doc_id)
#       8 def scrape_and_save(doc_id):
#       9     url = BASE_URL.format(doc_id)
# ---> 11     response = requests.get(url)
#      12     if response.status_code != 200:
#      13         print(f"Documento {doc_id} non trovato (HTTP {response.status_code}).")
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1303, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1299     if flags != 0:
#    1300         raise ValueError(
#    1301           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302           self.__class__)
# -> 1303     return self.read(nbytes, buffer)
#    1304 else:
#    1305     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1159, in SSLSocket.read(self, len, buffer)
#    1157 try:
#    1158     if buffer is not None:
# -> 1159         return self._sslobj.read(len, buffer)
#    1160     else:
#    1161         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def generate_csv_from_folder(folder_path, csv_file="csv_paths.csv"):
    csv_data = []
    
    # Verifica che la cartella esista
    if not os.path.exists(folder_path):
        print(f"La cartella {folder_path} non esiste.")
        return
    
    # Scansiona la cartella per trovare i file
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        
        if os.path.isfile(file_path):  # Assicuriamoci che sia un file e non una cartella
            file_id, _ = os.path.splitext(file_name)  # Rimuove l'estensione
            csv_data.append({"ID_file": file_id, "path_src": file_path})
    
    # Salvataggio dei dati in un file CSV
    with open(csv_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["ID_file", "path_src"])
        writer.writeheader()
        writer.writerows(csv_data)
    
    print(f"File CSV creato con successo: {csv_file}")

# Esempio di utilizzo
folder_path = "./downloads"  # Modifica con il percorso della tua cartella
generate_csv_from_folder(folder_path)
# Out:
# File CSV creato con successo: csv_paths.csv

# %%
#funzione per pulire i file txt dalle parti inutili presenti nella pagina web del consiglio Valle
def first_clean(target_folder, keyword, mid_strings, end_keyword, csv_paths):
    df = pd.read_csv(csv_paths)

    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    df["path_clean"] = ""

    for idx, row in df.iterrows():
        source_path = row["path_src"]
        if source_path.endswith(".txt"):
            filename = os.path.basename(source_path)
            target_path = os.path.join(target_folder, filename)

            df.at[idx, "path_clean"] = target_path

            with open(source_path, "r", encoding="utf-8") as file:
                content = file.read()

            if keyword in content:
                content = keyword + content.split(keyword, 1)[1] 

            for mid_string in mid_strings:
                content = re.sub(re.escape(mid_string), "", content) 

            if end_keyword in content:
                content = content.split(end_keyword, 1)[0]  

            with open(target_path, "w", encoding="utf-8") as file:
                file.write(content)

    df.to_csv(csv_paths, index=False)

#funzione per estrarre informazioni dai file txt: oggetto, legislatura, data e classificazione
def extract_and_format_date(text):
    
    date_pattern = re.search(r"(\d{1,2})\s+([a-zA-Z]+)\s+(\d{4})", text)
    
    if date_pattern:
        day, month_name, year = date_pattern.groups()
        
        months = {
            "gennaio": "01", "febbraio": "02", "marzo": "03", "aprile": "04", "maggio": "05", "giugno": "06",
            "luglio": "07", "agosto": "08", "settembre": "09", "ottobre": "10", "novembre": "11", "dicembre": "12"
        }
        
        month = months.get(month_name.lower())
        
        if month:
            return f"{int(day):02d}/{month}/{year}"
    
    return None

def first_info(pattern1, pattern2, csv_paths):
    df_paths = pd.read_csv(csv_paths)

    #df_paths['language'] = ""
    df_paths['object'] = ""
    df_paths['legislature'] = ""
    df_paths['date'] = ""
    df_paths['month'] = ""
    df_paths['class'] = ""

    for idx, row in df_paths.iterrows():
        source_path = row["path_clean"]
        if source_path.endswith(".txt"):
            filename = os.path.basename(source_path)
            filenum = int(os.path.splitext(filename)[0])

            with open(source_path, "r", encoding="utf-8") as file:
                content = file.read()

            match1 = re.search(pattern1, content)

            if match1:
                stringa = match1.group(1).strip()
                ogg, leg = stringa.split("/", 1)

                df_paths.loc[df_paths['ID_file'] == filenum, 'object'] = ogg
                df_paths.loc[df_paths['ID_file'] == filenum, 'legislature'] = leg

            date = extract_and_format_date(content)
            df_paths.loc[df_paths['ID_file'] == filenum, 'date'] = date
            if date:
                df_paths.loc[df_paths['ID_file'] == filenum, 'month'] = date.split("/")[1]
            
            match2 = re.search(pattern2, content, re.DOTALL)
            
            if match2:
                classe = match2.group(1).strip()
                classe = classe.replace("\n", ", ").strip()
                df_paths.loc[df_paths['ID_file'] == filenum, 'class'] = classe

            #try:
            #    lang = detect(content)
            #    if lang == 'fr':
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'fr'
            #    elif lang == 'it':
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'it'
            #    else:
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'other'
            #except:
            #    df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'error'

    df_paths.to_csv(csv_paths, index=False)

def second_info(csv_paths):
    df = pd.read_csv(csv_paths)
    
    if "obj_pos" not in df.columns:
        df["obj_pos"] = 0
    
    df["object"] = pd.to_numeric(df["object"], errors="coerce")  # Converti in numero per ordinamento
    
    df.sort_values(by=["date", "object"], ascending=[True, True], inplace=True)
    
    df["obj_pos"] = df.groupby("date").cumcount() + 1  # Assegna numeri progressivi
    
    df.to_csv(csv_paths, index=False)

# %%
target_folder = "./clean"

csv_paths = "./csv_paths.csv"
csv_details = "./csv_details.csv"
csv_cons = "./csv_cons.csv"
csv_chunks = "./csv_chunks.csv"

# %%
keyword = "Classificazione"
mid_strings = ["Precedente", "Successivo", "Resoconto integrale del dibattito dell'aula. I documenti allegati sono reperibili nel link \"iter atto\"."]
end_keyword = "Informativa cookies"

first_clean(target_folder, keyword, mid_strings, end_keyword, csv_paths)

pattern1 = r'(?:OGGETTO N\.|OBJET N°)(.*?)\s*-'
pattern2 = r'Classificazione\s*(.*?)\s*Oggetto'

first_info(pattern1, pattern2, csv_paths)
second_info(csv_paths)

# %%
import pandas as pd
import re

def define_names(csv_cons, leg):
    df_cons = pd.read_csv(csv_cons)
    df_cons = df_cons.reset_index()  # Aggiunge l'indice come colonna ID_cons
    df_cons.rename(columns={'index': 'ID_cons'}, inplace=True)
    names = []
    
    print(f"Filtrando per legislatura: {leg}")
    filtered_cons = df_cons[df_cons['legislature'].str.contains(leg, case=False, na=False)]
    
    surname_counts = filtered_cons['surname'].value_counts()

    for idx, row in filtered_cons.iterrows():
        surname = row["surname"]
        name = row["name"]
        
        if surname_counts[surname] > 1:
            names.append(f"{surname} {name[0]}.")
        else:
            names.append(surname)
    
    print(f"Numero di nomi trovati per la legislatura {leg}: {len(names)}")
    return filtered_cons, names

def isolate_chunk(csv_paths, csv_cons):
    df_paths = pd.read_csv(csv_paths)
    chunk_list = []

    for idx, row in df_paths.iterrows():
        leg = row["legislature"]
        date = row["date"]
        month = row["month"]
        #language = row["language"]
        obj = row["obj_pos"]
        
        print(f"Processando file {row['path_clean']} per la legislatura {leg}...")
        
        try:
            df_cons, list_cons = define_names(csv_cons, leg)

            with open(row["path_clean"], 'r') as f:
                text = f.read()

                all_matches = []
                for name in list_cons:
                    pattern = r"(?i)" + re.escape(name) + r"\s?\([^)]*\)\s?-"
                    matches = list(re.finditer(pattern, text))
                    all_matches.extend(matches)
                
                president_pattern = r"(?i)Presidente\s?-"
                president_matches = list(re.finditer(president_pattern, text))
                all_matches.extend(president_matches)
                
                all_matches.sort(key=lambda match: match.start())
                
                president_data = None
                if all_matches:
                    first_match = all_matches[0]
                    if not re.match(president_pattern, first_match.group(0), re.IGNORECASE):
                        surname = first_match.group(0)
                        words = surname.split()
                        surname = " ".join(words[:2])
                        if words[1].endswith('.') or words[1].startswith('('):
                            surname = words[0]
                        person_info = df_cons[df_cons["surname"] == surname].iloc[0]
                        president_data = {
                            "ID_cons": person_info["ID_cons"],
                            "year_birth": person_info["year_birth"],
                            "gender": person_info["gender"],
                            "group": 'Presidente',
                            "seniority": len(person_info["legislature"].split(','))
                        }

                chunk_idx = 1
                for i, match in enumerate(all_matches):
                    start_pos = match.end() 
                    end_pos = all_matches[i + 1].start() if i + 1 < len(all_matches) else len(text)

                    chunk = text[start_pos:end_pos].replace("\n", " ").strip()

                    if chunk:
                        if re.match(president_pattern, match.group(0), re.IGNORECASE):
                            if president_data:
                                ID_cons = president_data["ID_cons"]
                                year_birth = president_data["year_birth"]
                                gender = president_data["gender"]
                                group = president_data["group"]
                                seniority = president_data["seniority"]
                            else:
                                ID_cons = "N/A"
                                year_birth = "N/A"
                                gender = "N/A"
                                group = "N/A"
                                seniority = "N/A"
                        else:
                            surname = match.group(0)
                            party = re.search(r'\((.*?)\)', surname)
                            group = party.group(1) if party else "N/A"
                            words = surname.split()
                            surname = " ".join(words[:2])
                            if words[1].endswith('.') or words[1].startswith('('):
                                surname = words[0]
                            try:
                                person_info = df_cons[df_cons["surname"] == surname].iloc[0]
                                ID_cons = person_info["ID_cons"]
                                year_birth = person_info["year_birth"]
                                gender = person_info["gender"]
                                seniority = len(person_info["legislature"].split(','))
                            except IndexError:
                                ID_cons = "N/A"
                                year_birth = "N/A"
                                gender = "N/A"
                                group = "N/A"
                                seniority = "N/A"

                        chunk_list.append({
                            "ID_file": row["ID_file"],
                            "leg": leg,
                            "date": date,
                            "month": month,
                            "class": row["class"],
                            "obj_pos": obj,
                            #"language": language,
                            "ID_cons": ID_cons,
                            "year_birth": year_birth,
                            "gender": gender,
                            "group": group,
                            "seniority": seniority,
                            "position": chunk_idx,
                            "length": len(chunk),
                            "chunk": chunk
                        })
                        
                        chunk_idx += 1
            print('File ok')

        except Exception as e:
            print(f"Errore nel file {row['path_clean']}: {e}. Saltando questa entry.")
            continue

    df_chunks = pd.DataFrame(chunk_list)
    print(f"Numero totale di chunk processati: {len(chunk_list)}")
    return df_chunks

df = isolate_chunk(csv_paths, csv_cons)

print("Salvataggio del file csv_chunks.csv...")
df.to_csv("csv_chunks.csv", index=False)
print("File salvato con successo!")
# Out:
# Processando file ./clean/45461.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45462.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45463.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45464.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45465.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43971.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47801.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47802.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47803.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47804.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47805.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47806.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47807.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47808.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47809.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47810.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47811.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47812.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47813.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47814.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47815.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47816.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47817.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47818.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47819.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47820.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47821.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45161.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45162.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45163.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45164.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45165.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45166.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45167.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45168.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45169.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45170.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45171.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45172.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45173.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45174.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45175.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45176.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45177.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45178.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45179.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45180.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45181.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45182.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45183.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45184.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45185.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45186.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45187.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45188.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45189.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45190.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45191.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/
txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43962.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43965.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43966.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43967.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43969.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43970.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43972.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43973.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43975.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43976.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43977.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43979.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43980.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43982.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43984.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43986.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43987.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43989.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43991.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43993.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43994.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45277.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45278.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Numero totale di chunk processati: 34456
# Salvataggio del file csv_chunks.csv...
# File salvato con successo!

# %%
df_chunks = pd.read_csv(csv_chunks)

df_outcomes = df_chunks.copy()
df_outcomes = df_outcomes.drop(columns=['ID_cons','year_birth','gender','group','position','length','chunk'])
df_outcomes = df_outcomes.drop_duplicates(subset=['ID_file'])

intervention_counts = df_chunks.groupby('ID_file').size().reset_index(name='# interventions')
df_outcomes = df_outcomes.merge(intervention_counts, on='ID_file', how='left')

df_chunks_filtered = df_chunks[df_chunks['group'] != 'Presidente']
intervention_counts_filtered = df_chunks_filtered.groupby('ID_file').size().reset_index(name='# interventions (w/o president)')
df_outcomes = df_outcomes.merge(intervention_counts_filtered, on='ID_file', how='left')

length_sum = df_chunks.groupby('ID_file')['length'].sum().reset_index(name='total_length')
df_outcomes = df_outcomes.merge(length_sum, on='ID_file', how='left')

length_sum_filtered = df_chunks_filtered.groupby('ID_file')['length'].sum().reset_index(name='total_length (w/o president)')
df_outcomes = df_outcomes.merge(length_sum_filtered, on='ID_file', how='left')

def extract_number(text, pattern):
    match = re.search(pattern, text)
    if match:
        return int(match.group(1))  
    return None

def get_count(id_file, pattern):
    chunks = df_chunks[(df_chunks['ID_file'] == id_file) & (df_chunks['group'] == 'Presidente')]
    
    for chunk in chunks['chunk']:
        number = extract_number(chunk, pattern)
        if number is not None:
            return number
    
    return None

presenti = r"Presenti: (\d+)"
votanti = r"Votanti: (\d+)"
favorevoli = r"Favorevoli: (\d+)"
contrari = r"Contrari: (\d+)"
astenuti = r"Astenuti: (\d+)"

df_outcomes['presenti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, presenti))
df_outcomes['votanti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, votanti))
df_outcomes['favorevoli'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, favorevoli))
df_outcomes['contrari'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, contrari))
df_outcomes['astenuti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, astenuti))

def determine_outcome(row):
    favorevoli = row['favorevoli'] if pd.notna(row['favorevoli']) else 0
    contrari = row['contrari'] if pd.notna(row['contrari']) else 0
    astenuti = row['astenuti'] if pd.notna(row['astenuti']) else 0

    if pd.isna(row['favorevoli']) and pd.isna(row['contrari']) and pd.isna(row['astenuti']):
        return np.nan

    if favorevoli > contrari and favorevoli > astenuti:
        return 'approvato'
    else:
        return 'non approvato'

df_outcomes['outcome'] = df_outcomes.apply(determine_outcome, axis=1)

df_outcomes.to_csv("csv_outcomes.csv", index=False)

# %%
df = pd.read_csv("csv_chunks.csv")

df_filtered = df[df['group'] != 'Presidente']

df_filtered.to_csv("csv_chunks_filtered.csv", index=False)

# %%
valid_outcomes = df_outcomes[df_outcomes['outcome'].notna()]['ID_file']

df = pd.read_csv("csv_chunks.csv")
df_filtered = df[df['ID_file'].isin(valid_outcomes)]

df_filtered.to_csv("csv_chunks_outcomes.csv", index=False)

df = pd.read_csv("csv_chunks_outcomes.csv")

df_filtered = df[df['group'] != 'Presidente']

df_filtered.to_csv("csv_chunks_outcomes_filtered.csv", index=False)
