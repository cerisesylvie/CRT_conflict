# %%
import os
import re
import csv
import pandas as pd
import numpy as np

import time
import requests
from bs4 import BeautifulSoup

#from langdetect import detect
#from deep_translator import GoogleTranslator

# %%
BASE_URL = "https://www.consiglio.vda.it/app/oggettidelconsiglio/dettaglio?pk_documento={}&versione=R"

OUTPUT_FOLDER = "./downloads"
if not os.path.exists(OUTPUT_FOLDER):
    os.makedirs(OUTPUT_FOLDER)

#funzione per scraperare e salvare i resoconti dal sito del consiglio Valle
def scrape_and_save(doc_id):
    url = BASE_URL.format(doc_id)

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Documento {doc_id} non trovato (HTTP {response.status_code}).")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    page_text = soup.get_text(separator="\n", strip=True)

    output_file = os.path.join(OUTPUT_FOLDER, f"{doc_id}.txt")
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(page_text)
    
    print(f"Documento {doc_id} salvato in: {output_file}")
    return output_file


def main(start_id, end_id):
    csv_data = []
    print(f"Inizio lo scraping per i documenti dal {start_id} al {end_id}...")

    for doc_id in range(start_id, end_id + 1):
        print(f"Processo il documento {doc_id}...")
        file_path = scrape_and_save(doc_id)

        if file_path:
            csv_data.append({"ID_file": doc_id, "path_src": file_path})

        # Pausa per evitare di sovraccaricare il server (ad esempio 2-5 secondi)
        time.sleep(2 + (3 * doc_id % 5))  # Variamo la pausa per evitare un pattern troppo prevedibile

    # Salvataggio dei risultati nel file CSV
    csv_file = "csv_paths.csv"
    print(f"Salvataggio dei risultati nel file CSV: {csv_file}")
    with open(csv_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["ID_file", "path_src"])
        writer.writeheader()
        writer.writerows(csv_data)

    print("Completato! Tutti i documenti salvati nella cartella:", OUTPUT_FOLDER)

if __name__ == "__main__":
    main(start_id=41367, end_id=42421)
# Out:
# Inizio lo scraping per i documenti dal 41367 al 42421...
# Processo il documento 41367...
# Documento 41367 salvato in: ./downloads/41367.txt
# Processo il documento 41368...
# Documento 41368 salvato in: ./downloads/41368.txt
# Processo il documento 41369...
# Documento 41369 salvato in: ./downloads/41369.txt
# Processo il documento 41370...
# Documento 41370 salvato in: ./downloads/41370.txt
# Processo il documento 41371...
# Documento 41371 salvato in: ./downloads/41371.txt
# Processo il documento 41372...
# Documento 41372 salvato in: ./downloads/41372.txt
# Processo il documento 41373...
# Documento 41373 salvato in: ./downloads/41373.txt
# Processo il documento 41374...
# Documento 41374 salvato in: ./downloads/41374.txt
# Processo il documento 41375...
# Documento 41375 salvato in: ./downloads/41375.txt
# Processo il documento 41376...
# Documento 41376 salvato in: ./downloads/41376.txt
# Processo il documento 41377...
# Documento 41377 salvato in: ./downloads/41377.txt
# Processo il documento 41378...
# Documento 41378 salvato in: ./downloads/41378.txt
# Processo il documento 41379...
# Documento 41379 salvato in: ./downloads/41379.txt
# Processo il documento 41380...
# Documento 41380 salvato in: ./downloads/41380.txt
# Processo il documento 41381...
# Documento 41381 salvato in: ./downloads/41381.txt
# Processo il documento 41382...
# Documento 41382 salvato in: ./downloads/41382.txt
# Processo il documento 41508...
# Documento 41508 salvato in: ./downloads/41508.txt
# Processo il documento 41509...
# Documento 41509 salvato in: ./downloads/41509.txt
# Processo il documento 41510...
# Documento 41510 salvato in: ./downloads/41510.txt
# Processo il documento 41511...
# Documento 41511 non trovato (HTTP 404).
# Processo il documento 41512...
# Documento 41512 non trovato (HTTP 404).
# Processo il documento 41513...
# Documento 41513 non trovato (HTTP 404).
# Processo il documento 41514...
# Documento 41514 non trovato (HTTP 404).
# Processo il documento 41515...
# Documento 41515 non trovato (HTTP 404).
# Processo il documento 41516...
# Documento 41516 non trovato (HTTP 404).
# Processo il documento 41517...
# Documento 41517 non trovato (HTTP 404).
# Processo il documento 41518...
# Documento 41518 non trovato (HTTP 404).
# Processo il documento 41519...
# Documento 41519 non trovato (HTTP 404).
# Processo il documento 41520...
# Documento 41520 non trovato (HTTP 404).
# Processo il documento 41521...
# Documento 41521 salvato in: ./downloads/41521.txt
# Processo il documento 41522...
# Documento 41522 salvato in: ./downloads/41522.txt
# Processo il documento 41523...
# Documento 41523 salvato in: ./downloads/41523.txt
# Processo il documento 41524...
# Documento 41524 salvato in: ./downloads/41524.txt
# Processo il documento 41525...
# Documento 41525 salvato in: ./downloads/41525.txt
# Processo il documento 41526...
# Documento 41526 salvato in: ./downloads/41526.txt
# Processo il documento 41527...
# Documento 41527 salvato in: ./downloads/41527.txt
# Processo il documento 41528...
# Documento 41528 salvato in: ./downloads/41528.txt
# Processo il documento 41529...
# Documento 41529 salvato in: ./downloads/41529.txt
# Processo il documento 41530...
# Documento 41530 salvato in: ./downloads/41530.txt
# Processo il documento 41531...
# Documento 41531 salvato in: ./downloads/41531.txt
# Processo il documento 41532...
# Documento 41532 non trovato (HTTP 404).
# Processo il documento 41533...
# Documento 41533 non trovato (HTTP 404).
# Processo il documento 41534...
# Documento 41534 non trovato (HTTP 404).
# Processo il documento 41535...
# Documento 41535 non trovato (HTTP 404).
# Processo il documento 41536...
# Documento 41536 non trovato (HTTP 404).
# Processo il documento 41537...
# Documento 41537 non trovato (HTTP 404).
# Processo il documento 41538...
# Documento 41538 non trovato (HTTP 404).
# Processo il documento 41539...
# Documento 41539 non trovato (HTTP 404).
# Processo il documento 41540...
# Documento 41540 non trovato (HTTP 404).
# Processo il documento 41541...
# Documento 41541 salvato in: ./downloads/41541.txt
# Processo il documento 41542...
# Documento 41542 salvato in: ./downloads/41542.txt
# Processo il documento 41543...
# Documento 41543 salvato in: ./downloads/41543.txt
# Processo il documento 41544...
# Documento 41544 salvato in: ./downloads/41544.txt
# Processo il documento 41545...
# Documento 41545 salvato in: ./downloads/41545.txt
# Processo il documento 41546...
# Documento 41546 salvato in: ./downloads/41546.txt
# Processo il documento 41547...
# Documento 41547 salvato in: ./downloads/41547.txt
# Processo il documento 41548...
# Documento 41548 salvato in: ./downloads/41548.txt
# Processo il documento 41549...
# Documento 41549 salvato in: ./downloads/41549.txt
# Processo il documento 41550...
# Documento 41550 salvato in: ./downloads/41550.txt
# Documento 41592 salvato in: ./downloads/41592.txt
# Processo il documento 41593...
# Documento 41593 salvato in: ./downloads/41593.txt
# Processo il documento 41594...
# Documento 41594 salvato in: ./downloads/41594.txt
# Processo il documento 41595...
# Documento 41595 salvato in: ./downloads/41595.txt
# Processo il documento 41596...
# Documento 41596 salvato in: ./downloads/41596.txt
# Processo il documento 41597...
# Documento 41597 salvato in: ./downloads/41597.txt
# Processo il documento 41598...
# Documento 41598 salvato in: ./downloads/41598.txt
# Processo il documento 41599...
# Documento 41599 salvato in: ./downloads/41599.txt
# Processo il documento 41600...
# Documento 41600 salvato in: ./downloads/41600.txt
# Processo il documento 41601...
# Documento 41601 salvato in: ./downloads/41601.txt
# Processo il documento 41602...
# Documento 41602 salvato in: ./downloads/41602.txt
# Processo il documento 41603...
# Documento 41603 salvato in: ./downloads/41603.txt
# Processo il documento 41604...
# Documento 41604 non trovato (HTTP 404).
# Processo il documento 41605...
# Documento 41605 non trovato (HTTP 404).
# Processo il documento 41606...
# Documento 41606 non trovato (HTTP 404).
# Processo il documento 41607...
# Documento 41607 non trovato (HTTP 404).
# Processo il documento 41608...
# Documento 41608 non trovato (HTTP 404).
# Processo il documento 41609...
# Documento 41609 non trovato (HTTP 404).
# Processo il documento 41610...
# Documento 41610 non trovato (HTTP 404).
# Processo il documento 41611...
# Documento 41611 non trovato (HTTP 404).
# Processo il documento 41612...
# Documento 41612 non trovato (HTTP 404).
# Processo il documento 41613...
# Documento 41613 non trovato (HTTP 404).
# Processo il documento 41614...
# Documento 41614 non trovato (HTTP 404).
# Processo il documento 41615...
# Documento 41615 non trovato (HTTP 404).
# Processo il documento 41616...
# Documento 41616 non trovato (HTTP 404).
# Processo il documento 41617...
# Documento 41617 non trovato (HTTP 404).
# Processo il documento 41618...
# Documento 41618 non trovato (HTTP 404).
# Processo il documento 41619...
# Documento 41619 non trovato (HTTP 404).
# Processo il documento 41620...
# Documento 41620 non trovato (HTTP 404).
# Processo il documento 41621...
# Documento 41621 salvato in: ./downloads/41621.txt
# Processo il documento 41622...
# Documento 41622 salvato in: ./downloads/41622.txt
# Processo il documento 41623...
# Documento 41623 salvato in: ./downloads/41623.txt
# Processo il documento 41624...
# Documento 41624 salvato in: ./downloads/41624.txt
# Processo il documento 41625...
# Documento 41625 salvato in: ./downloads/41625.txt
# Processo il documento 41626...
# Documento 41626 salvato in: ./downloads/41626.txt
# Processo il documento 41627...
# Documento 41627 salvato in: ./downloads/41627.txt
# Processo il documento 41628...
# Documento 41628 salvato in: ./downloads/41628.txt
# Processo il documento 41629...
# Documento 41629 salvato in: ./downloads/41629.txt
# Processo il documento 41630...
# Documento 41630 salvato in: ./downloads/41630.txt
# Processo il documento 41631...
# Documento 41631 salvato in: ./downloads/41631.txt
# Processo il documento 41632...
# Documento 41632 salvato in: ./downloads/41632.txt
# Processo il documento 41633...
# Documento 41633 salvato in: ./downloads/41633.txt
# Processo il documento 41634...
# Documento 41634 non trovato (HTTP 404).
# Processo il documento 41635...
# Documento 41635 non trovato (HTTP 404).
# Processo il documento 41636...
# Documento 41636 non trovato (HTTP 404).
# Processo il documento 41637...
# Documento 41637 non trovato (HTTP 404).
# Processo il documento 41638...
# Documento 41638 non trovato (HTTP 404).
# Processo il documento 41639...
# Documento 41639 non trovato (HTTP 404).
# Processo il documento 41640...
# Documento 41640 non trovato (HTTP 404).
# Processo il documento 41641...
# Documento 41641 salvato in: ./downloads/41641.txt
# Processo il documento 41642...
# Documento 41642 non trovato (HTTP 404).
# Processo il documento 41643...
# Documento 41643 non trovato (HTTP 404).
# Processo il documento 41644...
# Documento 41644 non trovato (HTTP 404).
# Processo il documento 41645...
# Documento 41645 non trovato (HTTP 404).
# Processo il documento 41646...
# Documento 41646 non trovato (HTTP 404).
# Processo il documento 41647...
# Documento 41647 non trovato (HTTP 404).
# Processo il documento 41648...
# Documento 41648 non trovato (HTTP 404).
# Processo il documento 41649...
# Documento 41649 non trovato (HTTP 404).
# Processo il documento 41650...
# Documento 41650 non trovato (HTTP 404).
# Processo il documento 41651...
# Documento 41651 non trovato (HTTP 404).
# Processo il documento 41652...
# Documento 41652 non trovato (HTTP 404).
# Processo il documento 41653...
# Documento 41653 non trovato (HTTP 404).
# Processo il documento 41654...
# Documento 41654 non trovato (HTTP 404).
# Processo il documento 41655...
# Documento 41655 non trovato (HTTP 404).
# Processo il documento 41656...
# Documento 41656 non trovato (HTTP 404).
# Processo il documento 41657...
# Documento 41657 non trovato (HTTP 404).
# Processo il documento 41658...
# Documento 41658 non trovato (HTTP 404).
# Processo il documento 41659...
# Documento 41659 non trovato (HTTP 404).
# Processo il documento 41660...
# Documento 41660 non trovato (HTTP 404).
# Processo il documento 41661...
# Documento 41661 salvato in: ./downloads/41661.txt
# Processo il documento 41662...
# Documento 41662 salvato in: ./downloads/41662.txt
# Processo il documento 41663...
# Documento 41663 salvato in: ./downloads/41663.txt
# Processo il documento 41664...
# Documento 41664 salvato in: ./downloads/41664.txt
# Processo il documento 41665...
# Documento 41665 salvato in: ./downloads/41665.txt
# Processo il documento 41666...
# Documento 41666 salvato in: ./downloads/41666.txt
# Processo il documento 41667...
# Documento 41667 salvato in: ./downloads/41667.txt
# Processo il documento 41668...
# Documento 41668 salvato in: ./downloads/41668.txt
# Processo il documento 41669...
# Documento 41669 salvato in: ./downloads/41669.txt
# Processo il documento 41670...
# Documento 41670 salvato in: ./downloads/41670.txt
# Processo il documento 41671...
# Documento 41671 salvato in: ./downloads/41671.txt
# Processo il documento 41672...
# Documento 41672 salvato in: ./downloads/41672.txt
# Processo il documento 41673...
# Documento 41673 salvato in: ./downloads/41673.txt
# Processo il documento 41674...
# Documento 41674 salvato in: ./downloads/41674.txt
# Processo il documento 41675...
# Documento 41675 salvato in: ./downloads/41675.txt
# Processo il documento 41676...
# Documento 41676 salvato in: ./downloads/41676.txt
# Processo il documento 41677...
# Documento 41677 salvato in: ./downloads/41677.txt
# Processo il documento 41678...
# Documento 41678 salvato in: ./downloads/41678.txt
# Processo il documento 41679...
# Documento 41761 salvato in: ./downloads/41761.txt
# Processo il documento 41762...
# Documento 41762 salvato in: ./downloads/41762.txt
# Processo il documento 41763...
# Documento 41763 salvato in: ./downloads/41763.txt
# Processo il documento 41764...
# Documento 41764 salvato in: ./downloads/41764.txt
# Processo il documento 41765...
# Documento 41765 salvato in: ./downloads/41765.txt
# Processo il documento 41766...
# Documento 41766 salvato in: ./downloads/41766.txt
# Processo il documento 41767...
# Documento 41767 salvato in: ./downloads/41767.txt
# Processo il documento 41768...
# Documento 41768 salvato in: ./downloads/41768.txt
# Processo il documento 41769...
# Documento 41769 salvato in: ./downloads/41769.txt
# Processo il documento 41770...
# Documento 41770 salvato in: ./downloads/41770.txt
# Processo il documento 41771...
# Documento 41771 salvato in: ./downloads/41771.txt
# Processo il documento 41772...
# Documento 41772 salvato in: ./downloads/41772.txt
# Processo il documento 41773...
# Documento 41773 salvato in: ./downloads/41773.txt
# Processo il documento 41774...
# Documento 41774 salvato in: ./downloads/41774.txt
# Processo il documento 41775...
# Documento 41775 salvato in: ./downloads/41775.txt
# Processo il documento 41776...
# Documento 41776 salvato in: ./downloads/41776.txt
# Processo il documento 41777...
# Documento 41777 salvato in: ./downloads/41777.txt
# Processo il documento 41778...
# Documento 41778 salvato in: ./downloads/41778.txt
# Processo il documento 41779...
# Documento 41779 salvato in: ./downloads/41779.txt
# Processo il documento 41780...
# Documento 41780 salvato in: ./downloads/41780.txt
# Processo il documento 41781...
# Documento 41781 salvato in: ./downloads/41781.txt
# Processo il documento 41782...
# Documento 41782 salvato in: ./downloads/41782.txt
# Processo il documento 41783...
# Documento 41783 salvato in: ./downloads/41783.txt
# Processo il documento 41784...
# Documento 41784 non trovato (HTTP 404).
# Processo il documento 41785...
# Documento 41785 non trovato (HTTP 404).
# Processo il documento 41786...
# Documento 41786 non trovato (HTTP 404).
# Processo il documento 41787...
# Documento 41787 non trovato (HTTP 404).
# Processo il documento 41788...
# Documento 41788 non trovato (HTTP 404).
# Processo il documento 41789...
# Documento 41789 non trovato (HTTP 404).
# Processo il documento 41790...
# Documento 41790 non trovato (HTTP 404).
# Processo il documento 41791...
# Documento 41791 non trovato (HTTP 404).
# Processo il documento 41792...
# Documento 41792 non trovato (HTTP 404).
# Processo il documento 41793...
# Documento 41793 non trovato (HTTP 404).
# Processo il documento 41794...
# Documento 41794 non trovato (HTTP 404).
# Processo il documento 41795...
# Documento 41795 non trovato (HTTP 404).
# Processo il documento 41796...
# Documento 41796 non trovato (HTTP 404).
# Processo il documento 41797...
# Documento 41797 non trovato (HTTP 404).
# Processo il documento 41798...
# Documento 41798 non trovato (HTTP 404).
# Processo il documento 41799...
# Documento 41799 non trovato (HTTP 404).
# Processo il documento 41800...
# Documento 41800 non trovato (HTTP 404).
# Processo il documento 41801...
# Documento 41801 salvato in: ./downloads/41801.txt
# Processo il documento 41802...
# Documento 41802 non trovato (HTTP 404).
# Processo il documento 41803...
# Documento 41803 non trovato (HTTP 404).
# Processo il documento 41804...
# Documento 41804 non trovato (HTTP 404).
# Processo il documento 41805...
# Documento 41805 non trovato (HTTP 404).
# Processo il documento 41806...
# Documento 41806 non trovato (HTTP 404).
# Processo il documento 41807...
# Documento 41807 non trovato (HTTP 404).
# Processo il documento 41808...
# Documento 41808 non trovato (HTTP 404).
# Processo il documento 41809...
# Documento 41809 non trovato (HTTP 404).
# Processo il documento 41810...
# Documento 41810 non trovato (HTTP 404).
# Processo il documento 41811...
# Documento 41811 non trovato (HTTP 404).
# Processo il documento 41812...
# Documento 41812 non trovato (HTTP 404).
# Processo il documento 41813...
# Documento 41813 non trovato (HTTP 404).
# Processo il documento 41814...
# Documento 41814 non trovato (HTTP 404).
# Processo il documento 41815...
# Documento 41815 non trovato (HTTP 404).
# Processo il documento 41816...
# Documento 41816 non trovato (HTTP 404).
# Processo il documento 41817...
# Documento 41817 non trovato (HTTP 404).
# Processo il documento 41818...
# Documento 41818 non trovato (HTTP 404).
# Processo il documento 41819...
# Documento 41819 non trovato (HTTP 404).
# Processo il documento 41820...
# Documento 41820 non trovato (HTTP 404).
# Processo il documento 41821...
# Documento 41821 salvato in: ./downloads/41821.txt
# Processo il documento 41822...
# Documento 41822 salvato in: ./downloads/41822.txt
# Processo il documento 41823...
# Documento 41823 salvato in: ./downloads/41823.txt
# Processo il documento 41824...
# Documento 41824 salvato in: ./downloads/41824.txt
# Processo il documento 41825...
# Documento 41825 salvato in: ./downloads/41825.txt
# Processo il documento 41826...
# Documento 41826 salvato in: ./downloads/41826.txt
# Processo il documento 41827...
# Documento 41827 salvato in: ./downloads/41827.txt
# Processo il documento 41828...
# Documento 41828 salvato in: ./downloads/41828.txt
# Processo il documento 41829...
# Documento 41829 salvato in: ./downloads/41829.txt
# Processo il documento 41830...
# Documento 41830 salvato in: ./downloads/41830.txt
# Processo il documento 41831...
# Documento 41831 salvato in: ./downloads/41831.txt
# Processo il documento 41832...
# Documento 41832 salvato in: ./downloads/41832.txt
# Processo il documento 41833...
# Documento 41833 salvato in: ./downloads/41833.txt
# Processo il documento 41834...
# Documento 41834 salvato in: ./downloads/41834.txt
# Processo il documento 41835...
# Documento 41835 salvato in: ./downloads/41835.txt
# Processo il documento 41836...
# Documento 41836 salvato in: ./downloads/41836.txt
# Processo il documento 41837...
# Documento 41837 salvato in: ./downloads/41837.txt
# Processo il documento 41838...
# Documento 41838 salvato in: ./downloads/41838.txt
# Processo il documento 41839...
# Documento 41839 salvato in: ./downloads/41839.txt
# Processo il documento 41840...
# Documento 41840 salvato in: ./downloads/41840.txt
# Processo il documento 41841...
# Documento 41841 salvato in: ./downloads/41841.txt
# Processo il documento 41842...
# Documento 41842 salvato in: ./downloads/41842.txt
# Processo il documento 41843...
# Documento 41843 salvato in: ./downloads/41843.txt
# Processo il documento 41844...
# Documento 41844 salvato in: ./downloads/41844.txt
# Processo il documento 41845...
# Documento 41845 salvato in: ./downloads/41845.txt
# Processo il documento 41846...
# Documento 41846 salvato in: ./downloads/41846.txt
# Processo il documento 41847...
# Documento 41847 salvato in: ./downloads/41847.txt
# Processo il documento 41848...
# Documento 41848 salvato in: ./downloads/41848.txt
# Processo il documento 41849...
# Documento 41849 salvato in: ./downloads/41849.txt
# Processo il documento 41850...
# Documento 41850 salvato in: ./downloads/41850.txt
# Processo il documento 41851...
# Documento 41851 salvato in: ./downloads/41851.txt
# Processo il documento 41852...
# Documento 41852 salvato in: ./downloads/41852.txt
# Processo il documento 41853...
# Documento 41853 salvato in: ./downloads/41853.txt
# Processo il documento 41854...
# Documento 41854 salvato in: ./downloads/41854.txt
# Processo il documento 41855...
# Documento 41855 salvato in: ./downloads/41855.txt
# Processo il documento 41856...
# Documento 41856 salvato in: ./downloads/41856.txt
# Processo il documento 41857...
# Documento 41857 salvato in: ./downloads/41857.txt
# Processo il documento 41858...
# Documento 41858 salvato in: ./downloads/41858.txt
# Processo il documento 41859...
# Documento 41859 salvato in: ./downloads/41859.txt
# Processo il documento 41860...
# Documento 41860 salvato in: ./downloads/41860.txt
# Processo il documento 41861...
# Documento 41861 salvato in: ./downloads/41861.txt
# Processo il documento 41862...
# Documento 41862 salvato in: ./downloads/41862.txt
# Processo il documento 41863...
# Documento 41863 salvato in: ./downloads/41863.txt
# Processo il documento 41864...
# Documento 41864 salvato in: ./downloads/41864.txt
# Processo il documento 41865...
# Documento 41865 salvato in: ./downloads/41865.txt
# Processo il documento 41866...
# Documento 41866 salvato in: ./downloads/41866.txt
# Processo il documento 41867...
# Documento 41867 salvato in: ./downloads/41867.txt
# Processo il documento 41868...
# Documento 41868 non trovato (HTTP 404).
# Processo il documento 41869...
# Documento 41869 non trovato (HTTP 404).
# Processo il documento 41870...
# Documento 41870 non trovato (HTTP 404).
# Processo il documento 41871...
# Documento 41871 non trovato (HTTP 404).
# Processo il documento 41872...
# Documento 41872 non trovato (HTTP 404).
# Processo il documento 41873...
# Documento 41873 non trovato (HTTP 404).
# Processo il documento 41874...
# Documento 41874 non trovato (HTTP 404).
# Processo il documento 41875...
# Documento 41875 non trovato (HTTP 404).
# Processo il documento 41876...
# Documento 41876 non trovato (HTTP 404).
# Processo il documento 41877...
# Documento 41877 non trovato (HTTP 404).
# Processo il documento 41878...
# Documento 41878 non trovato (HTTP 404).
# Processo il documento 41879...
# Documento 41879 non trovato (HTTP 404).
# Processo il documento 41880...
# Documento 41880 non trovato (HTTP 404).
# Processo il documento 41881...
# Documento 41881 salvato in: ./downloads/41881.txt
# Processo il documento 41882...
# Documento 41882 salvato in: ./downloads/41882.txt
# Processo il documento 41883...
# Documento 41883 salvato in: ./downloads/41883.txt
# Processo il documento 41884...
# Documento 41884 salvato in: ./downloads/41884.txt
# Processo il documento 41885...
# Documento 41885 salvato in: ./downloads/41885.txt
# Processo il documento 41886...
# Documento 41886 salvato in: ./downloads/41886.txt
# Processo il documento 41887...
# Documento 41887 salvato in: ./downloads/41887.txt
# Processo il documento 41888...
# Documento 41888 salvato in: ./downloads/41888.txt
# Processo il documento 41889...
# Documento 41889 salvato in: ./downloads/41889.txt
# Processo il documento 41890...
# Documento 41931 salvato in: ./downloads/41931.txt
# Processo il documento 41932...
# Documento 41932 salvato in: ./downloads/41932.txt
# Processo il documento 41933...
# Documento 41933 salvato in: ./downloads/41933.txt
# Processo il documento 41934...
# Documento 41934 salvato in: ./downloads/41934.txt
# Processo il documento 41935...
# Documento 41935 salvato in: ./downloads/41935.txt
# Processo il documento 41936...
# Documento 41936 salvato in: ./downloads/41936.txt
# Processo il documento 41937...
# Documento 41937 salvato in: ./downloads/41937.txt
# Processo il documento 41938...
# Documento 41938 salvato in: ./downloads/41938.txt
# Processo il documento 41939...
# Documento 41939 salvato in: ./downloads/41939.txt
# Processo il documento 41940...
# Documento 41940 salvato in: ./downloads/41940.txt
# Processo il documento 41941...
# Documento 41941 salvato in: ./downloads/41941.txt
# Processo il documento 41942...
# Documento 41942 salvato in: ./downloads/41942.txt
# Processo il documento 41943...
# Documento 41943 salvato in: ./downloads/41943.txt
# Processo il documento 41944...
# Documento 41944 salvato in: ./downloads/41944.txt
# Processo il documento 41945...
# Documento 41945 salvato in: ./downloads/41945.txt
# Processo il documento 41946...
# Documento 41946 salvato in: ./downloads/41946.txt
# Processo il documento 41947...
# Documento 41947 salvato in: ./downloads/41947.txt
# Processo il documento 41948...
# Documento 41948 salvato in: ./downloads/41948.txt
# Processo il documento 41949...
# Documento 41949 non trovato (HTTP 404).
# Processo il documento 41950...
# Documento 41950 non trovato (HTTP 404).
# Processo il documento 41951...
# Documento 41951 non trovato (HTTP 404).
# Processo il documento 41952...
# Documento 41952 non trovato (HTTP 404).
# Processo il documento 41953...
# Documento 41953 non trovato (HTTP 404).
# Processo il documento 41954...
# Documento 41954 non trovato (HTTP 404).
# Processo il documento 41955...
# Documento 41955 non trovato (HTTP 404).
# Processo il documento 41956...
# Documento 41956 non trovato (HTTP 404).
# Processo il documento 41957...
# Documento 41957 non trovato (HTTP 404).
# Processo il documento 41958...
# Documento 41958 non trovato (HTTP 404).
# Processo il documento 41959...
# Documento 41959 non trovato (HTTP 404).
# Processo il documento 41960...
# Documento 41960 non trovato (HTTP 404).
# Processo il documento 41961...
# Documento 41961 non trovato (HTTP 404).
# Processo il documento 41962...
# Documento 41962 non trovato (HTTP 404).
# Processo il documento 41963...
# Documento 41963 non trovato (HTTP 404).
# Processo il documento 41964...
# Documento 41964 non trovato (HTTP 404).
# Processo il documento 41965...
# Documento 41965 non trovato (HTTP 404).
# Processo il documento 41966...
# Documento 41966 non trovato (HTTP 404).
# Processo il documento 41967...
# Documento 41967 non trovato (HTTP 404).
# Processo il documento 41968...
# Documento 41968 non trovato (HTTP 404).
# Processo il documento 41969...
# Documento 41969 non trovato (HTTP 404).
# Processo il documento 41970...
# Documento 41970 non trovato (HTTP 404).
# Processo il documento 41971...
# Documento 41971 non trovato (HTTP 404).
# Processo il documento 41972...
# Documento 41972 non trovato (HTTP 404).
# Processo il documento 41973...
# Documento 41973 non trovato (HTTP 404).
# Processo il documento 41974...
# Documento 41974 non trovato (HTTP 404).
# Processo il documento 41975...
# Documento 41975 non trovato (HTTP 404).
# Processo il documento 41976...
# Documento 41976 non trovato (HTTP 404).
# Processo il documento 41977...
# ...
# Processo il documento 42211...
# Documento 42211 non trovato (HTTP 404).
# Processo il documento 42212...
# Documento 42212 non trovato (HTTP 404).
# Processo il documento 42213...
# Documento 42213 non trovato (HTTP 404).
# Processo il documento 42214...
# Documento 42214 non trovato (HTTP 404).
# Processo il documento 42215...
# Documento 42215 non trovato (HTTP 404).
# Processo il documento 42216...
# Documento 42216 non trovato (HTTP 404).
# Processo il documento 42217...
# Documento 42217 non trovato (HTTP 404).
# Processo il documento 42218...
# Documento 42218 non trovato (HTTP 404).
# Processo il documento 42219...
# Documento 42219 non trovato (HTTP 404).
# Processo il documento 42220...
# Documento 42220 non trovato (HTTP 404).
# Processo il documento 42221...
# Documento 42221 salvato in: ./downloads/42221.txt
# Processo il documento 42222...
# Documento 42222 salvato in: ./downloads/42222.txt
# Processo il documento 42223...
# Documento 42223 salvato in: ./downloads/42223.txt
# Processo il documento 42224...
# Documento 42224 salvato in: ./downloads/42224.txt
# Processo il documento 42225...
# Documento 42225 salvato in: ./downloads/42225.txt
# Processo il documento 42226...
# Documento 42226 salvato in: ./downloads/42226.txt
# Processo il documento 42227...
# Documento 42227 salvato in: ./downloads/42227.txt
# Processo il documento 42228...
# Documento 42228 salvato in: ./downloads/42228.txt
# Processo il documento 42229...
# Documento 42229 salvato in: ./downloads/42229.txt
# Processo il documento 42230...
# Documento 42230 salvato in: ./downloads/42230.txt
# Processo il documento 42231...
# Documento 42231 salvato in: ./downloads/42231.txt
# Processo il documento 42232...
# Documento 42232 salvato in: ./downloads/42232.txt
# Processo il documento 42233...
# Documento 42233 salvato in: ./downloads/42233.txt
# Processo il documento 42234...
# Documento 42234 salvato in: ./downloads/42234.txt
# Processo il documento 42235...
# Documento 42235 salvato in: ./downloads/42235.txt
# Processo il documento 42236...
# Documento 42236 salvato in: ./downloads/42236.txt
# Processo il documento 42237...
# Documento 42237 salvato in: ./downloads/42237.txt
# Processo il documento 42238...
# Documento 42238 salvato in: ./downloads/42238.txt
# Processo il documento 42239...
# Documento 42239 salvato in: ./downloads/42239.txt
# Processo il documento 42240...
# Documento 42240 non trovato (HTTP 404).
# Processo il documento 42241...
# Documento 42241 salvato in: ./downloads/42241.txt
# Processo il documento 42242...
# Documento 42242 salvato in: ./downloads/42242.txt
# Processo il documento 42243...
# Documento 42243 salvato in: ./downloads/42243.txt
# Processo il documento 42244...
# Documento 42244 salvato in: ./downloads/42244.txt
# Processo il documento 42245...
# Documento 42245 salvato in: ./downloads/42245.txt
# Processo il documento 42246...
# Documento 42246 salvato in: ./downloads/42246.txt
# Processo il documento 42247...
# Documento 42247 salvato in: ./downloads/42247.txt
# Processo il documento 42248...
# Documento 42248 salvato in: ./downloads/42248.txt
# Processo il documento 42249...
# Documento 42249 salvato in: ./downloads/42249.txt
# Processo il documento 42250...
# Documento 42250 salvato in: ./downloads/42250.txt
# Processo il documento 42251...
# Documento 42251 salvato in: ./downloads/42251.txt
# Processo il documento 42252...
# Documento 42252 salvato in: ./downloads/42252.txt
# Processo il documento 42253...
# Documento 42253 salvato in: ./downloads/42253.txt
# Processo il documento 42254...
# Documento 42254 salvato in: ./downloads/42254.txt
# Processo il documento 42255...
# Documento 42255 salvato in: ./downloads/42255.txt
# Processo il documento 42256...
# Documento 42256 salvato in: ./downloads/42256.txt
# Processo il documento 42257...
# Documento 42257 salvato in: ./downloads/42257.txt
# Processo il documento 42258...
# Documento 42258 salvato in: ./downloads/42258.txt
# Processo il documento 42259...
# Documento 42259 non trovato (HTTP 404).
# Processo il documento 42260...
# Documento 42260 non trovato (HTTP 404).
# Processo il documento 42261...
# Documento 42261 salvato in: ./downloads/42261.txt
# Processo il documento 42262...
# Documento 42262 salvato in: ./downloads/42262.txt
# Processo il documento 42263...
# Documento 42263 salvato in: ./downloads/42263.txt
# Processo il documento 42264...
# Documento 42264 salvato in: ./downloads/42264.txt
# Processo il documento 42265...
# Documento 42265 salvato in: ./downloads/42265.txt
# Processo il documento 42266...
# Documento 42266 non trovato (HTTP 404).
# Processo il documento 42267...
# Documento 42267 non trovato (HTTP 404).
# Processo il documento 42268...
# Documento 42268 non trovato (HTTP 404).
# Processo il documento 42269...
# Documento 42269 non trovato (HTTP 404).
# Processo il documento 42270...
# Documento 42270 non trovato (HTTP 404).
# Processo il documento 42271...
# Documento 42271 non trovato (HTTP 404).
# Processo il documento 42272...
# Documento 42272 non trovato (HTTP 404).
# Processo il documento 42273...
# Documento 42273 non trovato (HTTP 404).
# Processo il documento 42274...
# Documento 42274 non trovato (HTTP 404).
# Processo il documento 42275...
# Documento 42275 non trovato (HTTP 404).
# Processo il documento 42276...
# Documento 42276 non trovato (HTTP 404).
# Processo il documento 42277...
# Documento 42277 non trovato (HTTP 404).
# Processo il documento 42278...
# Documento 42278 non trovato (HTTP 404).
# Processo il documento 42279...
# Documento 42279 non trovato (HTTP 404).
# Processo il documento 42280...
# Documento 42280 non trovato (HTTP 404).
# Processo il documento 42281...
# Documento 42281 salvato in: ./downloads/42281.txt
# Processo il documento 42282...
# Documento 42282 salvato in: ./downloads/42282.txt
# Processo il documento 42283...
# Documento 42283 salvato in: ./downloads/42283.txt
# Processo il documento 42284...
# Documento 42284 non trovato (HTTP 404).
# Processo il documento 42285...
# Documento 42285 non trovato (HTTP 404).
# Processo il documento 42286...
# Documento 42286 non trovato (HTTP 404).
# Processo il documento 42287...
# Documento 42287 non trovato (HTTP 404).
# Processo il documento 42288...
# Documento 42288 non trovato (HTTP 404).
# Processo il documento 42289...
# Documento 42289 non trovato (HTTP 404).
# Processo il documento 42290...
# Documento 42290 non trovato (HTTP 404).
# Processo il documento 42291...
# Documento 42291 non trovato (HTTP 404).
# Processo il documento 42292...
# Documento 42292 non trovato (HTTP 404).
# Processo il documento 42293...
# Documento 42293 non trovato (HTTP 404).
# Processo il documento 42294...
# Documento 42294 non trovato (HTTP 404).
# Processo il documento 42295...
# Documento 42295 non trovato (HTTP 404).
# Processo il documento 42296...
# Documento 42296 non trovato (HTTP 404).
# Processo il documento 42297...
# Documento 42297 non trovato (HTTP 404).
# Processo il documento 42298...
# Documento 42298 non trovato (HTTP 404).
# Processo il documento 42299...
# Documento 42299 non trovato (HTTP 404).
# Processo il documento 42300...
# Documento 42300 non trovato (HTTP 404).
# Processo il documento 42301...
# Documento 42301 salvato in: ./downloads/42301.txt
# Processo il documento 42302...
# Documento 42302 salvato in: ./downloads/42302.txt
# Processo il documento 42303...
# Documento 42303 salvato in: ./downloads/42303.txt
# Processo il documento 42304...
# Documento 42304 salvato in: ./downloads/42304.txt
# Processo il documento 42305...
# Documento 42305 salvato in: ./downloads/42305.txt
# Processo il documento 42306...
# Documento 42306 salvato in: ./downloads/42306.txt
# Processo il documento 42307...
# Documento 42307 salvato in: ./downloads/42307.txt
# Processo il documento 42308...
# Documento 42308 salvato in: ./downloads/42308.txt
# Processo il documento 42309...
# Documento 42309 salvato in: ./downloads/42309.txt
# Processo il documento 42310...
# Documento 42310 salvato in: ./downloads/42310.txt
# Processo il documento 42311...
# Documento 42311 salvato in: ./downloads/42311.txt
# Processo il documento 42312...
# Documento 42312 salvato in: ./downloads/42312.txt
# Processo il documento 42313...
# Documento 42313 salvato in: ./downloads/42313.txt
# Processo il documento 42314...
# Documento 42314 salvato in: ./downloads/42314.txt
# Processo il documento 42315...
# Documento 42315 non trovato (HTTP 404).
# Processo il documento 42316...
# Documento 42316 non trovato (HTTP 404).
# Processo il documento 42317...
# Documento 42317 non trovato (HTTP 404).
# Processo il documento 42318...
# Documento 42318 non trovato (HTTP 404).
# Processo il documento 42319...
# Documento 42319 non trovato (HTTP 404).
# Processo il documento 42320...
# Documento 42320 non trovato (HTTP 404).
# Processo il documento 42321...
# Documento 42321 salvato in: ./downloads/42321.txt
# Processo il documento 42322...
# Documento 42322 salvato in: ./downloads/42322.txt
# Processo il documento 42323...
# Documento 42323 non trovato (HTTP 404).
# Processo il documento 42324...
# Documento 42324 non trovato (HTTP 404).
# Processo il documento 42325...
# Documento 42325 non trovato (HTTP 404).
# Processo il documento 42326...
# Documento 42326 non trovato (HTTP 404).
# Processo il documento 42327...
# Documento 42327 non trovato (HTTP 404).
# Processo il documento 42328...
# Documento 42328 non trovato (HTTP 404).
# Processo il documento 42329...
# Documento 42329 non trovato (HTTP 404).
# Processo il documento 42330...
# Documento 42330 non trovato (HTTP 404).
# Processo il documento 42331...
# Documento 42331 non trovato (HTTP 404).
# Processo il documento 42332...
# Documento 42332 non trovato (HTTP 404).
# Processo il documento 42333...
# Documento 42333 non trovato (HTTP 404).
# Processo il documento 42334...
# Documento 42334 non trovato (HTTP 404).
# Processo il documento 42335...
# Documento 42335 non trovato (HTTP 404).
# Processo il documento 42336...
# Documento 42336 non trovato (HTTP 404).
# Processo il documento 42337...
# Documento 42337 non trovato (HTTP 404).
# Processo il documento 42338...
# Documento 42338 non trovato (HTTP 404).
# Processo il documento 42339...
# Documento 42339 non trovato (HTTP 404).
# Processo il documento 42340...
# Documento 42340 non trovato (HTTP 404).
# Processo il documento 42341...
# Documento 42341 salvato in: ./downloads/42341.txt
# Processo il documento 42342...
# Documento 42342 non trovato (HTTP 404).
# Processo il documento 42343...
# Documento 42343 non trovato (HTTP 404).
# Processo il documento 42344...
# Documento 42344 non trovato (HTTP 404).
# Processo il documento 42345...
# Documento 42345 non trovato (HTTP 404).
# Processo il documento 42346...
# Documento 42346 non trovato (HTTP 404).
# Processo il documento 42347...
# Documento 42347 non trovato (HTTP 404).
# Processo il documento 42348...
# Documento 42348 non trovato (HTTP 404).
# Processo il documento 42349...
# Documento 42349 non trovato (HTTP 404).
# Processo il documento 42350...
# Documento 42350 non trovato (HTTP 404).
# Processo il documento 42351...
# Documento 42351 non trovato (HTTP 404).
# Processo il documento 42352...
# Documento 42352 non trovato (HTTP 404).
# Processo il documento 42353...
# Documento 42353 non trovato (HTTP 404).
# Processo il documento 42354...
# Documento 42354 non trovato (HTTP 404).
# Processo il documento 42355...
# Documento 42355 non trovato (HTTP 404).
# Processo il documento 42356...
# Documento 42356 non trovato (HTTP 404).
# Processo il documento 42357...
# Documento 42357 non trovato (HTTP 404).
# Processo il documento 42358...
# Documento 42358 non trovato (HTTP 404).
# Processo il documento 42359...
# Documento 42359 non trovato (HTTP 404).
# Processo il documento 42360...
# Documento 42360 non trovato (HTTP 404).
# Processo il documento 42361...
# Documento 42361 salvato in: ./downloads/42361.txt
# Processo il documento 42362...
# Documento 42362 salvato in: ./downloads/42362.txt
# Processo il documento 42363...
# Documento 42363 salvato in: ./downloads/42363.txt
# Processo il documento 42364...
# Documento 42364 salvato in: ./downloads/42364.txt
# Processo il documento 42365...
# Documento 42365 salvato in: ./downloads/42365.txt
# Processo il documento 42366...
# Documento 42366 salvato in: ./downloads/42366.txt
# Processo il documento 42367...
# Documento 42367 salvato in: ./downloads/42367.txt
# Processo il documento 42368...
# Documento 42368 salvato in: ./downloads/42368.txt
# Processo il documento 42369...
# Documento 42369 salvato in: ./downloads/42369.txt
# Processo il documento 42370...
# Documento 42370 salvato in: ./downloads/42370.txt
# Processo il documento 42371...
# Documento 42371 salvato in: ./downloads/42371.txt
# Processo il documento 42372...
# Documento 42372 salvato in: ./downloads/42372.txt
# Processo il documento 42373...
# Documento 42373 salvato in: ./downloads/42373.txt
# Processo il documento 42374...
# Documento 42374 salvato in: ./downloads/42374.txt
# Processo il documento 42375...
# Documento 42375 salvato in: ./downloads/42375.txt
# Processo il documento 42376...
# Documento 42376 salvato in: ./downloads/42376.txt
# Processo il documento 42377...
# Documento 42377 salvato in: ./downloads/42377.txt
# Processo il documento 42378...
# Documento 42378 salvato in: ./downloads/42378.txt
# Processo il documento 42379...
# Documento 42379 salvato in: ./downloads/42379.txt
# Processo il documento 42380...
# Documento 42380 salvato in: ./downloads/42380.txt
# Processo il documento 42381...
# Documento 42381 salvato in: ./downloads/42381.txt
# Processo il documento 42382...
# Documento 42382 salvato in: ./downloads/42382.txt
# Processo il documento 42383...
# Documento 42383 non trovato (HTTP 404).
# Processo il documento 42384...
# Documento 42384 non trovato (HTTP 404).
# Processo il documento 42385...
# Documento 42385 non trovato (HTTP 404).
# Processo il documento 42386...
# Documento 42386 non trovato (HTTP 404).
# Processo il documento 42387...
# Documento 42387 non trovato (HTTP 404).
# Processo il documento 42388...
# Documento 42388 non trovato (HTTP 404).
# Processo il documento 42389...
# Documento 42389 non trovato (HTTP 404).
# Processo il documento 42390...
# Documento 42390 non trovato (HTTP 404).
# Processo il documento 42391...
# Documento 42391 non trovato (HTTP 404).
# Processo il documento 42392...
# Documento 42392 non trovato (HTTP 404).
# Processo il documento 42393...
# Documento 42393 non trovato (HTTP 404).
# Processo il documento 42394...
# Documento 42394 non trovato (HTTP 404).
# Processo il documento 42395...
# Documento 42395 non trovato (HTTP 404).
# Processo il documento 42396...
# Documento 42396 non trovato (HTTP 404).
# Processo il documento 42397...
# Documento 42397 non trovato (HTTP 404).
# Processo il documento 42398...
# Documento 42398 non trovato (HTTP 404).
# Processo il documento 42399...
# Documento 42399 non trovato (HTTP 404).
# Processo il documento 42400...
# Documento 42400 non trovato (HTTP 404).
# Processo il documento 42401...
# Documento 42401 salvato in: ./downloads/42401.txt
# Processo il documento 42402...
# Documento 42402 salvato in: ./downloads/42402.txt
# Processo il documento 42403...
# Documento 42403 non trovato (HTTP 404).
# Processo il documento 42404...
# Documento 42404 non trovato (HTTP 404).
# Processo il documento 42405...
# Documento 42405 non trovato (HTTP 404).
# Processo il documento 42406...
# Documento 42406 non trovato (HTTP 404).
# Processo il documento 42407...
# Documento 42407 non trovato (HTTP 404).
# Processo il documento 42408...
# Documento 42408 non trovato (HTTP 404).
# Processo il documento 42409...
# Documento 42409 non trovato (HTTP 404).
# Processo il documento 42410...
# Documento 42410 non trovato (HTTP 404).
# Processo il documento 42411...
# Documento 42411 non trovato (HTTP 404).
# Processo il documento 42412...
# Documento 42412 non trovato (HTTP 404).
# Processo il documento 42413...
# Documento 42413 non trovato (HTTP 404).
# Processo il documento 42414...
# Documento 42414 non trovato (HTTP 404).
# Processo il documento 42415...
# Documento 42415 non trovato (HTTP 404).
# Processo il documento 42416...
# Documento 42416 non trovato (HTTP 404).
# Processo il documento 42417...
# Documento 42417 non trovato (HTTP 404).
# Processo il documento 42418...
# Documento 42418 non trovato (HTTP 404).
# Processo il documento 42419...
# Documento 42419 non trovato (HTTP 404).
# Processo il documento 42420...
# Documento 42420 non trovato (HTTP 404).
# Processo il documento 42421...
# Documento 42421 salvato in: ./downloads/42421.txt
# Salvataggio dei risultati nel file CSV: csv_paths.csv
# Completato! Tutti i documenti salvati nella cartella: ./downloads

# %%
def generate_csv_from_folder(folder_path, csv_file="csv_paths.csv"):
    csv_data = []
    
    # Verifica che la cartella esista
    if not os.path.exists(folder_path):
        print(f"La cartella {folder_path} non esiste.")
        return
    
    # Scansiona la cartella per trovare i file
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        
        if os.path.isfile(file_path):  # Assicuriamoci che sia un file e non una cartella
            file_id, _ = os.path.splitext(file_name)  # Rimuove l'estensione
            csv_data.append({"ID_file": file_id, "path_src": file_path})
    
    # Salvataggio dei dati in un file CSV
    with open(csv_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["ID_file", "path_src"])
        writer.writeheader()
        writer.writerows(csv_data)
    
    print(f"File CSV creato con successo: {csv_file}")

# Esempio di utilizzo
folder_path = "./downloads"  # Modifica con il percorso della tua cartella
generate_csv_from_folder(folder_path)
# Out:
# File CSV creato con successo: csv_paths.csv

# %%
#funzione per pulire i file txt dalle parti inutili presenti nella pagina web del consiglio Valle
def first_clean(target_folder, keyword, mid_strings, end_keyword, csv_paths):
    df = pd.read_csv(csv_paths)

    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    df["path_clean"] = ""

    for idx, row in df.iterrows():
        source_path = row["path_src"]
        if source_path.endswith(".txt"):
            filename = os.path.basename(source_path)
            target_path = os.path.join(target_folder, filename)

            df.at[idx, "path_clean"] = target_path

            with open(source_path, "r", encoding="utf-8") as file:
                content = file.read()

            if keyword in content:
                content = keyword + content.split(keyword, 1)[1] 

            for mid_string in mid_strings:
                content = re.sub(re.escape(mid_string), "", content) 

            if end_keyword in content:
                content = content.split(end_keyword, 1)[0]  

            with open(target_path, "w", encoding="utf-8") as file:
                file.write(content)

    df.to_csv(csv_paths, index=False)

#funzione per estrarre informazioni dai file txt: oggetto, legislatura, data e classificazione
def extract_and_format_date(text):
    
    date_pattern = re.search(r"(\d{1,2})\s+([a-zA-Z]+)\s+(\d{4})", text)
    
    if date_pattern:
        day, month_name, year = date_pattern.groups()
        
        months = {
            "gennaio": "01", "febbraio": "02", "marzo": "03", "aprile": "04", "maggio": "05", "giugno": "06",
            "luglio": "07", "agosto": "08", "settembre": "09", "ottobre": "10", "novembre": "11", "dicembre": "12"
        }
        
        month = months.get(month_name.lower())
        
        if month:
            return f"{int(day):02d}/{month}/{year}"
    
    return None

def first_info(pattern1, pattern2, csv_paths):
    df_paths = pd.read_csv(csv_paths)

    #df_paths['language'] = ""
    df_paths['object'] = ""
    df_paths['legislature'] = ""
    df_paths['date'] = ""
    df_paths['month'] = ""
    df_paths['class'] = ""

    for idx, row in df_paths.iterrows():
        source_path = row["path_clean"]
        if source_path.endswith(".txt"):
            filename = os.path.basename(source_path)
            filenum = int(os.path.splitext(filename)[0])

            with open(source_path, "r", encoding="utf-8") as file:
                content = file.read()

            match1 = re.search(pattern1, content)

            if match1:
                stringa = match1.group(1).strip()
                ogg, leg = stringa.split("/", 1)

                df_paths.loc[df_paths['ID_file'] == filenum, 'object'] = ogg
                df_paths.loc[df_paths['ID_file'] == filenum, 'legislature'] = leg

            date = extract_and_format_date(content)
            df_paths.loc[df_paths['ID_file'] == filenum, 'date'] = date
            if date:
                df_paths.loc[df_paths['ID_file'] == filenum, 'month'] = date.split("/")[1]
            
            match2 = re.search(pattern2, content, re.DOTALL)
            
            if match2:
                classe = match2.group(1).strip()
                classe = classe.replace("\n", ", ").strip()
                df_paths.loc[df_paths['ID_file'] == filenum, 'class'] = classe

            #try:
            #    lang = detect(content)
            #    if lang == 'fr':
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'fr'
            #    elif lang == 'it':
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'it'
            #    else:
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'other'
            #except:
            #    df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'error'

    df_paths.to_csv(csv_paths, index=False)

def second_info(csv_paths):
    df = pd.read_csv(csv_paths)
    
    if "obj_pos" not in df.columns:
        df["obj_pos"] = 0
    
    df["object"] = pd.to_numeric(df["object"], errors="coerce")  # Converti in numero per ordinamento
    
    df.sort_values(by=["date", "object"], ascending=[True, True], inplace=True)
    
    df["obj_pos"] = df.groupby("date").cumcount() + 1  # Assegna numeri progressivi
    
    df.to_csv(csv_paths, index=False)

# %%
target_folder = "./clean"

csv_paths = "./csv_paths.csv"
csv_details = "./csv_details.csv"
csv_cons = "./csv_cons.csv"
csv_chunks = "./csv_chunks.csv"

# %%
keyword = "Classificazione"
mid_strings = ["Precedente", "Successivo", "Resoconto integrale del dibattito dell'aula. I documenti allegati sono reperibili nel link \"iter atto\"."]
end_keyword = "Informativa cookies"

first_clean(target_folder, keyword, mid_strings, end_keyword, csv_paths)

pattern1 = r'(?:OGGETTO N\.|OBJET N°)(.*?)\s*-'
pattern2 = r'Classificazione\s*(.*?)\s*Oggetto'

first_info(pattern1, pattern2, csv_paths)
second_info(csv_paths)

# %%
import pandas as pd
import re

def define_names(csv_cons, leg):
    df_cons = pd.read_csv(csv_cons)
    df_cons = df_cons.reset_index()  # Aggiunge l'indice come colonna ID_cons
    df_cons.rename(columns={'index': 'ID_cons'}, inplace=True)
    names = []
    
    print(f"Filtrando per legislatura: {leg}")
    filtered_cons = df_cons[df_cons['legislature'].str.contains(leg, case=False, na=False)]
    
    surname_counts = filtered_cons['surname'].value_counts()

    for idx, row in filtered_cons.iterrows():
        surname = row["surname"]
        name = row["name"]
        
        if surname_counts[surname] > 1:
            names.append(f"{surname} {name[0]}.")
        else:
            names.append(surname)
    
    print(f"Numero di nomi trovati per la legislatura {leg}: {len(names)}")
    return filtered_cons, names

def isolate_chunk(csv_paths, csv_cons):
    df_paths = pd.read_csv(csv_paths)
    chunk_list = []

    for idx, row in df_paths.iterrows():
        leg = row["legislature"]
        date = row["date"]
        month = row["month"]
        #language = row["language"]
        obj = row["obj_pos"]
        
        print(f"Processando file {row['path_clean']} per la legislatura {leg}...")
        
        try:
            df_cons, list_cons = define_names(csv_cons, leg)

            with open(row["path_clean"], 'r') as f:
                text = f.read()

                all_matches = []
                for name in list_cons:
                    pattern = r"(?i)" + re.escape(name) + r"\s?\([^)]*\)\s?-"
                    matches = list(re.finditer(pattern, text))
                    all_matches.extend(matches)
                
                president_pattern = r"(?i)Presidente\s?-"
                president_matches = list(re.finditer(president_pattern, text))
                all_matches.extend(president_matches)
                
                all_matches.sort(key=lambda match: match.start())
                
                president_data = None
                if all_matches:
                    first_match = all_matches[0]
                    if not re.match(president_pattern, first_match.group(0), re.IGNORECASE):
                        surname = first_match.group(0)
                        words = surname.split()
                        surname = " ".join(words[:2])
                        if words[1].endswith('.') or words[1].startswith('('):
                            surname = words[0]
                        person_info = df_cons[df_cons["surname"] == surname].iloc[0]
                        president_data = {
                            "ID_cons": person_info["ID_cons"],
                            "year_birth": person_info["year_birth"],
                            "gender": person_info["gender"],
                            "group": 'Presidente',
                            "seniority": len(person_info["legislature"].split(','))
                        }

                chunk_idx = 1
                for i, match in enumerate(all_matches):
                    start_pos = match.end() 
                    end_pos = all_matches[i + 1].start() if i + 1 < len(all_matches) else len(text)

                    chunk = text[start_pos:end_pos].replace("\n", " ").strip()

                    if chunk:
                        if re.match(president_pattern, match.group(0), re.IGNORECASE):
                            if president_data:
                                ID_cons = president_data["ID_cons"]
                                year_birth = president_data["year_birth"]
                                gender = president_data["gender"]
                                group = president_data["group"]
                                seniority = president_data["seniority"]
                            else:
                                ID_cons = "N/A"
                                year_birth = "N/A"
                                gender = "N/A"
                                group = "N/A"
                                seniority = "N/A"
                        else:
                            surname = match.group(0)
                            party = re.search(r'\((.*?)\)', surname)
                            group = party.group(1) if party else "N/A"
                            words = surname.split()
                            surname = " ".join(words[:2])
                            if words[1].endswith('.') or words[1].startswith('('):
                                surname = words[0]
                            try:
                                person_info = df_cons[df_cons["surname"] == surname].iloc[0]
                                ID_cons = person_info["ID_cons"]
                                year_birth = person_info["year_birth"]
                                gender = person_info["gender"]
                                seniority = len(person_info["legislature"].split(','))
                            except IndexError:
                                ID_cons = "N/A"
                                year_birth = "N/A"
                                gender = "N/A"
                                group = "N/A"
                                seniority = "N/A"

                        chunk_list.append({
                            "ID_file": row["ID_file"],
                            "leg": leg,
                            "date": date,
                            "month": month,
                            "class": row["class"],
                            "obj_pos": obj,
                            #"language": language,
                            "ID_cons": ID_cons,
                            "year_birth": year_birth,
                            "gender": gender,
                            "group": group,
                            "seniority": seniority,
                            "position": chunk_idx,
                            "length": len(chunk),
                            "chunk": chunk
                        })
                        
                        chunk_idx += 1
            print('File ok')

        except Exception as e:
            print(f"Errore nel file {row['path_clean']}: {e}. Saltando questa entry.")
            continue

    df_chunks = pd.DataFrame(chunk_list)
    print(f"Numero totale di chunk processati: {len(chunk_list)}")
    return df_chunks

df = isolate_chunk(csv_paths, csv_cons)

print("Salvataggio del file csv_chunks.csv...")
df.to_csv("csv_chunks.csv", index=False)
print("File salvato con successo!")
# Out:
# Processando file ./clean/45461.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45462.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45463.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45464.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45465.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43971.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/41709.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/41710.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/41711.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42001.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42002.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42003.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42004.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42005.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42006.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42007.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42008.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42009.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42010.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42011.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/47801.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47802.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47803.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47804.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47805.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47806.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47807.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47808.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47809.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47810.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47811.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47812.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47813.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47814.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47815.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47816.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47817.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47818.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47819.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47820.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47821.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45161.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45162.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45163.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45164.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45165.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45166.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45167.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45168.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45169.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45170.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45171.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45172.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45173.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45174.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45175.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45176.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45177.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45178.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45179.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45180.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45181.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45182.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45183.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45184.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45185.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45186.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45187.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45188.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45189.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45190.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45191.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45192.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45193.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42221.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42222.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42223.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42224.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42225.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42226.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42227.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42228.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42229.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42230.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42231.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42232.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42233.txt per la legislatura XV...
# Filtrando per legislatura: XV
# Numero di nomi trovati per la legislatura XV: 63
# File ok
# Processando file ./clean/42561.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42562.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42563.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42564.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42565.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42566.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42567.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42568.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42569.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42570.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42571.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42572.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42573.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/
txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43967.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43969.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43970.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43972.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43973.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43975.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43976.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43977.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43979.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43980.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43982.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43984.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43986.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43987.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43989.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43991.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43993.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43994.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45277.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45278.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Numero totale di chunk processati: 48612
# Salvataggio del file csv_chunks.csv...
# File salvato con successo!

# %%
df_chunks = pd.read_csv(csv_chunks)

df_outcomes = df_chunks.copy()
df_outcomes = df_outcomes.drop(columns=['ID_cons','year_birth','gender','group','position','length','chunk'])
df_outcomes = df_outcomes.drop_duplicates(subset=['ID_file'])

intervention_counts = df_chunks.groupby('ID_file').size().reset_index(name='# interventions')
df_outcomes = df_outcomes.merge(intervention_counts, on='ID_file', how='left')

df_chunks_filtered = df_chunks[df_chunks['group'] != 'Presidente']
intervention_counts_filtered = df_chunks_filtered.groupby('ID_file').size().reset_index(name='# interventions (w/o president)')
df_outcomes = df_outcomes.merge(intervention_counts_filtered, on='ID_file', how='left')

length_sum = df_chunks.groupby('ID_file')['length'].sum().reset_index(name='total_length')
df_outcomes = df_outcomes.merge(length_sum, on='ID_file', how='left')

length_sum_filtered = df_chunks_filtered.groupby('ID_file')['length'].sum().reset_index(name='total_length (w/o president)')
df_outcomes = df_outcomes.merge(length_sum_filtered, on='ID_file', how='left')

def extract_number(text, pattern):
    match = re.search(pattern, text)
    if match:
        return int(match.group(1))  
    return None

def get_count(id_file, pattern):
    chunks = df_chunks[(df_chunks['ID_file'] == id_file) & (df_chunks['group'] == 'Presidente')]
    
    for chunk in chunks['chunk']:
        number = extract_number(chunk, pattern)
        if number is not None:
            return number
    
    return None

presenti = r"Presenti: (\d+)"
votanti = r"Votanti: (\d+)"
favorevoli = r"Favorevoli: (\d+)"
contrari = r"Contrari: (\d+)"
astenuti = r"Astenuti: (\d+)"

df_outcomes['presenti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, presenti))
df_outcomes['votanti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, votanti))
df_outcomes['favorevoli'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, favorevoli))
df_outcomes['contrari'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, contrari))
df_outcomes['astenuti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, astenuti))

def determine_outcome(row):
    favorevoli = row['favorevoli'] if pd.notna(row['favorevoli']) else 0
    contrari = row['contrari'] if pd.notna(row['contrari']) else 0
    astenuti = row['astenuti'] if pd.notna(row['astenuti']) else 0

    if pd.isna(row['favorevoli']) and pd.isna(row['contrari']) and pd.isna(row['astenuti']):
        return np.nan

    if favorevoli > contrari and favorevoli > astenuti:
        return 'approvato'
    else:
        return 'non approvato'

df_outcomes['outcome'] = df_outcomes.apply(determine_outcome, axis=1)

df_outcomes.to_csv("csv_outcomes.csv", index=False)

# %%
df = pd.read_csv("csv_chunks.csv")

df_filtered = df[df['group'] != 'Presidente']

df_filtered.to_csv("csv_chunks_filtered.csv", index=False)

# %%
valid_outcomes = df_outcomes[df_outcomes['outcome'].notna()]['ID_file']

df = pd.read_csv("csv_chunks.csv")
df_filtered = df[df['ID_file'].isin(valid_outcomes)]

df_filtered.to_csv("csv_chunks_outcomes.csv", index=False)

df = pd.read_csv("csv_chunks_outcomes.csv")

df_filtered = df[df['group'] != 'Presidente']

df_filtered.to_csv("csv_chunks_outcomes_filtered.csv", index=False)
