# %%
import os
import re
import csv
import pandas as pd
import numpy as np

import time
import requests
from bs4 import BeautifulSoup

#from langdetect import detect
#from deep_translator import GoogleTranslator

# %%
BASE_URL = "https://www.consiglio.vda.it/app/oggettidelconsiglio/dettaglio?pk_documento={}&versione=R"

OUTPUT_FOLDER = "./downloads"
if not os.path.exists(OUTPUT_FOLDER):
    os.makedirs(OUTPUT_FOLDER)

#funzione per scraperare e salvare i resoconti dal sito del consiglio Valle
def scrape_and_save(doc_id):
    url = BASE_URL.format(doc_id)

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Documento {doc_id} non trovato (HTTP {response.status_code}).")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    page_text = soup.get_text(separator="\n", strip=True)

    output_file = os.path.join(OUTPUT_FOLDER, f"{doc_id}.txt")
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(page_text)
    
    print(f"Documento {doc_id} salvato in: {output_file}")
    return output_file


def main(start_id, end_id):
    csv_data = []
    print(f"Inizio lo scraping per i documenti dal {start_id} al {end_id}...")

    for doc_id in range(start_id, end_id + 1):
        print(f"Processo il documento {doc_id}...")
        file_path = scrape_and_save(doc_id)

        if file_path:
            csv_data.append({"ID_file": doc_id, "path_src": file_path})

        # Pausa per evitare di sovraccaricare il server (ad esempio 2-5 secondi)
        time.sleep(2 + (3 * doc_id % 5))  # Variamo la pausa per evitare un pattern troppo prevedibile

    # Salvataggio dei risultati nel file CSV
    csv_file = "csv_paths.csv"
    print(f"Salvataggio dei risultati nel file CSV: {csv_file}")
    with open(csv_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["ID_file", "path_src"])
        writer.writeheader()
        writer.writerows(csv_data)

    print("Completato! Tutti i documenti salvati nella cartella:", OUTPUT_FOLDER)

if __name__ == "__main__":
    main(start_id=42762, end_id=46721)
# Out:
# Inizio lo scraping per i documenti dal 42762 al 46721...
# Processo il documento 42762...
# Documento 42762 salvato in: ./downloads/42762.txt
# Processo il documento 42763...
# Documento 42763 salvato in: ./downloads/42763.txt
# Processo il documento 42764...
# Documento 42764 salvato in: ./downloads/42764.txt
# Processo il documento 42765...
# Documento 42765 salvato in: ./downloads/42765.txt
# Processo il documento 42766...
# Documento 42766 salvato in: ./downloads/42766.txt
# Processo il documento 42767...
# Documento 42767 salvato in: ./downloads/42767.txt
# Processo il documento 42768...
# Documento 42768 salvato in: ./downloads/42768.txt
# Processo il documento 42769...
# Documento 42769 salvato in: ./downloads/42769.txt
# Processo il documento 42770...
# Documento 42770 salvato in: ./downloads/42770.txt
# Processo il documento 42771...
# Documento 42771 salvato in: ./downloads/42771.txt
# Processo il documento 42772...
# Documento 42772 salvato in: ./downloads/42772.txt
# Processo il documento 42773...
# Documento 42773 salvato in: ./downloads/42773.txt
# Processo il documento 42774...
# Documento 42774 salvato in: ./downloads/42774.txt
# Processo il documento 42775...
# Documento 42775 salvato in: ./downloads/42775.txt
# Processo il documento 42776...
# Documento 42776 salvato in: ./downloads/42776.txt
# Processo il documento 42777...
# Documento 42777 salvato in: ./downloads/42777.txt
# Processo il documento 42778...
# Documento 42778 salvato in: ./downloads/42778.txt
# Processo il documento 42779...
# Documento 42779 salvato in: ./downloads/42779.txt
# Processo il documento 42780...
# Documento 42780 salvato in: ./downloads/42780.txt
# Processo il documento 42781...
# Documento 42781 salvato in: ./downloads/42781.txt
# Processo il documento 42782...
# Documento 42782 salvato in: ./downloads/42782.txt
# Processo il documento 42783...
# Documento 42783 salvato in: ./downloads/42783.txt
# Processo il documento 42784...
# Documento 42784 salvato in: ./downloads/42784.txt
# Processo il documento 42785...
# Documento 42785 salvato in: ./downloads/42785.txt
# Processo il documento 42786...
# Documento 42786 salvato in: ./downloads/42786.txt
# Processo il documento 42787...
# Documento 42787 salvato in: ./downloads/42787.txt
# Processo il documento 42788...
# Documento 42788 salvato in: ./downloads/42788.txt
# Processo il documento 42789...
# Documento 42789 salvato in: ./downloads/42789.txt
# Processo il documento 42790...
# Documento 42790 salvato in: ./downloads/42790.txt
# Processo il documento 42791...
# Documento 42791 salvato in: ./downloads/42791.txt
# Processo il documento 42792...
# Documento 42792 salvato in: ./downloads/42792.txt
# Processo il documento 42793...
# Documento 42793 salvato in: ./downloads/42793.txt
# Processo il documento 42794...
# Documento 42794 salvato in: ./downloads/42794.txt
# Processo il documento 42795...
# Documento 42795 salvato in: ./downloads/42795.txt
# Processo il documento 42796...
# Documento 42796 salvato in: ./downloads/42796.txt
# Processo il documento 42797...
# Documento 42797 non trovato (HTTP 404).
# Processo il documento 42798...
# Documento 42798 non trovato (HTTP 404).
# Processo il documento 42799...
# Documento 42799 non trovato (HTTP 404).
# Processo il documento 42800...
# Documento 42800 non trovato (HTTP 404).
# Processo il documento 42801...
# Documento 42801 salvato in: ./downloads/42801.txt
# Processo il documento 42802...
# Documento 42802 salvato in: ./downloads/42802.txt
# Processo il documento 42803...
# Documento 42803 salvato in: ./downloads/42803.txt
# Processo il documento 42804...
# Documento 42804 salvato in: ./downloads/42804.txt
# Processo il documento 42805...
# Documento 42805 salvato in: ./downloads/42805.txt
# Processo il documento 42806...
# Documento 42806 salvato in: ./downloads/42806.txt
# Processo il documento 42807...
# Documento 42807 salvato in: ./downloads/42807.txt
# Processo il documento 42808...
# Documento 42808 salvato in: ./downloads/42808.txt
# Processo il documento 42809...
# Documento 42809 salvato in: ./downloads/42809.txt
# Processo il documento 42810...
# Documento 42810 salvato in: ./downloads/42810.txt
# Processo il documento 42811...
# Documento 42811 salvato in: ./downloads/42811.txt
# Processo il documento 42812...
# Documento 42812 salvato in: ./downloads/42812.txt
# Processo il documento 42813...
# Documento 42813 salvato in: ./downloads/42813.txt
# Processo il documento 42814...
# Documento 42814 salvato in: ./downloads/42814.txt
# Processo il documento 42815...
# Documento 42815 salvato in: ./downloads/42815.txt
# Processo il documento 42816...
# Documento 42816 salvato in: ./downloads/42816.txt
# Processo il documento 42817...
# Documento 42817 salvato in: ./downloads/42817.txt
# Processo il documento 42818...
# Documento 42818 salvato in: ./downloads/42818.txt
# Processo il documento 42819...
# Documento 42819 salvato in: ./downloads/42819.txt
# Processo il documento 42820...
# Documento 42820 salvato in: ./downloads/42820.txt
# Processo il documento 42821...
# Documento 42821 salvato in: ./downloads/42821.txt
# Processo il documento 42822...
# Documento 42822 salvato in: ./downloads/42822.txt
# Processo il documento 42823...
# Documento 42823 salvato in: ./downloads/42823.txt
# Processo il documento 42824...
# Documento 42824 salvato in: ./downloads/42824.txt
# Processo il documento 42825...
# Documento 42825 salvato in: ./downloads/42825.txt
# Processo il documento 42826...
# Documento 42826 salvato in: ./downloads/42826.txt
# Processo il documento 42827...
# Documento 42827 salvato in: ./downloads/42827.txt
# Processo il documento 42828...
# Documento 42828 salvato in: ./downloads/42828.txt
# Processo il documento 42829...
# Documento 42829 salvato in: ./downloads/42829.txt
# Processo il documento 42830...
# Documento 42830 salvato in: ./downloads/42830.txt
# Processo il documento 42831...
# Documento 42831 salvato in: ./downloads/42831.txt
# Processo il documento 42832...
# Documento 42832 salvato in: ./downloads/42832.txt
# Processo il documento 42833...
# Documento 42833 salvato in: ./downloads/42833.txt
# Processo il documento 42834...
# Documento 42834 salvato in: ./downloads/42834.txt
# Processo il documento 42835...
# Documento 42835 salvato in: ./downloads/42835.txt
# Processo il documento 42836...
# Documento 42836 salvato in: ./downloads/42836.txt
# Processo il documento 42837...
# Documento 42837 salvato in: ./downloads/42837.txt
# Processo il documento 42838...
# Documento 42838 salvato in: ./downloads/42838.txt
# Processo il documento 42839...
# Documento 42839 salvato in: ./downloads/42839.txt
# Processo il documento 42840...
# Documento 42840 salvato in: ./downloads/42840.txt
# Processo il documento 42841...
# Documento 42841 salvato in: ./downloads/42841.txt
# Processo il documento 42842...
# Documento 42842 salvato in: ./downloads/42842.txt
# Processo il documento 42843...
# Documento 42843 salvato in: ./downloads/42843.txt
# Processo il documento 42844...
# Documento 42844 salvato in: ./downloads/42844.txt
# Processo il documento 42845...
# Documento 42845 salvato in: ./downloads/42845.txt
# Processo il documento 42846...
# Documento 42846 salvato in: ./downloads/42846.txt
# Processo il documento 42847...
# Documento 42847 salvato in: ./downloads/42847.txt
# Processo il documento 42848...
# Documento 42848 salvato in: ./downloads/42848.txt
# Processo il documento 42849...
# Documento 42849 salvato in: ./downloads/42849.txt
# Processo il documento 42850...
# Documento 42850 salvato in: ./downloads/42850.txt
# Processo il documento 42851...
# Documento 42851 salvato in: ./downloads/42851.txt
# Processo il documento 42852...
# Documento 42852 salvato in: ./downloads/42852.txt
# Processo il documento 42853...
# Documento 42853 salvato in: ./downloads/42853.txt
# Processo il documento 42854...
# Documento 42854 salvato in: ./downloads/42854.txt
# Processo il documento 42855...
# Documento 42855 salvato in: ./downloads/42855.txt
# Processo il documento 42856...
# Documento 42856 salvato in: ./downloads/42856.txt
# Processo il documento 42857...
# Documento 42857 salvato in: ./downloads/42857.txt
# Processo il documento 42858...
# Documento 42858 salvato in: ./downloads/42858.txt
# Processo il documento 42859...
# Documento 42859 non trovato (HTTP 404).
# Processo il documento 42860...
# Documento 42860 non trovato (HTTP 404).
# Processo il documento 42861...
# Documento 42861 salvato in: ./downloads/42861.txt
# Processo il documento 42862...
# Documento 42862 salvato in: ./downloads/42862.txt
# Processo il documento 42863...
# Documento 42863 salvato in: ./downloads/42863.txt
# Processo il documento 42864...
# Documento 42864 salvato in: ./downloads/42864.txt
# Processo il documento 42865...
# Documento 42865 salvato in: ./downloads/42865.txt
# Processo il documento 42866...
# Documento 42866 salvato in: ./downloads/42866.txt
# Processo il documento 42867...
# Documento 42867 salvato in: ./downloads/42867.txt
# Processo il documento 42868...
# Documento 42868 salvato in: ./downloads/42868.txt
# Processo il documento 42869...
# Documento 42869 salvato in: ./downloads/42869.txt
# Processo il documento 42870...
# Documento 42870 salvato in: ./downloads/42870.txt
# Processo il documento 42871...
# Documento 42871 salvato in: ./downloads/42871.txt
# Processo il documento 42872...
# Documento 42872 salvato in: ./downloads/42872.txt
# Processo il documento 42873...
# Documento 42873 salvato in: ./downloads/42873.txt
# Processo il documento 42874...
# Documento 42874 salvato in: ./downloads/42874.txt
# Processo il documento 42875...
# Documento 42875 salvato in: ./downloads/42875.txt
# Processo il documento 42876...
# Documento 42876 salvato in: ./downloads/42876.txt
# Processo il documento 42877...
# Documento 42877 salvato in: ./downloads/42877.txt
# Processo il documento 42878...
# Documento 42878 salvato in: ./downloads/42878.txt
# Processo il documento 42879...
# Documento 42879 salvato in: ./downloads/42879.txt
# Processo il documento 42880...
# Documento 42880 salvato in: ./downloads/42880.txt
# Processo il documento 42881...
# Documento 42881 salvato in: ./downloads/42881.txt
# Processo il documento 42882...
# Documento 42882 salvato in: ./downloads/42882.txt
# Processo il documento 42883...
# Documento 42883 salvato in: ./downloads/42883.txt
# Processo il documento 42884...
# Documento 42884 salvato in: ./downloads/42884.txt
# Processo il documento 42885...
# Documento 42885 salvato in: ./downloads/42885.txt
# Processo il documento 42886...
# Documento 42886 salvato in: ./downloads/42886.txt
# Processo il documento 42887...
# Documento 42887 salvato in: ./downloads/42887.txt
# Processo il documento 42888...
# Documento 42888 salvato in: ./downloads/42888.txt
# Processo il documento 42889...
# Documento 42889 salvato in: ./downloads/42889.txt
# Processo il documento 42890...
# Documento 42890 salvato in: ./downloads/42890.txt
# Processo il documento 42891...
# Documento 42891 salvato in: ./downloads/42891.txt
# Processo il documento 42892...
# Documento 42892 salvato in: ./downloads/42892.txt
# Processo il documento 42893...
# Documento 42893 salvato in: ./downloads/42893.txt
# Processo il documento 42894...
# Documento 42894 salvato in: ./downloads/42894.txt
# Processo il documento 42895...
# Documento 42895 salvato in: ./downloads/42895.txt
# Processo il documento 42896...
# Documento 42896 salvato in: ./downloads/42896.txt
# Processo il documento 42897...
# Documento 42897 salvato in: ./downloads/42897.txt
# Processo il documento 42898...
# Documento 42898 salvato in: ./downloads/42898.txt
# Processo il documento 42899...
# Documento 42899 salvato in: ./downloads/42899.txt
# Processo il documento 42900...
# Documento 42900 salvato in: ./downloads/42900.txt
# Processo il documento 42901...
# Documento 42901 salvato in: ./downloads/42901.txt
# Processo il documento 42902...
# Documento 42902 salvato in: ./downloads/42902.txt
# Processo il documento 42903...
# Documento 42903 salvato in: ./downloads/42903.txt
# Processo il documento 42904...
# Documento 42904 salvato in: ./downloads/42904.txt
# Processo il documento 42905...
# Documento 42905 salvato in: ./downloads/42905.txt
# Processo il documento 42906...
# Documento 42906 salvato in: ./downloads/42906.txt
# Processo il documento 42907...
# Documento 42907 salvato in: ./downloads/42907.txt
# Processo il documento 42908...
# Documento 42908 salvato in: ./downloads/42908.txt
# Processo il documento 42909...
# Documento 42909 salvato in: ./downloads/42909.txt
# Processo il documento 42910...
# Documento 42910 salvato in: ./downloads/42910.txt
# Processo il documento 42911...
# Documento 42911 salvato in: ./downloads/42911.txt
# Processo il documento 42912...
# Documento 42912 salvato in: ./downloads/42912.txt
# Processo il documento 42913...
# Documento 42913 salvato in: ./downloads/42913.txt
# Processo il documento 42914...
# Documento 42914 salvato in: ./downloads/42914.txt
# Processo il documento 42915...
# Documento 42915 non trovato (HTTP 404).
# Processo il documento 42916...
# Documento 42916 non trovato (HTTP 404).
# Processo il documento 42917...
# Documento 42917 non trovato (HTTP 404).
# Processo il documento 42918...
# Documento 42918 non trovato (HTTP 404).
# Processo il documento 42919...
# Documento 42919 non trovato (HTTP 404).
# Processo il documento 42920...
# Documento 42920 non trovato (HTTP 404).
# Processo il documento 42921...
# Documento 42921 salvato in: ./downloads/42921.txt
# Processo il documento 42922...
# Documento 42922 salvato in: ./downloads/42922.txt
# Processo il documento 42923...
# Documento 42923 salvato in: ./downloads/42923.txt
# Processo il documento 42924...
# Documento 42924 salvato in: ./downloads/42924.txt
# Processo il documento 42925...
# Documento 42925 salvato in: ./downloads/42925.txt
# Processo il documento 42926...
# Documento 42926 non trovato (HTTP 404).
# Processo il documento 42927...
# Documento 42927 non trovato (HTTP 404).
# Processo il documento 42928...
# Documento 42928 non trovato (HTTP 404).
# Processo il documento 42929...
# Documento 42929 non trovato (HTTP 404).
# Processo il documento 42930...
# Documento 42930 non trovato (HTTP 404).
# Processo il documento 42931...
# Documento 42931 non trovato (HTTP 404).
# Processo il documento 42932...
# Documento 42932 non trovato (HTTP 404).
# Processo il documento 42933...
# Documento 42933 non trovato (HTTP 404).
# Processo il documento 42934...
# Documento 42934 non trovato (HTTP 404).
# Processo il documento 42935...
# Documento 42935 non trovato (HTTP 404).
# Processo il documento 42936...
# Documento 42936 non trovato (HTTP 404).
# Processo il documento 42937...
# Documento 42937 non trovato (HTTP 404).
# Processo il documento 42938...
# Documento 42938 non trovato (HTTP 404).
# Processo il documento 42939...
# Documento 42939 non trovato (HTTP 404).
# Processo il documento 42940...
# Documento 42940 non trovato (HTTP 404).
# Processo il documento 42941...
# Documento 42941 salvato in: ./downloads/42941.txt
# Processo il documento 42942...
# Documento 42942 salvato in: ./downloads/42942.txt
# Processo il documento 42943...
# Documento 42943 salvato in: ./downloads/42943.txt
# Processo il documento 42944...
# Documento 42944 salvato in: ./downloads/42944.txt
# Processo il documento 42986...
# Documento 42986 salvato in: ./downloads/42986.txt
# Processo il documento 42987...
# Documento 42987 salvato in: ./downloads/42987.txt
# Processo il documento 42988...
# Documento 42988 salvato in: ./downloads/42988.txt
# Processo il documento 42989...
# Documento 42989 salvato in: ./downloads/42989.txt
# Processo il documento 42990...
# Documento 42990 salvato in: ./downloads/42990.txt
# Processo il documento 42991...
# Documento 42991 salvato in: ./downloads/42991.txt
# Processo il documento 42992...
# Documento 42992 salvato in: ./downloads/42992.txt
# Processo il documento 42993...
# Documento 42993 salvato in: ./downloads/42993.txt
# Processo il documento 42994...
# Documento 42994 salvato in: ./downloads/42994.txt
# Processo il documento 42995...
# Documento 42995 salvato in: ./downloads/42995.txt
# Processo il documento 42996...
# Documento 42996 salvato in: ./downloads/42996.txt
# Processo il documento 42997...
# Documento 42997 salvato in: ./downloads/42997.txt
# Processo il documento 42998...
# Documento 42998 salvato in: ./downloads/42998.txt
# Processo il documento 42999...
# Documento 42999 salvato in: ./downloads/42999.txt
# Processo il documento 43000...
# Documento 43000 salvato in: ./downloads/43000.txt
# Processo il documento 43001...
# Documento 43001 salvato in: ./downloads/43001.txt
# Processo il documento 43002...
# Documento 43002 salvato in: ./downloads/43002.txt
# Processo il documento 43003...
# Documento 43003 non trovato (HTTP 404).
# Processo il documento 43004...
# Documento 43004 non trovato (HTTP 404).
# Processo il documento 43005...
# Documento 43005 non trovato (HTTP 404).
# Processo il documento 43006...
# Documento 43006 non trovato (HTTP 404).
# Processo il documento 43007...
# Documento 43007 non trovato (HTTP 404).
# Processo il documento 43008...
# Documento 43008 non trovato (HTTP 404).
# Processo il documento 43009...
# Documento 43009 non trovato (HTTP 404).
# Processo il documento 43010...
# Documento 43010 non trovato (HTTP 404).
# Processo il documento 43011...
# Documento 43011 non trovato (HTTP 404).
# Processo il documento 43012...
# Documento 43012 non trovato (HTTP 404).
# Processo il documento 43013...
# Documento 43013 non trovato (HTTP 404).
# Processo il documento 43014...
# Documento 43014 non trovato (HTTP 404).
# Processo il documento 43015...
# Documento 43015 non trovato (HTTP 404).
# Processo il documento 43016...
# Documento 43016 non trovato (HTTP 404).
# Processo il documento 43017...
# Documento 43017 non trovato (HTTP 404).
# Processo il documento 43018...
# Documento 43018 non trovato (HTTP 404).
# Processo il documento 43019...
# Documento 43019 non trovato (HTTP 404).
# Processo il documento 43020...
# Documento 43020 non trovato (HTTP 404).
# Processo il documento 43021...
# Documento 43021 salvato in: ./downloads/43021.txt
# Processo il documento 43022...
# Documento 43022 salvato in: ./downloads/43022.txt
# Processo il documento 43023...
# Documento 43023 salvato in: ./downloads/43023.txt
# Processo il documento 43024...
# Documento 43024 salvato in: ./downloads/43024.txt
# Processo il documento 43025...
# Documento 43025 salvato in: ./downloads/43025.txt
# Processo il documento 43026...
# Documento 43026 salvato in: ./downloads/43026.txt
# Processo il documento 43027...
# Documento 43027 salvato in: ./downloads/43027.txt
# Processo il documento 43028...
# Documento 43028 salvato in: ./downloads/43028.txt
# Processo il documento 43195...
# Documento 43195 salvato in: ./downloads/43195.txt
# Processo il documento 43196...
# Documento 43196 salvato in: ./downloads/43196.txt
# Processo il documento 43197...
# Documento 43197 salvato in: ./downloads/43197.txt
# Processo il documento 43198...
# Documento 43198 salvato in: ./downloads/43198.txt
# Processo il documento 43199...
# Documento 43199 salvato in: ./downloads/43199.txt
# Processo il documento 43200...
# Documento 43200 salvato in: ./downloads/43200.txt
# Processo il documento 43201...
# Documento 43201 salvato in: ./downloads/43201.txt
# Processo il documento 43202...
# Documento 43202 salvato in: ./downloads/43202.txt
# Processo il documento 43203...
# Documento 43203 salvato in: ./downloads/43203.txt
# Processo il documento 43204...
# Documento 43204 salvato in: ./downloads/43204.txt
# Processo il documento 43205...
# Documento 43205 salvato in: ./downloads/43205.txt
# Processo il documento 43206...
# Documento 43206 salvato in: ./downloads/43206.txt
# Processo il documento 43207...
# Documento 43207 salvato in: ./downloads/43207.txt
# Processo il documento 43208...
# Documento 43208 salvato in: ./downloads/43208.txt
# Processo il documento 43209...
# Documento 43209 salvato in: ./downloads/43209.txt
# Processo il documento 43210...
# Documento 43210 salvato in: ./downloads/43210.txt
# Processo il documento 43211...
# Documento 43211 salvato in: ./downloads/43211.txt
# Processo il documento 43212...
# Documento 43212 salvato in: ./downloads/43212.txt
# Processo il documento 43213...
# Documento 43213 salvato in: ./downloads/43213.txt
# Processo il documento 43214...
# Documento 43214 salvato in: ./downloads/43214.txt
# Processo il documento 43215...
# Documento 43215 salvato in: ./downloads/43215.txt
# Processo il documento 43216...
# Documento 43216 salvato in: ./downloads/43216.txt
# Processo il documento 43217...
# Documento 43217 salvato in: ./downloads/43217.txt
# Processo il documento 43218...
# Documento 43218 salvato in: ./downloads/43218.txt
# Processo il documento 43219...
# Documento 43219 salvato in: ./downloads/43219.txt
# Processo il documento 43220...
# Documento 43220 salvato in: ./downloads/43220.txt
# Processo il documento 43221...
# Documento 43221 salvato in: ./downloads/43221.txt
# Processo il documento 43222...
# Documento 43222 salvato in: ./downloads/43222.txt
# Processo il documento 43223...
# Documento 43223 salvato in: ./downloads/43223.txt
# Processo il documento 43224...
# Documento 43224 salvato in: ./downloads/43224.txt
# Processo il documento 43225...
# Documento 43225 salvato in: ./downloads/43225.txt
# Processo il documento 43226...
# Documento 43226 salvato in: ./downloads/43226.txt
# Processo il documento 43227...
# Documento 43227 non trovato (HTTP 404).
# Processo il documento 43228...
# Documento 43228 non trovato (HTTP 404).
# Processo il documento 43229...
# Documento 43229 non trovato (HTTP 404).
# Processo il documento 43230...
# Documento 43230 non trovato (HTTP 404).
# Processo il documento 43231...
# Documento 43231 non trovato (HTTP 404).
# Processo il documento 43232...
# Documento 43232 non trovato (HTTP 404).
# Processo il documento 43233...
# Documento 43233 non trovato (HTTP 404).
# Processo il documento 43234...
# Documento 43234 non trovato (HTTP 404).
# Processo il documento 43235...
# Documento 43235 non trovato (HTTP 404).
# Processo il documento 43236...
# Documento 43236 non trovato (HTTP 404).
# Documento 43278 salvato in: ./downloads/43278.txt
# Processo il documento 43279...
# Documento 43279 salvato in: ./downloads/43279.txt
# Processo il documento 43280...
# Documento 43280 salvato in: ./downloads/43280.txt
# Processo il documento 43281...
# Documento 43281 salvato in: ./downloads/43281.txt
# Processo il documento 43282...
# Documento 43282 salvato in: ./downloads/43282.txt
# Processo il documento 43283...
# Documento 43283 salvato in: ./downloads/43283.txt
# Processo il documento 43284...
# Documento 43284 salvato in: ./downloads/43284.txt
# Processo il documento 43285...
# Documento 43285 salvato in: ./downloads/43285.txt
# Processo il documento 43286...
# Documento 43286 salvato in: ./downloads/43286.txt
# Processo il documento 43287...
# Documento 43287 salvato in: ./downloads/43287.txt
# Processo il documento 43288...
# Documento 43288 non trovato (HTTP 404).
# Processo il documento 43289...
# Documento 43289 non trovato (HTTP 404).
# Processo il documento 43290...
# Documento 43290 non trovato (HTTP 404).
# Processo il documento 43291...
# Documento 43291 non trovato (HTTP 404).
# Processo il documento 43292...
# Documento 43292 non trovato (HTTP 404).
# Processo il documento 43293...
# Documento 43293 non trovato (HTTP 404).
# Processo il documento 43294...
# Documento 43294 non trovato (HTTP 404).
# Processo il documento 43295...
# Documento 43295 non trovato (HTTP 404).
# Processo il documento 43296...
# Documento 43296 non trovato (HTTP 404).
# Processo il documento 43297...
# Documento 43297 non trovato (HTTP 404).
# Processo il documento 43298...
# Documento 43298 non trovato (HTTP 404).
# Processo il documento 43299...
# Documento 43299 non trovato (HTTP 404).
# Processo il documento 43300...
# Documento 43300 non trovato (HTTP 404).
# Processo il documento 43301...
# Documento 43301 salvato in: ./downloads/43301.txt
# Processo il documento 43302...
# Documento 43302 salvato in: ./downloads/43302.txt
# Processo il documento 43303...
# Documento 43303 salvato in: ./downloads/43303.txt
# Processo il documento 43304...
# Documento 43304 salvato in: ./downloads/43304.txt
# Processo il documento 43305...
# Documento 43305 salvato in: ./downloads/43305.txt
# Processo il documento 43306...
# Documento 43306 salvato in: ./downloads/43306.txt
# Processo il documento 43307...
# Documento 43307 salvato in: ./downloads/43307.txt
# Processo il documento 43308...
# Documento 43308 salvato in: ./downloads/43308.txt
# Processo il documento 43309...
# Documento 43309 salvato in: ./downloads/43309.txt
# Processo il documento 43310...
# Documento 43310 salvato in: ./downloads/43310.txt
# Processo il documento 43311...
# Documento 43311 salvato in: ./downloads/43311.txt
# Processo il documento 43312...
# Documento 43312 salvato in: ./downloads/43312.txt
# Processo il documento 43313...
# Documento 43313 salvato in: ./downloads/43313.txt
# Processo il documento 43314...
# Documento 43314 salvato in: ./downloads/43314.txt
# Processo il documento 43315...
# Documento 43315 salvato in: ./downloads/43315.txt
# Processo il documento 43316...
# Documento 43316 salvato in: ./downloads/43316.txt
# Processo il documento 43317...
# Documento 43317 salvato in: ./downloads/43317.txt
# Processo il documento 43318...
# Documento 43318 salvato in: ./downloads/43318.txt
# Processo il documento 43319...
# Documento 43319 salvato in: ./downloads/43319.txt
# Processo il documento 43320...
# Documento 43320 salvato in: ./downloads/43320.txt
# Processo il documento 43321...
# Documento 43321 salvato in: ./downloads/43321.txt
# Processo il documento 43322...
# Documento 43322 salvato in: ./downloads/43322.txt
# Processo il documento 43323...
# Documento 43323 salvato in: ./downloads/43323.txt
# Processo il documento 43324...
# Documento 43324 salvato in: ./downloads/43324.txt
# Processo il documento 43325...
# Documento 43325 salvato in: ./downloads/43325.txt
# Processo il documento 43326...
# Documento 43326 salvato in: ./downloads/43326.txt
# Processo il documento 43327...
# Documento 43327 salvato in: ./downloads/43327.txt
# Processo il documento 43328...
# Documento 43328 salvato in: ./downloads/43328.txt
# Processo il documento 43329...
# Documento 43329 salvato in: ./downloads/43329.txt
# Processo il documento 43330...
# Documento 43330 salvato in: ./downloads/43330.txt
# Processo il documento 43331...
# Documento 43331 salvato in: ./downloads/43331.txt
# Processo il documento 43332...
# Documento 43332 salvato in: ./downloads/43332.txt
# Processo il documento 43333...
# Documento 43333 salvato in: ./downloads/43333.txt
# Processo il documento 43334...
# Documento 43334 salvato in: ./downloads/43334.txt
# Processo il documento 43335...
# Documento 43335 salvato in: ./downloads/43335.txt
# Processo il documento 43336...
# Documento 43336 salvato in: ./downloads/43336.txt
# Processo il documento 43337...
# Documento 43337 salvato in: ./downloads/43337.txt
# Processo il documento 43338...
# Documento 43338 salvato in: ./downloads/43338.txt
# Processo il documento 43339...
# Documento 43339 salvato in: ./downloads/43339.txt
# Processo il documento 43340...
# Documento 43340 salvato in: ./downloads/43340.txt
# Processo il documento 43341...
# Documento 43341 salvato in: ./downloads/43341.txt
# Processo il documento 43342...
# Documento 43342 salvato in: ./downloads/43342.txt
# Processo il documento 43343...
# Documento 43343 salvato in: ./downloads/43343.txt
# Processo il documento 43344...
# Documento 43344 salvato in: ./downloads/43344.txt
# Processo il documento 43345...
# Documento 43345 salvato in: ./downloads/43345.txt
# Processo il documento 43346...
# Documento 43346 non trovato (HTTP 404).
# Processo il documento 43347...
# Documento 43347 non trovato (HTTP 404).
# Processo il documento 43348...
# Documento 43348 non trovato (HTTP 404).
# Processo il documento 43349...
# Documento 43349 non trovato (HTTP 404).
# Processo il documento 43350...
# Documento 43350 non trovato (HTTP 404).
# Processo il documento 43351...
# Documento 43351 non trovato (HTTP 404).
# Processo il documento 43352...
# Documento 43352 non trovato (HTTP 404).
# Processo il documento 43353...
# Documento 43353 non trovato (HTTP 404).
# Processo il documento 43354...
# Documento 43354 non trovato (HTTP 404).
# Processo il documento 43355...
# Documento 43355 non trovato (HTTP 404).
# Processo il documento 43356...
# Documento 43356 non trovato (HTTP 404).
# Processo il documento 43357...
# Documento 43357 non trovato (HTTP 404).
# Processo il documento 43358...
# Documento 43358 non trovato (HTTP 404).
# Processo il documento 43359...
# Documento 43359 non trovato (HTTP 404).
# Processo il documento 43360...
# Documento 43360 non trovato (HTTP 404).
# Processo il documento 43361...
# Documento 43361 salvato in: ./downloads/43361.txt
# Processo il documento 43362...
# Documento 43362 salvato in: ./downloads/43362.txt
# Processo il documento 43363...
# Documento 46642 salvato in: ./downloads/46642.txt
# Processo il documento 46643...
# Documento 46643 salvato in: ./downloads/46643.txt
# Processo il documento 46644...
# Documento 46644 salvato in: ./downloads/46644.txt
# Processo il documento 46645...
# Documento 46645 salvato in: ./downloads/46645.txt
# Processo il documento 46646...
# Documento 46646 non trovato (HTTP 404).
# Processo il documento 46647...
# Documento 46647 non trovato (HTTP 404).
# Processo il documento 46648...
# Documento 46648 non trovato (HTTP 404).
# Processo il documento 46649...
# Documento 46649 non trovato (HTTP 404).
# Processo il documento 46650...
# Documento 46650 non trovato (HTTP 404).
# Processo il documento 46651...
# Documento 46651 non trovato (HTTP 404).
# Processo il documento 46652...
# Documento 46652 non trovato (HTTP 404).
# Processo il documento 46653...
# Documento 46653 non trovato (HTTP 404).
# Processo il documento 46654...
# Documento 46654 non trovato (HTTP 404).
# Processo il documento 46655...
# Documento 46655 non trovato (HTTP 404).
# Processo il documento 46656...
# Documento 46656 non trovato (HTTP 404).
# Processo il documento 46657...
# Documento 46657 non trovato (HTTP 404).
# Processo il documento 46658...
# Documento 46658 non trovato (HTTP 404).
# Processo il documento 46659...
# Documento 46659 non trovato (HTTP 404).
# Processo il documento 46660...
# Documento 46660 non trovato (HTTP 404).
# Processo il documento 46661...
# Documento 46661 salvato in: ./downloads/46661.txt
# Processo il documento 46662...
# Documento 46662 salvato in: ./downloads/46662.txt
# Processo il documento 46663...
# Documento 46663 salvato in: ./downloads/46663.txt
# Processo il documento 46664...
# Documento 46664 salvato in: ./downloads/46664.txt
# Processo il documento 46665...
# Documento 46665 salvato in: ./downloads/46665.txt
# Processo il documento 46666...
# Documento 46666 salvato in: ./downloads/46666.txt
# Processo il documento 46667...
# Documento 46667 salvato in: ./downloads/46667.txt
# Processo il documento 46668...
# Documento 46668 salvato in: ./downloads/46668.txt
# Processo il documento 46669...
# Documento 46669 salvato in: ./downloads/46669.txt
# Processo il documento 46670...
# Documento 46670 salvato in: ./downloads/46670.txt
# Processo il documento 46671...
# Documento 46671 salvato in: ./downloads/46671.txt
# Processo il documento 46672...
# Documento 46672 salvato in: ./downloads/46672.txt
# Processo il documento 46673...
# Documento 46673 salvato in: ./downloads/46673.txt
# Processo il documento 46674...
# Documento 46674 salvato in: ./downloads/46674.txt
# Processo il documento 46675...
# Documento 46675 salvato in: ./downloads/46675.txt
# Processo il documento 46676...
# Documento 46676 salvato in: ./downloads/46676.txt
# Processo il documento 46677...
# Documento 46677 salvato in: ./downloads/46677.txt
# Processo il documento 46678...
# Documento 46678 salvato in: ./downloads/46678.txt
# Processo il documento 46679...
# Documento 46679 salvato in: ./downloads/46679.txt
# Processo il documento 46680...
# Documento 46680 salvato in: ./downloads/46680.txt
# Processo il documento 46681...
# Documento 46681 salvato in: ./downloads/46681.txt
# Processo il documento 46682...
# Documento 46682 salvato in: ./downloads/46682.txt
# Processo il documento 46683...
# Documento 46683 salvato in: ./downloads/46683.txt
# Processo il documento 46684...
# Documento 46684 salvato in: ./downloads/46684.txt
# Processo il documento 46685...
# Documento 46685 salvato in: ./downloads/46685.txt
# Processo il documento 46686...
# Documento 46686 salvato in: ./downloads/46686.txt
# Processo il documento 46687...
# Documento 46687 salvato in: ./downloads/46687.txt
# Processo il documento 46688...
# Documento 46688 salvato in: ./downloads/46688.txt
# Processo il documento 46689...
# Documento 46689 salvato in: ./downloads/46689.txt
# Processo il documento 46690...
# Documento 46690 salvato in: ./downloads/46690.txt
# Processo il documento 46691...
# Documento 46691 salvato in: ./downloads/46691.txt
# Processo il documento 46692...
# Documento 46692 salvato in: ./downloads/46692.txt
# Processo il documento 46693...
# Documento 46693 salvato in: ./downloads/46693.txt
# Processo il documento 46694...
# Documento 46694 salvato in: ./downloads/46694.txt
# Processo il documento 46695...
# Documento 46695 salvato in: ./downloads/46695.txt
# Processo il documento 46696...
# Documento 46696 salvato in: ./downloads/46696.txt
# Processo il documento 46697...
# Documento 46697 salvato in: ./downloads/46697.txt
# Processo il documento 46698...
# Documento 46698 salvato in: ./downloads/46698.txt
# Processo il documento 46699...
# Documento 46699 salvato in: ./downloads/46699.txt
# Processo il documento 46700...
# Documento 46700 salvato in: ./downloads/46700.txt
# Processo il documento 46701...
# Documento 46701 salvato in: ./downloads/46701.txt
# Processo il documento 46702...
# Documento 46702 salvato in: ./downloads/46702.txt
# Processo il documento 46703...
# Documento 46703 salvato in: ./downloads/46703.txt
# Processo il documento 46704...
# Documento 46704 salvato in: ./downloads/46704.txt
# Processo il documento 46705...
# Documento 46705 salvato in: ./downloads/46705.txt
# Processo il documento 46706...
# Documento 46706 salvato in: ./downloads/46706.txt
# Processo il documento 46707...
# Documento 46707 salvato in: ./downloads/46707.txt
# Processo il documento 46708...
# Documento 46708 salvato in: ./downloads/46708.txt
# Processo il documento 46709...
# Documento 46709 salvato in: ./downloads/46709.txt
# Processo il documento 46710...
# Documento 46710 salvato in: ./downloads/46710.txt
# Processo il documento 46711...
# Documento 46711 salvato in: ./downloads/46711.txt
# Processo il documento 46712...
# Documento 46712 salvato in: ./downloads/46712.txt
# Processo il documento 46713...
# Documento 46713 non trovato (HTTP 404).
# Processo il documento 46714...
# Documento 46714 non trovato (HTTP 404).
# Processo il documento 46715...
# Documento 46715 non trovato (HTTP 404).
# Processo il documento 46716...
# Documento 46716 non trovato (HTTP 404).
# Processo il documento 46717...
# Documento 46717 non trovato (HTTP 404).
# Processo il documento 46718...
# Documento 46718 non trovato (HTTP 404).
# Processo il documento 46719...
# Documento 46719 non trovato (HTTP 404).
# Processo il documento 46720...
# Documento 46720 non trovato (HTTP 404).
# Processo il documento 46721...
# Documento 46721 salvato in: ./downloads/46721.txt
# Salvataggio dei risultati nel file CSV: csv_paths.csv
# Completato! Tutti i documenti salvati nella cartella: ./downloads

# %%
def generate_csv_from_folder(folder_path, csv_file="csv_paths.csv"):
    csv_data = []
    
    # Verifica che la cartella esista
    if not os.path.exists(folder_path):
        print(f"La cartella {folder_path} non esiste.")
        return
    
    # Scansiona la cartella per trovare i file
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        
        if os.path.isfile(file_path):  # Assicuriamoci che sia un file e non una cartella
            file_id, _ = os.path.splitext(file_name)  # Rimuove l'estensione
            csv_data.append({"ID_file": file_id, "path_src": file_path})
    
    # Salvataggio dei dati in un file CSV
    with open(csv_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["ID_file", "path_src"])
        writer.writeheader()
        writer.writerows(csv_data)
    
    print(f"File CSV creato con successo: {csv_file}")

# Esempio di utilizzo
folder_path = "./downloads"  # Modifica con il percorso della tua cartella
generate_csv_from_folder(folder_path)
# Out:
# File CSV creato con successo: csv_paths.csv

# %%
#funzione per pulire i file txt dalle parti inutili presenti nella pagina web del consiglio Valle
def first_clean(target_folder, keyword, mid_strings, end_keyword, csv_paths):
    df = pd.read_csv(csv_paths)

    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    df["path_clean"] = ""

    for idx, row in df.iterrows():
        source_path = row["path_src"]
        if source_path.endswith(".txt"):
            filename = os.path.basename(source_path)
            target_path = os.path.join(target_folder, filename)

            df.at[idx, "path_clean"] = target_path

            with open(source_path, "r", encoding="utf-8") as file:
                content = file.read()

            if keyword in content:
                content = keyword + content.split(keyword, 1)[1] 

            for mid_string in mid_strings:
                content = re.sub(re.escape(mid_string), "", content) 

            if end_keyword in content:
                content = content.split(end_keyword, 1)[0]  

            with open(target_path, "w", encoding="utf-8") as file:
                file.write(content)

    df.to_csv(csv_paths, index=False)

#funzione per estrarre informazioni dai file txt: oggetto, legislatura, data e classificazione
def extract_and_format_date(text):
    
    date_pattern = re.search(r"(\d{1,2})\s+([a-zA-Z]+)\s+(\d{4})", text)
    
    if date_pattern:
        day, month_name, year = date_pattern.groups()
        
        months = {
            "gennaio": "01", "febbraio": "02", "marzo": "03", "aprile": "04", "maggio": "05", "giugno": "06",
            "luglio": "07", "agosto": "08", "settembre": "09", "ottobre": "10", "novembre": "11", "dicembre": "12"
        }
        
        month = months.get(month_name.lower())
        
        if month:
            return f"{int(day):02d}/{month}/{year}"
    
    return None

def first_info(pattern1, pattern2, csv_paths):
    df_paths = pd.read_csv(csv_paths)

    #df_paths['language'] = ""
    df_paths['object'] = ""
    df_paths['legislature'] = ""
    df_paths['date'] = ""
    df_paths['month'] = ""
    df_paths['class'] = ""

    for idx, row in df_paths.iterrows():
        source_path = row["path_clean"]
        if source_path.endswith(".txt"):
            filename = os.path.basename(source_path)
            filenum = int(os.path.splitext(filename)[0])

            with open(source_path, "r", encoding="utf-8") as file:
                content = file.read()

            match1 = re.search(pattern1, content)

            if match1:
                stringa = match1.group(1).strip()
                ogg, leg = stringa.split("/", 1)

                df_paths.loc[df_paths['ID_file'] == filenum, 'object'] = ogg
                df_paths.loc[df_paths['ID_file'] == filenum, 'legislature'] = leg

            date = extract_and_format_date(content)
            df_paths.loc[df_paths['ID_file'] == filenum, 'date'] = date
            if date:
                df_paths.loc[df_paths['ID_file'] == filenum, 'month'] = date.split("/")[1]
            
            match2 = re.search(pattern2, content, re.DOTALL)
            
            if match2:
                classe = match2.group(1).strip()
                classe = classe.replace("\n", ", ").strip()
                df_paths.loc[df_paths['ID_file'] == filenum, 'class'] = classe

            #try:
            #    lang = detect(content)
            #    if lang == 'fr':
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'fr'
            #    elif lang == 'it':
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'it'
            #    else:
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'other'
            #except:
            #    df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'error'

    df_paths.to_csv(csv_paths, index=False)

def second_info(csv_paths):
    df = pd.read_csv(csv_paths)
    
    if "obj_pos" not in df.columns:
        df["obj_pos"] = 0
    
    df["object"] = pd.to_numeric(df["object"], errors="coerce")  # Converti in numero per ordinamento
    
    df.sort_values(by=["date", "object"], ascending=[True, True], inplace=True)
    
    df["obj_pos"] = df.groupby("date").cumcount() + 1  # Assegna numeri progressivi
    
    df.to_csv(csv_paths, index=False)

# %%
target_folder = "./clean"

csv_paths = "./csv_paths.csv"
csv_details = "./csv_details.csv"
csv_cons = "./csv_cons.csv"
csv_chunks = "./csv_chunks.csv"

# %%
keyword = "Classificazione"
mid_strings = ["Precedente", "Successivo", "Resoconto integrale del dibattito dell'aula. I documenti allegati sono reperibili nel link \"iter atto\"."]
end_keyword = "Informativa cookies"

first_clean(target_folder, keyword, mid_strings, end_keyword, csv_paths)

pattern1 = r'(?:OGGETTO N\.|OBJET N°)(.*?)\s*-'
pattern2 = r'Classificazione\s*(.*?)\s*Oggetto'

first_info(pattern1, pattern2, csv_paths)
second_info(csv_paths)

# %%
import pandas as pd
import re

def define_names(csv_cons, leg):
    df_cons = pd.read_csv(csv_cons)
    df_cons = df_cons.reset_index()  # Aggiunge l'indice come colonna ID_cons
    df_cons.rename(columns={'index': 'ID_cons'}, inplace=True)
    names = []
    
    print(f"Filtrando per legislatura: {leg}")
    filtered_cons = df_cons[df_cons['legislature'].str.contains(leg, case=False, na=False)]
    
    surname_counts = filtered_cons['surname'].value_counts()

    for idx, row in filtered_cons.iterrows():
        surname = row["surname"]
        name = row["name"]
        
        if surname_counts[surname] > 1:
            names.append(f"{surname} {name[0]}.")
        else:
            names.append(surname)
    
    print(f"Numero di nomi trovati per la legislatura {leg}: {len(names)}")
    return filtered_cons, names

def isolate_chunk(csv_paths, csv_cons):
    df_paths = pd.read_csv(csv_paths)
    chunk_list = []

    for idx, row in df_paths.iterrows():
        leg = row["legislature"]
        date = row["date"]
        month = row["month"]
        #language = row["language"]
        obj = row["obj_pos"]
        
        print(f"Processando file {row['path_clean']} per la legislatura {leg}...")
        
        try:
            df_cons, list_cons = define_names(csv_cons, leg)

            with open(row["path_clean"], 'r') as f:
                text = f.read()

                all_matches = []
                for name in list_cons:
                    pattern = r"(?i)" + re.escape(name) + r"\s?\([^)]*\)\s?-"
                    matches = list(re.finditer(pattern, text))
                    all_matches.extend(matches)
                
                president_pattern = r"(?i)Presidente\s?-"
                president_matches = list(re.finditer(president_pattern, text))
                all_matches.extend(president_matches)
                
                all_matches.sort(key=lambda match: match.start())
                
                president_data = None
                if all_matches:
                    first_match = all_matches[0]
                    if not re.match(president_pattern, first_match.group(0), re.IGNORECASE):
                        surname = first_match.group(0)
                        words = surname.split()
                        surname = " ".join(words[:2])
                        if words[1].endswith('.') or words[1].startswith('('):
                            surname = words[0]
                        person_info = df_cons[df_cons["surname"] == surname].iloc[0]
                        president_data = {
                            "ID_cons": person_info["ID_cons"],
                            "year_birth": person_info["year_birth"],
                            "gender": person_info["gender"],
                            "group": 'Presidente',
                            "seniority": len(person_info["legislature"].split(','))
                        }

                chunk_idx = 1
                for i, match in enumerate(all_matches):
                    start_pos = match.end() 
                    end_pos = all_matches[i + 1].start() if i + 1 < len(all_matches) else len(text)

                    chunk = text[start_pos:end_pos].replace("\n", " ").strip()

                    if chunk:
                        if re.match(president_pattern, match.group(0), re.IGNORECASE):
                            if president_data:
                                ID_cons = president_data["ID_cons"]
                                year_birth = president_data["year_birth"]
                                gender = president_data["gender"]
                                group = president_data["group"]
                                seniority = president_data["seniority"]
                            else:
                                ID_cons = "N/A"
                                year_birth = "N/A"
                                gender = "N/A"
                                group = "N/A"
                                seniority = "N/A"
                        else:
                            surname = match.group(0)
                            party = re.search(r'\((.*?)\)', surname)
                            group = party.group(1) if party else "N/A"
                            words = surname.split()
                            surname = " ".join(words[:2])
                            if words[1].endswith('.') or words[1].startswith('('):
                                surname = words[0]
                            try:
                                person_info = df_cons[df_cons["surname"] == surname].iloc[0]
                                ID_cons = person_info["ID_cons"]
                                year_birth = person_info["year_birth"]
                                gender = person_info["gender"]
                                seniority = len(person_info["legislature"].split(','))
                            except IndexError:
                                ID_cons = "N/A"
                                year_birth = "N/A"
                                gender = "N/A"
                                group = "N/A"
                                seniority = "N/A"

                        chunk_list.append({
                            "ID_file": row["ID_file"],
                            "leg": leg,
                            "date": date,
                            "month": month,
                            "class": row["class"],
                            "obj_pos": obj,
                            #"language": language,
                            "ID_cons": ID_cons,
                            "year_birth": year_birth,
                            "gender": gender,
                            "group": group,
                            "seniority": seniority,
                            "position": chunk_idx,
                            "length": len(chunk),
                            "chunk": chunk
                        })
                        
                        chunk_idx += 1
            print('File ok')

        except Exception as e:
            print(f"Errore nel file {row['path_clean']}: {e}. Saltando questa entry.")
            continue

    df_chunks = pd.DataFrame(chunk_list)
    print(f"Numero totale di chunk processati: {len(chunk_list)}")
    return df_chunks

df = isolate_chunk(csv_paths, csv_cons)

print("Salvataggio del file csv_chunks.csv...")
df.to_csv("csv_chunks.csv", index=False)
print("File salvato con successo!")
# Out:
# Processando file ./clean/45461.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45462.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45463.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45464.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45465.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43971.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47801.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47802.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47803.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47804.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47805.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47806.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47807.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47808.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47809.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47810.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47811.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47812.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47813.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47814.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47815.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47816.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47817.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47818.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47819.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47820.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47821.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45161.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45162.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45163.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45164.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45165.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45166.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45167.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45168.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45169.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45170.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45171.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45172.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45173.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45174.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45175.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45176.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45177.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45178.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45179.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45180.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45181.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45182.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45183.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45184.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45185.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45186.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45187.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45188.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45189.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45190.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45191.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45192.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45193.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42561.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42562.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42563.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42564.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42565.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42566.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42567.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42568.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42569.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42570.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42571.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42572.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42573.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42574.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42575.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42576.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42577.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42578.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42579.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/42580.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/
txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43970.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43972.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43973.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43975.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43976.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43977.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43979.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43980.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43982.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43984.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43986.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43987.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43989.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43991.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43993.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/43994.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45277.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/45278.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Numero totale di chunk processati: 34456
# Salvataggio del file csv_chunks.csv...
# File salvato con successo!

# %%
df_chunks = pd.read_csv(csv_chunks)

df_outcomes = df_chunks.copy()
df_outcomes = df_outcomes.drop(columns=['ID_cons','year_birth','gender','group','position','length','chunk'])
df_outcomes = df_outcomes.drop_duplicates(subset=['ID_file'])

intervention_counts = df_chunks.groupby('ID_file').size().reset_index(name='# interventions')
df_outcomes = df_outcomes.merge(intervention_counts, on='ID_file', how='left')

df_chunks_filtered = df_chunks[df_chunks['group'] != 'Presidente']
intervention_counts_filtered = df_chunks_filtered.groupby('ID_file').size().reset_index(name='# interventions (w/o president)')
df_outcomes = df_outcomes.merge(intervention_counts_filtered, on='ID_file', how='left')

length_sum = df_chunks.groupby('ID_file')['length'].sum().reset_index(name='total_length')
df_outcomes = df_outcomes.merge(length_sum, on='ID_file', how='left')

length_sum_filtered = df_chunks_filtered.groupby('ID_file')['length'].sum().reset_index(name='total_length (w/o president)')
df_outcomes = df_outcomes.merge(length_sum_filtered, on='ID_file', how='left')

def extract_number(text, pattern):
    match = re.search(pattern, text)
    if match:
        return int(match.group(1))  
    return None

def get_count(id_file, pattern):
    chunks = df_chunks[(df_chunks['ID_file'] == id_file) & (df_chunks['group'] == 'Presidente')]
    
    for chunk in chunks['chunk']:
        number = extract_number(chunk, pattern)
        if number is not None:
            return number
    
    return None

presenti = r"Presenti: (\d+)"
votanti = r"Votanti: (\d+)"
favorevoli = r"Favorevoli: (\d+)"
contrari = r"Contrari: (\d+)"
astenuti = r"Astenuti: (\d+)"

df_outcomes['presenti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, presenti))
df_outcomes['votanti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, votanti))
df_outcomes['favorevoli'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, favorevoli))
df_outcomes['contrari'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, contrari))
df_outcomes['astenuti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, astenuti))

def determine_outcome(row):
    favorevoli = row['favorevoli'] if pd.notna(row['favorevoli']) else 0
    contrari = row['contrari'] if pd.notna(row['contrari']) else 0
    astenuti = row['astenuti'] if pd.notna(row['astenuti']) else 0

    if pd.isna(row['favorevoli']) and pd.isna(row['contrari']) and pd.isna(row['astenuti']):
        return np.nan

    if favorevoli > contrari and favorevoli > astenuti:
        return 'approvato'
    else:
        return 'non approvato'

df_outcomes['outcome'] = df_outcomes.apply(determine_outcome, axis=1)

df_outcomes.to_csv("csv_outcomes.csv", index=False)

# %%
df = pd.read_csv("csv_chunks.csv")

df_filtered = df[df['group'] != 'Presidente']

df_filtered.to_csv("csv_chunks_filtered.csv", index=False)

# %%
valid_outcomes = df_outcomes[df_outcomes['outcome'].notna()]['ID_file']

df = pd.read_csv("csv_chunks.csv")
df_filtered = df[df['ID_file'].isin(valid_outcomes)]

df_filtered.to_csv("csv_chunks_outcomes.csv", index=False)

df = pd.read_csv("csv_chunks_outcomes.csv")

df_filtered = df[df['group'] != 'Presidente']

df_filtered.to_csv("csv_chunks_outcomes_filtered.csv", index=False)
