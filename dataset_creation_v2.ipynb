# %%
import os
import re
import csv
import pandas as pd
import numpy as np

import time
import requests
from bs4 import BeautifulSoup

#from langdetect import detect
#from deep_translator import GoogleTranslator

# %%
BASE_URL = "https://www.consiglio.vda.it/app/oggettidelconsiglio/dettaglio?pk_documento={}&versione=R"

OUTPUT_FOLDER = "./downloads"
if not os.path.exists(OUTPUT_FOLDER):
    os.makedirs(OUTPUT_FOLDER)

#funzione per scraperare e salvare i resoconti dal sito del consiglio Valle
def scrape_and_save(doc_id):
    url = BASE_URL.format(doc_id)

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Documento {doc_id} non trovato (HTTP {response.status_code}).")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    page_text = soup.get_text(separator="\n", strip=True)

    output_file = os.path.join(OUTPUT_FOLDER, f"{doc_id}.txt")
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(page_text)
    
    print(f"Documento {doc_id} salvato in: {output_file}")
    return output_file


def main(start_id, end_id):
    csv_data = []
    print(f"Inizio lo scraping per i documenti dal {start_id} al {end_id}...")

    for doc_id in range(start_id, end_id + 1):
        print(f"Processo il documento {doc_id}...")
        file_path = scrape_and_save(doc_id)

        if file_path:
            csv_data.append({"ID_file": doc_id, "path_src": file_path})

        # Pausa per evitare di sovraccaricare il server (ad esempio 2-5 secondi)
        time.sleep(2 + (3 * doc_id % 5))  # Variamo la pausa per evitare un pattern troppo prevedibile

    # Salvataggio dei risultati nel file CSV
    csv_file = "csv_paths.csv"
    print(f"Salvataggio dei risultati nel file CSV: {csv_file}")
    with open(csv_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["ID_file", "path_src"])
        writer.writeheader()
        writer.writerows(csv_data)

    print("Completato! Tutti i documenti salvati nella cartella:", OUTPUT_FOLDER)

if __name__ == "__main__":
    main(start_id=46721, end_id=47000)
# Out:
# Inizio lo scraping per i documenti dal 46721 al 47000...
# Processo il documento 46721...
# Documento 46721 salvato in: ./downloads/46721.txt
# Processo il documento 46722...
# Documento 46722 salvato in: ./downloads/46722.txt
# Processo il documento 46723...
# Documento 46723 salvato in: ./downloads/46723.txt
# Processo il documento 46724...
# Documento 46724 salvato in: ./downloads/46724.txt
# Processo il documento 46725...
# Documento 46725 salvato in: ./downloads/46725.txt
# Processo il documento 46726...
# Documento 46726 salvato in: ./downloads/46726.txt
# Processo il documento 46727...
# Documento 46727 salvato in: ./downloads/46727.txt
# Processo il documento 46728...
# Documento 46728 salvato in: ./downloads/46728.txt
# Processo il documento 46729...
# Documento 46729 salvato in: ./downloads/46729.txt
# Processo il documento 46730...
# Documento 46730 salvato in: ./downloads/46730.txt
# Processo il documento 46731...
# Documento 46731 salvato in: ./downloads/46731.txt
# Processo il documento 46732...
# Documento 46732 salvato in: ./downloads/46732.txt
# Processo il documento 46733...
# Documento 46733 salvato in: ./downloads/46733.txt
# Processo il documento 46734...
# Documento 46734 salvato in: ./downloads/46734.txt
# Processo il documento 46735...
# Documento 46735 salvato in: ./downloads/46735.txt
# Processo il documento 46736...
# Documento 46736 salvato in: ./downloads/46736.txt
# Processo il documento 46737...
# Documento 46737 salvato in: ./downloads/46737.txt
# Processo il documento 46738...
# Documento 46738 salvato in: ./downloads/46738.txt
# Processo il documento 46739...
# Documento 46739 salvato in: ./downloads/46739.txt
# Processo il documento 46740...
# Documento 46740 salvato in: ./downloads/46740.txt
# Processo il documento 46741...
# Documento 46741 salvato in: ./downloads/46741.txt
# Processo il documento 46742...
# Documento 46742 salvato in: ./downloads/46742.txt
# Processo il documento 46743...
# Documento 46743 salvato in: ./downloads/46743.txt
# Processo il documento 46744...
# Documento 46744 salvato in: ./downloads/46744.txt
# Processo il documento 46745...
# Documento 46745 salvato in: ./downloads/46745.txt
# Processo il documento 46746...
# Documento 46746 salvato in: ./downloads/46746.txt
# Processo il documento 46747...
# Documento 46747 salvato in: ./downloads/46747.txt
# Processo il documento 46748...
# Documento 46748 salvato in: ./downloads/46748.txt
# Processo il documento 46749...
# Documento 46749 salvato in: ./downloads/46749.txt
# Processo il documento 46750...
# Documento 46750 salvato in: ./downloads/46750.txt
# Processo il documento 46751...
# Documento 46751 salvato in: ./downloads/46751.txt
# Processo il documento 46752...
# Documento 46752 salvato in: ./downloads/46752.txt
# Processo il documento 46753...
# Documento 46753 salvato in: ./downloads/46753.txt
# Processo il documento 46754...
# Documento 46754 salvato in: ./downloads/46754.txt
# Processo il documento 46755...
# Documento 46755 salvato in: ./downloads/46755.txt
# Processo il documento 46756...
# Documento 46756 salvato in: ./downloads/46756.txt
# Processo il documento 46757...
# Documento 46757 salvato in: ./downloads/46757.txt
# Processo il documento 46758...
# Documento 46758 salvato in: ./downloads/46758.txt
# Processo il documento 46759...
# Documento 46759 salvato in: ./downloads/46759.txt
# Processo il documento 46760...
# Documento 46760 salvato in: ./downloads/46760.txt
# Processo il documento 46761...
# Documento 46761 salvato in: ./downloads/46761.txt
# Processo il documento 46762...
# Documento 46762 salvato in: ./downloads/46762.txt
# Processo il documento 46763...
# Documento 46763 salvato in: ./downloads/46763.txt
# Processo il documento 46764...
# Documento 46764 salvato in: ./downloads/46764.txt
# Processo il documento 46765...
# Documento 46765 salvato in: ./downloads/46765.txt
# Processo il documento 46766...
# Documento 46766 salvato in: ./downloads/46766.txt
# Processo il documento 46767...
# Documento 46767 salvato in: ./downloads/46767.txt
# Processo il documento 46768...
# Documento 46768 salvato in: ./downloads/46768.txt
# Processo il documento 46769...
# Documento 46769 salvato in: ./downloads/46769.txt
# Processo il documento 46770...
# Documento 46770 salvato in: ./downloads/46770.txt
# Processo il documento 46771...
# Documento 46771 salvato in: ./downloads/46771.txt
# Processo il documento 46772...
# Documento 46772 salvato in: ./downloads/46772.txt
# Processo il documento 46773...
# Documento 46773 salvato in: ./downloads/46773.txt
# Processo il documento 46774...
# Documento 46774 salvato in: ./downloads/46774.txt
# Processo il documento 46775...
# Documento 46775 salvato in: ./downloads/46775.txt
# Processo il documento 46776...
# Documento 46776 salvato in: ./downloads/46776.txt
# Processo il documento 46777...
# Documento 46777 salvato in: ./downloads/46777.txt
# Processo il documento 46778...
# Documento 46778 salvato in: ./downloads/46778.txt
# Processo il documento 46779...
# Documento 46779 salvato in: ./downloads/46779.txt
# Processo il documento 46780...
# Documento 46780 salvato in: ./downloads/46780.txt
# Processo il documento 46781...
# Documento 46781 salvato in: ./downloads/46781.txt
# Processo il documento 46782...
# Documento 46782 salvato in: ./downloads/46782.txt
# Processo il documento 46783...
# Documento 46783 salvato in: ./downloads/46783.txt
# Processo il documento 46784...
# Documento 46784 salvato in: ./downloads/46784.txt
# Processo il documento 46785...
# Documento 46785 salvato in: ./downloads/46785.txt
# Processo il documento 46786...
# Documento 46786 salvato in: ./downloads/46786.txt
# Processo il documento 46787...
# Documento 46787 non trovato (HTTP 404).
# Processo il documento 46788...
# Documento 46788 non trovato (HTTP 404).
# Processo il documento 46789...
# Documento 46789 non trovato (HTTP 404).
# Processo il documento 46790...
# Documento 46790 non trovato (HTTP 404).
# Processo il documento 46791...
# Documento 46791 non trovato (HTTP 404).
# Processo il documento 46792...
# Documento 46792 non trovato (HTTP 404).
# Processo il documento 46793...
# Documento 46793 non trovato (HTTP 404).
# Processo il documento 46794...
# Documento 46794 non trovato (HTTP 404).
# Processo il documento 46795...
# Documento 46795 non trovato (HTTP 404).
# Processo il documento 46796...
# Documento 46796 non trovato (HTTP 404).
# Processo il documento 46797...
# Documento 46797 non trovato (HTTP 404).
# Processo il documento 46798...
# Documento 46798 non trovato (HTTP 404).
# Processo il documento 46799...
# Documento 46799 non trovato (HTTP 404).
# Processo il documento 46800...
# Documento 46800 non trovato (HTTP 404).
# Processo il documento 46801...
# Documento 46801 salvato in: ./downloads/46801.txt
# Processo il documento 46802...
# Documento 46802 salvato in: ./downloads/46802.txt
# Processo il documento 46803...
# Documento 46803 salvato in: ./downloads/46803.txt
# Processo il documento 46804...
# Documento 46804 salvato in: ./downloads/46804.txt
# Processo il documento 46805...
# Documento 46805 salvato in: ./downloads/46805.txt
# Processo il documento 46806...
# Documento 46806 salvato in: ./downloads/46806.txt
# Processo il documento 46807...
# Documento 46807 salvato in: ./downloads/46807.txt
# Processo il documento 46808...
# Documento 46808 salvato in: ./downloads/46808.txt
# Processo il documento 46809...
# Documento 46809 salvato in: ./downloads/46809.txt
# Processo il documento 46810...
# Documento 46810 salvato in: ./downloads/46810.txt
# Processo il documento 46811...
# Documento 46811 salvato in: ./downloads/46811.txt
# Processo il documento 46812...
# Documento 46812 salvato in: ./downloads/46812.txt
# Processo il documento 46813...
# Documento 46813 salvato in: ./downloads/46813.txt
# Processo il documento 46814...
# Documento 46814 salvato in: ./downloads/46814.txt
# Processo il documento 46815...
# Documento 46815 salvato in: ./downloads/46815.txt
# Processo il documento 46816...
# Documento 46816 salvato in: ./downloads/46816.txt
# Processo il documento 46817...
# Documento 46817 salvato in: ./downloads/46817.txt
# Processo il documento 46818...
# Documento 46818 salvato in: ./downloads/46818.txt
# Processo il documento 46819...
# Documento 46819 salvato in: ./downloads/46819.txt
# Processo il documento 46820...
# Documento 46820 salvato in: ./downloads/46820.txt
# Processo il documento 46821...
# Documento 46821 salvato in: ./downloads/46821.txt
# Processo il documento 46822...
# Documento 46822 salvato in: ./downloads/46822.txt
# Processo il documento 46823...
# Documento 46823 salvato in: ./downloads/46823.txt
# Processo il documento 46824...
# Documento 46824 salvato in: ./downloads/46824.txt
# Processo il documento 46825...
# Documento 46825 non trovato (HTTP 404).
# Processo il documento 46826...
# Documento 46826 non trovato (HTTP 404).
# Processo il documento 46827...
# Documento 46827 non trovato (HTTP 404).
# Processo il documento 46828...
# Documento 46828 non trovato (HTTP 404).
# Processo il documento 46829...
# Documento 46829 non trovato (HTTP 404).
# Processo il documento 46830...
# Documento 46830 non trovato (HTTP 404).
# Processo il documento 46831...
# Documento 46831 non trovato (HTTP 404).
# Processo il documento 46832...
# Documento 46832 non trovato (HTTP 404).
# Processo il documento 46833...
# Documento 46833 non trovato (HTTP 404).
# Processo il documento 46834...
# Documento 46834 non trovato (HTTP 404).
# Processo il documento 46835...
# Documento 46835 non trovato (HTTP 404).
# Processo il documento 46836...
# Documento 46836 non trovato (HTTP 404).
# Processo il documento 46837...
# Documento 46837 non trovato (HTTP 404).
# Processo il documento 46838...
# Documento 46838 non trovato (HTTP 404).
# Processo il documento 46839...
# Documento 46839 non trovato (HTTP 404).
# Processo il documento 46840...
# Documento 46840 non trovato (HTTP 404).
# Processo il documento 46841...
# Documento 46841 salvato in: ./downloads/46841.txt
# Processo il documento 46842...
# Documento 46842 salvato in: ./downloads/46842.txt
# Processo il documento 46843...
# Documento 46843 salvato in: ./downloads/46843.txt
# Processo il documento 46844...
# Documento 46844 salvato in: ./downloads/46844.txt
# Processo il documento 46845...
# Documento 46845 salvato in: ./downloads/46845.txt
# Processo il documento 46846...
# Documento 46846 salvato in: ./downloads/46846.txt
# Processo il documento 46847...
# Documento 46847 salvato in: ./downloads/46847.txt
# Processo il documento 46848...
# Documento 46848 salvato in: ./downloads/46848.txt
# Processo il documento 46849...
# Documento 46849 salvato in: ./downloads/46849.txt
# Processo il documento 46850...
# Documento 46850 salvato in: ./downloads/46850.txt
# Processo il documento 46851...
# Documento 46851 salvato in: ./downloads/46851.txt
# Processo il documento 46852...
# Documento 46852 salvato in: ./downloads/46852.txt
# Processo il documento 46853...
# Documento 46853 salvato in: ./downloads/46853.txt
# Processo il documento 46854...
# Documento 46854 salvato in: ./downloads/46854.txt
# Processo il documento 46855...
# Documento 46855 salvato in: ./downloads/46855.txt
# Processo il documento 46856...
# Documento 46856 salvato in: ./downloads/46856.txt
# Processo il documento 46857...
# Documento 46857 salvato in: ./downloads/46857.txt
# Processo il documento 46858...
# Documento 46858 salvato in: ./downloads/46858.txt
# Processo il documento 46859...
# Documento 46859 salvato in: ./downloads/46859.txt
# Processo il documento 46860...
# Documento 46860 salvato in: ./downloads/46860.txt
# Processo il documento 46861...
# Documento 46861 salvato in: ./downloads/46861.txt
# Processo il documento 46862...
# Documento 46862 salvato in: ./downloads/46862.txt
# Processo il documento 46863...
# Documento 46863 salvato in: ./downloads/46863.txt
# Processo il documento 46864...
# Documento 46864 salvato in: ./downloads/46864.txt
# Processo il documento 46865...
# Documento 46865 salvato in: ./downloads/46865.txt
# Processo il documento 46866...
# Documento 46866 salvato in: ./downloads/46866.txt
# Processo il documento 46867...
# Documento 46867 salvato in: ./downloads/46867.txt
# Processo il documento 46868...
# Documento 46868 salvato in: ./downloads/46868.txt
# Processo il documento 46869...
# Documento 46869 salvato in: ./downloads/46869.txt
# Processo il documento 46870...
# Documento 46870 salvato in: ./downloads/46870.txt
# Processo il documento 46871...
# Documento 46871 salvato in: ./downloads/46871.txt
# Processo il documento 46872...
# Documento 46872 salvato in: ./downloads/46872.txt
# Processo il documento 46873...
# Documento 46873 salvato in: ./downloads/46873.txt
# Processo il documento 46874...
# Documento 46874 salvato in: ./downloads/46874.txt
# Processo il documento 46875...
# Documento 46875 salvato in: ./downloads/46875.txt
# Processo il documento 46876...
# Documento 46876 salvato in: ./downloads/46876.txt
# Processo il documento 46877...
# Documento 46877 salvato in: ./downloads/46877.txt
# Processo il documento 46878...
# Documento 46878 salvato in: ./downloads/46878.txt
# Processo il documento 46879...
# Documento 46879 salvato in: ./downloads/46879.txt
# Processo il documento 46880...
# Documento 46880 salvato in: ./downloads/46880.txt
# Processo il documento 46881...
# Documento 46881 salvato in: ./downloads/46881.txt
# Processo il documento 46882...
# Documento 46882 salvato in: ./downloads/46882.txt
# Processo il documento 46883...
# Documento 46883 salvato in: ./downloads/46883.txt
# Processo il documento 46884...
# Documento 46884 salvato in: ./downloads/46884.txt
# Processo il documento 46885...
# Documento 46885 salvato in: ./downloads/46885.txt
# Processo il documento 46886...
# Documento 46886 salvato in: ./downloads/46886.txt
# Processo il documento 46887...
# Documento 46887 salvato in: ./downloads/46887.txt
# Processo il documento 46888...
# Documento 46888 salvato in: ./downloads/46888.txt
# Processo il documento 46889...
# Documento 46889 salvato in: ./downloads/46889.txt
# Processo il documento 46890...
# Documento 46890 salvato in: ./downloads/46890.txt
# Processo il documento 46891...
# Documento 46891 salvato in: ./downloads/46891.txt
# Processo il documento 46892...
# Documento 46892 salvato in: ./downloads/46892.txt
# Processo il documento 46893...
# Documento 46893 salvato in: ./downloads/46893.txt
# Processo il documento 46894...
# Documento 46894 salvato in: ./downloads/46894.txt
# Processo il documento 46895...
# Documento 46895 salvato in: ./downloads/46895.txt
# Processo il documento 46896...
# Documento 46896 salvato in: ./downloads/46896.txt
# Processo il documento 46897...
# Documento 46897 salvato in: ./downloads/46897.txt
# Processo il documento 46898...
# Documento 46898 salvato in: ./downloads/46898.txt
# Processo il documento 46899...
# Documento 46899 salvato in: ./downloads/46899.txt
# Processo il documento 46900...
# Documento 46900 salvato in: ./downloads/46900.txt
# Processo il documento 46901...
# Documento 46901 salvato in: ./downloads/46901.txt
# Processo il documento 46902...
# Documento 46902 salvato in: ./downloads/46902.txt
# Processo il documento 46903...
# Documento 46903 salvato in: ./downloads/46903.txt
# Processo il documento 46904...
# Documento 46904 salvato in: ./downloads/46904.txt
# Processo il documento 46905...
# Documento 46905 salvato in: ./downloads/46905.txt
# Processo il documento 46906...
# Documento 46906 salvato in: ./downloads/46906.txt
# Processo il documento 46907...
# Documento 46907 salvato in: ./downloads/46907.txt
# Processo il documento 46908...
# Documento 46908 salvato in: ./downloads/46908.txt
# Processo il documento 46909...
# Documento 46909 salvato in: ./downloads/46909.txt
# Processo il documento 46910...
# Documento 46910 salvato in: ./downloads/46910.txt
# Processo il documento 46911...
# Documento 46911 salvato in: ./downloads/46911.txt
# Processo il documento 46912...
# Documento 46912 salvato in: ./downloads/46912.txt
# Processo il documento 46913...
# Documento 46913 salvato in: ./downloads/46913.txt
# Processo il documento 46914...
# Documento 46914 salvato in: ./downloads/46914.txt
# Processo il documento 46915...
# Documento 46915 salvato in: ./downloads/46915.txt
# Processo il documento 46916...
# Documento 46916 salvato in: ./downloads/46916.txt
# Processo il documento 46917...
# Documento 46917 salvato in: ./downloads/46917.txt
# Processo il documento 46918...
# Documento 46918 salvato in: ./downloads/46918.txt
# Processo il documento 46919...
# Documento 46919 salvato in: ./downloads/46919.txt
# Processo il documento 46920...
# Documento 46920 salvato in: ./downloads/46920.txt
# Processo il documento 46921...
# Documento 46921 salvato in: ./downloads/46921.txt
# Processo il documento 46922...
# Documento 46922 salvato in: ./downloads/46922.txt
# Processo il documento 46923...
# Documento 46923 salvato in: ./downloads/46923.txt
# Processo il documento 46924...
# Documento 46924 salvato in: ./downloads/46924.txt
# Processo il documento 46925...
# Documento 46925 salvato in: ./downloads/46925.txt
# Processo il documento 46926...
# Documento 46926 salvato in: ./downloads/46926.txt
# Processo il documento 46927...
# Documento 46927 salvato in: ./downloads/46927.txt
# Processo il documento 46928...
# Documento 46928 salvato in: ./downloads/46928.txt
# Processo il documento 46929...
# Documento 46929 salvato in: ./downloads/46929.txt
# Processo il documento 46930...
# Documento 46930 salvato in: ./downloads/46930.txt
# Processo il documento 46931...
# Documento 46931 salvato in: ./downloads/46931.txt
# Processo il documento 46932...
# Documento 46932 salvato in: ./downloads/46932.txt
# Processo il documento 46933...
# Documento 46933 salvato in: ./downloads/46933.txt
# Processo il documento 46934...
# Documento 46934 salvato in: ./downloads/46934.txt
# Processo il documento 46935...
# Documento 46935 salvato in: ./downloads/46935.txt
# Processo il documento 46936...
# Documento 46936 salvato in: ./downloads/46936.txt
# Processo il documento 46937...
# Documento 46937 salvato in: ./downloads/46937.txt
# Processo il documento 46938...
# Documento 46938 salvato in: ./downloads/46938.txt
# Processo il documento 46939...
# Documento 46939 salvato in: ./downloads/46939.txt
# Processo il documento 46940...
# Documento 46940 salvato in: ./downloads/46940.txt
# Processo il documento 46941...
# Documento 46941 salvato in: ./downloads/46941.txt
# Processo il documento 46942...
# Documento 46942 salvato in: ./downloads/46942.txt
# Processo il documento 46943...
# Documento 46943 salvato in: ./downloads/46943.txt
# Processo il documento 46944...
# Documento 46944 salvato in: ./downloads/46944.txt
# Processo il documento 46945...
# Documento 46945 salvato in: ./downloads/46945.txt
# Processo il documento 46946...
# Documento 46946 salvato in: ./downloads/46946.txt
# Processo il documento 46947...
# Documento 46947 salvato in: ./downloads/46947.txt
# Processo il documento 46948...
# Documento 46948 salvato in: ./downloads/46948.txt
# Processo il documento 46949...
# Documento 46949 salvato in: ./downloads/46949.txt
# Processo il documento 46950...
# Documento 46950 salvato in: ./downloads/46950.txt
# Processo il documento 46951...
# Documento 46951 salvato in: ./downloads/46951.txt
# Processo il documento 46952...
# Documento 46952 salvato in: ./downloads/46952.txt
# Processo il documento 46953...
# Documento 46953 salvato in: ./downloads/46953.txt
# Processo il documento 46954...
# Documento 46954 salvato in: ./downloads/46954.txt
# Processo il documento 46955...
# Documento 46955 salvato in: ./downloads/46955.txt
# Processo il documento 46956...
# Documento 46956 salvato in: ./downloads/46956.txt
# Processo il documento 46957...
# Documento 46957 salvato in: ./downloads/46957.txt
# Processo il documento 46958...
# Documento 46958 salvato in: ./downloads/46958.txt
# Processo il documento 46959...
# Documento 46959 salvato in: ./downloads/46959.txt
# Processo il documento 46960...
# Documento 46960 salvato in: ./downloads/46960.txt
# Processo il documento 46961...
# Documento 46961 salvato in: ./downloads/46961.txt
# Processo il documento 46962...
# Documento 46962 salvato in: ./downloads/46962.txt
# Processo il documento 46963...
# Documento 46963 salvato in: ./downloads/46963.txt
# Processo il documento 46964...
# Documento 46964 salvato in: ./downloads/46964.txt
# Processo il documento 46965...
# Documento 46965 salvato in: ./downloads/46965.txt
# Processo il documento 46966...
# Documento 46966 salvato in: ./downloads/46966.txt
# Processo il documento 46967...
# Documento 46967 salvato in: ./downloads/46967.txt
# Processo il documento 46968...
# Documento 46968 salvato in: ./downloads/46968.txt
# Processo il documento 46969...
# Documento 46969 salvato in: ./downloads/46969.txt
# Processo il documento 46970...
# Documento 46970 salvato in: ./downloads/46970.txt
# Processo il documento 46971...
# Documento 46971 salvato in: ./downloads/46971.txt
# Processo il documento 46972...
# Documento 46972 salvato in: ./downloads/46972.txt
# Processo il documento 46973...
# Documento 46973 salvato in: ./downloads/46973.txt
# Processo il documento 46974...
# Documento 46974 salvato in: ./downloads/46974.txt
# Processo il documento 46975...
# Documento 46975 salvato in: ./downloads/46975.txt
# Processo il documento 46976...
# Documento 46976 salvato in: ./downloads/46976.txt
# Processo il documento 46977...
# Documento 46977 salvato in: ./downloads/46977.txt
# Processo il documento 46978...
# Documento 46978 salvato in: ./downloads/46978.txt
# Processo il documento 46979...
# Documento 46979 salvato in: ./downloads/46979.txt
# Processo il documento 46980...
# Documento 46980 salvato in: ./downloads/46980.txt
# Processo il documento 46981...
# Documento 46981 salvato in: ./downloads/46981.txt
# Processo il documento 46982...
# Documento 46982 salvato in: ./downloads/46982.txt
# Processo il documento 46983...
# Documento 46983 salvato in: ./downloads/46983.txt
# Processo il documento 46984...
# Documento 46984 salvato in: ./downloads/46984.txt
# Processo il documento 46985...
# Documento 46985 salvato in: ./downloads/46985.txt
# Processo il documento 46986...
# Documento 46986 salvato in: ./downloads/46986.txt
# Processo il documento 46987...
# Documento 46987 salvato in: ./downloads/46987.txt
# Processo il documento 46988...
# Documento 46988 salvato in: ./downloads/46988.txt
# Processo il documento 46989...
# Documento 46989 salvato in: ./downloads/46989.txt
# Processo il documento 46990...
# Documento 46990 salvato in: ./downloads/46990.txt
# Processo il documento 46991...
# Documento 46991 salvato in: ./downloads/46991.txt
# Processo il documento 46992...
# Documento 46992 salvato in: ./downloads/46992.txt
# Processo il documento 46993...
# Documento 46993 salvato in: ./downloads/46993.txt
# Processo il documento 46994...
# Documento 46994 salvato in: ./downloads/46994.txt
# Processo il documento 46995...
# Documento 46995 salvato in: ./downloads/46995.txt
# Processo il documento 46996...
# Documento 46996 salvato in: ./downloads/46996.txt
# Processo il documento 46997...
# Documento 46997 salvato in: ./downloads/46997.txt
# Processo il documento 46998...
# Documento 46998 salvato in: ./downloads/46998.txt
# Processo il documento 46999...
# Documento 46999 salvato in: ./downloads/46999.txt
# Processo il documento 47000...
# Documento 47000 salvato in: ./downloads/47000.txt
# Salvataggio dei risultati nel file CSV: csv_paths.csv
# Completato! Tutti i documenti salvati nella cartella: ./downloads

# %%
def generate_csv_from_folder(folder_path, csv_file="csv_paths.csv"):
    csv_data = []
    
    # Verifica che la cartella esista
    if not os.path.exists(folder_path):
        print(f"La cartella {folder_path} non esiste.")
        return
    
    # Scansiona la cartella per trovare i file
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        
        if os.path.isfile(file_path):  # Assicuriamoci che sia un file e non una cartella
            file_id, _ = os.path.splitext(file_name)  # Rimuove l'estensione
            csv_data.append({"ID_file": file_id, "path_src": file_path})
    
    # Salvataggio dei dati in un file CSV
    with open(csv_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["ID_file", "path_src"])
        writer.writeheader()
        writer.writerows(csv_data)
    
    print(f"File CSV creato con successo: {csv_file}")

# Esempio di utilizzo
folder_path = "./downloads"  # Modifica con il percorso della tua cartella
generate_csv_from_folder(folder_path)
# Out:
# File CSV creato con successo: csv_paths.csv

# %%
#funzione per pulire i file txt dalle parti inutili presenti nella pagina web del consiglio Valle
def first_clean(target_folder, keyword, mid_strings, end_keyword, csv_paths):
    df = pd.read_csv(csv_paths)

    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    df["path_clean"] = ""

    for idx, row in df.iterrows():
        source_path = row["path_src"]
        if source_path.endswith(".txt"):
            filename = os.path.basename(source_path)
            target_path = os.path.join(target_folder, filename)

            df.at[idx, "path_clean"] = target_path

            with open(source_path, "r", encoding="utf-8") as file:
                content = file.read()

            if keyword in content:
                content = keyword + content.split(keyword, 1)[1] 

            for mid_string in mid_strings:
                content = re.sub(re.escape(mid_string), "", content) 

            if end_keyword in content:
                content = content.split(end_keyword, 1)[0]  

            with open(target_path, "w", encoding="utf-8") as file:
                file.write(content)

    df.to_csv(csv_paths, index=False)

#funzione per estrarre informazioni dai file txt: oggetto, legislatura, data e classificazione
def extract_and_format_date(text):
    
    date_pattern = re.search(r"(\d{1,2})\s+([a-zA-Z]+)\s+(\d{4})", text)
    
    if date_pattern:
        day, month_name, year = date_pattern.groups()
        
        months = {
            "gennaio": "01", "febbraio": "02", "marzo": "03", "aprile": "04", "maggio": "05", "giugno": "06",
            "luglio": "07", "agosto": "08", "settembre": "09", "ottobre": "10", "novembre": "11", "dicembre": "12"
        }
        
        month = months.get(month_name.lower())
        
        if month:
            return f"{int(day):02d}/{month}/{year}"
    
    return None

def first_info(pattern1, pattern2, csv_paths):
    df_paths = pd.read_csv(csv_paths)

    #df_paths['language'] = ""
    df_paths['object'] = ""
    df_paths['legislature'] = ""
    df_paths['date'] = ""
    df_paths['month'] = ""
    df_paths['class'] = ""

    for idx, row in df_paths.iterrows():
        source_path = row["path_clean"]
        if source_path.endswith(".txt"):
            filename = os.path.basename(source_path)
            filenum = int(os.path.splitext(filename)[0])

            with open(source_path, "r", encoding="utf-8") as file:
                content = file.read()

            match1 = re.search(pattern1, content)

            if match1:
                stringa = match1.group(1).strip()
                ogg, leg = stringa.split("/", 1)

                df_paths.loc[df_paths['ID_file'] == filenum, 'object'] = ogg
                df_paths.loc[df_paths['ID_file'] == filenum, 'legislature'] = leg

            date = extract_and_format_date(content)
            df_paths.loc[df_paths['ID_file'] == filenum, 'date'] = date
            df_paths.loc[df_paths['ID_file'] == filenum, 'month'] = date.split("/")[1]
            
            match2 = re.search(pattern2, content, re.DOTALL)
            
            if match2:
                classe = match2.group(1).strip()
                classe = classe.replace("\n", ", ").strip()
                df_paths.loc[df_paths['ID_file'] == filenum, 'class'] = classe

            #try:
            #    lang = detect(content)
            #    if lang == 'fr':
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'fr'
            #    elif lang == 'it':
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'it'
            #    else:
            #        df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'other'
            #except:
            #    df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'error'

    df_paths.to_csv(csv_paths, index=False)

def second_info(csv_paths):
    df = pd.read_csv(csv_paths)
    
    if "obj_pos" not in df.columns:
        df["obj_pos"] = 0
    
    df["object"] = pd.to_numeric(df["object"], errors="coerce")  # Converti in numero per ordinamento
    
    df.sort_values(by=["date", "object"], ascending=[True, True], inplace=True)
    
    df["obj_pos"] = df.groupby("date").cumcount() + 1  # Assegna numeri progressivi
    
    df.to_csv(csv_paths, index=False)

# %%
target_folder = "./clean"

csv_paths = "./csv_paths.csv"
csv_details = "./csv_details.csv"
csv_cons = "./csv_cons.csv"
csv_chunks = "./csv_chunks.csv"

# %%
keyword = "Classificazione"
mid_strings = ["Precedente", "Successivo", "Resoconto integrale del dibattito dell'aula. I documenti allegati sono reperibili nel link \"iter atto\"."]
end_keyword = "Informativa cookies"

first_clean(target_folder, keyword, mid_strings, end_keyword, csv_paths)

pattern1 = r'(?:OGGETTO N\.|OBJET N°)(.*?)\s*-'
pattern2 = r'Classificazione\s*(.*?)\s*Oggetto'

first_info(pattern1, pattern2, csv_paths)
second_info(csv_paths)

# %%
import pandas as pd
import re

def define_names(csv_cons, leg):
    df_cons = pd.read_csv(csv_cons)
    df_cons = df_cons.reset_index()  # Aggiunge l'indice come colonna ID_cons
    df_cons.rename(columns={'index': 'ID_cons'}, inplace=True)
    names = []
    
    print(f"Filtrando per legislatura: {leg}")
    filtered_cons = df_cons[df_cons['legislature'].str.contains(leg, case=False, na=False)]
    
    surname_counts = filtered_cons['surname'].value_counts()

    for idx, row in filtered_cons.iterrows():
        surname = row["surname"]
        name = row["name"]
        
        if surname_counts[surname] > 1:
            names.append(f"{surname} {name[0]}.")
        else:
            names.append(surname)
    
    print(f"Numero di nomi trovati per la legislatura {leg}: {len(names)}")
    return filtered_cons, names

def isolate_chunk(csv_paths, csv_cons):
    df_paths = pd.read_csv(csv_paths)
    chunk_list = []

    for idx, row in df_paths.iterrows():
        leg = row["legislature"]
        date = row["date"]
        month = row["month"]
        #language = row["language"]
        obj = row["obj_pos"]
        
        print(f"Processando file {row['path_clean']} per la legislatura {leg}...")
        
        try:
            df_cons, list_cons = define_names(csv_cons, leg)

            with open(row["path_clean"], 'r') as f:
                text = f.read()

                all_matches = []
                for name in list_cons:
                    pattern = r"(?i)" + re.escape(name) + r"\s?\([^)]*\)\s?-"
                    matches = list(re.finditer(pattern, text))
                    all_matches.extend(matches)
                
                president_pattern = r"(?i)Presidente\s?-"
                president_matches = list(re.finditer(president_pattern, text))
                all_matches.extend(president_matches)
                
                all_matches.sort(key=lambda match: match.start())
                
                president_data = None
                if all_matches:
                    first_match = all_matches[0]
                    if not re.match(president_pattern, first_match.group(0), re.IGNORECASE):
                        surname = first_match.group(0)
                        words = surname.split()
                        surname = " ".join(words[:2])
                        if words[1].endswith('.') or words[1].startswith('('):
                            surname = words[0]
                        person_info = df_cons[df_cons["surname"] == surname].iloc[0]
                        president_data = {
                            "ID_cons": person_info["ID_cons"],
                            "year_birth": person_info["year_birth"],
                            "gender": person_info["gender"],
                            "group": 'Presidente',
                            "seniority": len(person_info["legislature"].split(','))
                        }

                chunk_idx = 1
                for i, match in enumerate(all_matches):
                    start_pos = match.end() 
                    end_pos = all_matches[i + 1].start() if i + 1 < len(all_matches) else len(text)

                    chunk = text[start_pos:end_pos].replace("\n", " ").strip()

                    if chunk:
                        if re.match(president_pattern, match.group(0), re.IGNORECASE):
                            if president_data:
                                ID_cons = president_data["ID_cons"]
                                year_birth = president_data["year_birth"]
                                gender = president_data["gender"]
                                group = president_data["group"]
                                seniority = president_data["seniority"]
                            else:
                                ID_cons = "N/A"
                                year_birth = "N/A"
                                gender = "N/A"
                                group = "N/A"
                                seniority = "N/A"
                        else:
                            surname = match.group(0)
                            party = re.search(r'\((.*?)\)', surname)
                            group = party.group(1) if party else "N/A"
                            words = surname.split()
                            surname = " ".join(words[:2])
                            if words[1].endswith('.') or words[1].startswith('('):
                                surname = words[0]
                            try:
                                person_info = df_cons[df_cons["surname"] == surname].iloc[0]
                                ID_cons = person_info["ID_cons"]
                                year_birth = person_info["year_birth"]
                                gender = person_info["gender"]
                                seniority = len(person_info["legislature"].split(','))
                            except IndexError:
                                ID_cons = "N/A"
                                year_birth = "N/A"
                                gender = "N/A"
                                group = "N/A"
                                seniority = "N/A"

                        chunk_list.append({
                            "ID_file": row["ID_file"],
                            "leg": leg,
                            "date": date,
                            "month": month,
                            "class": row["class"],
                            "obj_pos": obj,
                            #"language": language,
                            "ID_cons": ID_cons,
                            "year_birth": year_birth,
                            "gender": gender,
                            "group": group,
                            "seniority": seniority,
                            "position": chunk_idx,
                            "length": len(chunk),
                            "chunk": chunk
                        })
                        
                        chunk_idx += 1
            print('File ok')

        except Exception as e:
            print(f"Errore nel file {row['path_clean']}: {e}. Saltando questa entry.")
            continue

    df_chunks = pd.DataFrame(chunk_list)
    print(f"Numero totale di chunk processati: {len(chunk_list)}")
    return df_chunks

df = isolate_chunk(csv_paths, csv_cons)

print("Salvataggio del file csv_chunks.csv...")
df.to_csv("csv_chunks.csv", index=False)
print("File salvato con successo!")
# Out:
# Processando file ./clean/47801.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47802.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47803.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47804.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47805.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47806.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47807.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47808.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47809.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47810.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47811.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47812.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47813.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47814.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47815.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47816.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47817.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47818.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47819.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47820.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47821.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47161.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47162.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47163.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47164.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47165.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47166.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47167.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47168.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47169.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47170.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47171.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47172.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47173.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47174.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47175.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47176.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47177.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47178.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47179.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47180.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47181.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47182.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47183.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47184.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47185.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47186.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47187.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47188.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47189.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47190.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47191.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47192.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47193.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47194.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47195.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47196.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47197.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47198.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47199.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47200.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47201.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47202.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47203.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47204.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47205.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47206.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47822.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47823.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47824.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47825.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47826.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47827.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47828.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47829.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47830.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47831.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47832.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47833.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47834.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47835.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47836.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47837.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47838.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47839.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47840.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47841.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47842.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47843.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47844.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47845.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47846.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47847.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47848.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47849.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47850.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47851.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47852.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47853.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47854.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47855.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47856.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47857.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47858.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47859.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47207.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47208.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47209.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47210.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47211.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47212.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47213.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47214.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47215.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47216.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47217.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47218.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47219.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47220.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47401.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47402.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47403.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47404.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47405.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47406.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47881.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47882.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47883.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47884.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47885.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47886.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47887.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47888.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47889.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47890.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47891.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47892.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47893.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47894.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47895.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47896.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47897.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47021.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47022.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47023.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47024.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47025.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47026.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47027.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47028.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47407.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47408.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47409.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47410.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47411.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47412.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47413.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47414.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47415.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47416.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47417.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47418.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47419.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47420.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47421.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47422.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47423.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47424.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47425.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47426.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47427.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47428.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47429.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47430.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47431.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47432.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47433.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47434.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47435.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47436.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47437.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47898.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47899.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47900.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47901.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47902.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47903.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47904.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47905.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47906.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47907.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47908.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47909.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47910.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47911.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47912.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47913.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47914.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47915.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47916.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47917.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47918.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47919.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47920.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47921.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47922.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47923.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47924.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47925.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47926.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47927.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47928.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47929.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47930.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47931.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47932.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47933.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47934.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47935.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47936.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46841.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46842.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46843.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46844.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46845.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46846.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46847.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46848.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46849.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46850.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46851.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46852.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46853.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46854.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46855.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46856.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46857.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46858.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46859.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46860.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46861.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46862.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46863.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46864.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46865.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46866.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46867.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46868.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46869.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46870.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46871.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46872.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46873.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46874.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46875.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46876.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46877.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46878.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46879.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46880.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46881.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46882.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46883.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46884.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47029.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47030.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47031.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47032.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47033.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47034.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47035.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47036.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47037.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47038.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47039.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47040.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47041.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47042.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47043.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47044.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47045.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47046.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47047.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47048.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47049.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47050.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47051.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47052.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47053.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47054.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47055.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47056.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47057.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47058.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47059.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47060.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47061.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47062.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47063.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47064.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47065.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47066.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47067.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47068.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47937.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47938.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47939.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47940.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47941.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47942.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47943.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47944.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47945.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47946.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47947.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47948.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47949.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47950.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47951.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# Errore nel file ./clean/47951.txt: single positional indexer is out-of-bounds. Saltando questa entry.
# ...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47395.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47396.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47397.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47601.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47602.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47603.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47604.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47605.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47606.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47607.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47608.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47609.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47610.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47611.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46801.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46802.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46803.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46804.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46805.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47621.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47622.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47623.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47624.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47625.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47626.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47627.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47628.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47629.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47630.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47631.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47632.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47633.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47634.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47635.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47636.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47637.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47638.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47639.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47640.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47641.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47642.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47661.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47662.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47663.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47664.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47665.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47666.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47667.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47668.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47669.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47670.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47671.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47672.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47673.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47674.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47675.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47676.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47677.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47678.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47679.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47680.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46806.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46807.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46808.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46809.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46810.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46811.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46812.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46813.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46814.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46815.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46816.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46817.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46818.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46819.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46820.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46821.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46822.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46823.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/46824.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47681.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47682.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47683.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47684.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47685.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47686.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47687.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47688.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47689.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47690.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47691.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47692.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47701.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47702.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47703.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47704.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47705.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47706.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47707.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47708.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47709.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47710.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47711.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47712.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47713.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Numero totale di chunk processati: 9197
# Salvataggio del file csv_chunks.csv...
# File salvato con successo!

# %%
df_chunks = pd.read_csv(csv_chunks)

df_outcomes = df_chunks.copy()
df_outcomes = df_outcomes.drop(columns=['ID_cons','year_birth','gender','group','position','length','chunk'])
df_outcomes = df_outcomes.drop_duplicates(subset=['ID_file'])

intervention_counts = df_chunks.groupby('ID_file').size().reset_index(name='# interventions')
df_outcomes = df_outcomes.merge(intervention_counts, on='ID_file', how='left')

df_chunks_filtered = df_chunks[df_chunks['group'] != 'Presidente']
intervention_counts_filtered = df_chunks_filtered.groupby('ID_file').size().reset_index(name='# interventions (w/o president)')
df_outcomes = df_outcomes.merge(intervention_counts_filtered, on='ID_file', how='left')

length_sum = df_chunks.groupby('ID_file')['length'].sum().reset_index(name='total_length')
df_outcomes = df_outcomes.merge(length_sum, on='ID_file', how='left')

length_sum_filtered = df_chunks_filtered.groupby('ID_file')['length'].sum().reset_index(name='total_length (w/o president)')
df_outcomes = df_outcomes.merge(length_sum_filtered, on='ID_file', how='left')

def extract_number(text, pattern):
    match = re.search(pattern, text)
    if match:
        return int(match.group(1))  
    return None

def get_count(id_file, pattern):
    chunks = df_chunks[(df_chunks['ID_file'] == id_file) & (df_chunks['group'] == 'Presidente')]
    
    for chunk in chunks['chunk']:
        number = extract_number(chunk, pattern)
        if number is not None:
            return number
    
    return None

presenti = r"Presenti: (\d+)"
votanti = r"Votanti: (\d+)"
favorevoli = r"Favorevoli: (\d+)"
contrari = r"Contrari: (\d+)"
astenuti = r"Astenuti: (\d+)"

df_outcomes['presenti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, presenti))
df_outcomes['votanti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, votanti))
df_outcomes['favorevoli'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, favorevoli))
df_outcomes['contrari'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, contrari))
df_outcomes['astenuti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, astenuti))

def determine_outcome(row):
    favorevoli = row['favorevoli'] if pd.notna(row['favorevoli']) else 0
    contrari = row['contrari'] if pd.notna(row['contrari']) else 0
    astenuti = row['astenuti'] if pd.notna(row['astenuti']) else 0

    if pd.isna(row['favorevoli']) and pd.isna(row['contrari']) and pd.isna(row['astenuti']):
        return np.nan

    if favorevoli > contrari and favorevoli > astenuti:
        return 'approvato'
    else:
        return 'non approvato'

df_outcomes['outcome'] = df_outcomes.apply(determine_outcome, axis=1)

df_outcomes.to_csv("csv_outcomes.csv", index=False)

# %%
df = pd.read_csv("csv_chunks.csv")

df_filtered = df[df['group'] != 'Presidente']

df_filtered.to_csv("csv_chunks_filtered.csv", index=False)

# %%
valid_outcomes = df_outcomes[df_outcomes['outcome'].notna()]['ID_file']

df = pd.read_csv("csv_chunks.csv")
df_filtered = df[df['ID_file'].isin(valid_outcomes)]

df_filtered.to_csv("csv_chunks_outcomes.csv", index=False)

df = pd.read_csv("csv_chunks_outcomes.csv")

df_filtered = df[df['group'] != 'Presidente']

df_filtered.to_csv("csv_chunks_outcomes_filtered.csv", index=False)
