# %%
import os
import re
import csv
import pandas as pd
import numpy as np

import time
import requests
from bs4 import BeautifulSoup

from langdetect import detect
from deep_translator import GoogleTranslator

# %%
BASE_URL = "https://www.consiglio.vda.it/app/oggettidelconsiglio/dettaglio?pk_documento={}&versione=R"

OUTPUT_FOLDER = "./downloads"
if not os.path.exists(OUTPUT_FOLDER):
    os.makedirs(OUTPUT_FOLDER)

#funzione per scraperare e salvare i resoconti dal sito del consiglio Valle
def scrape_and_save(doc_id):
    url = BASE_URL.format(doc_id)

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Documento {doc_id} non trovato (HTTP {response.status_code}).")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    page_text = soup.get_text(separator="\n", strip=True)

    output_file = os.path.join(OUTPUT_FOLDER, f"{doc_id}.txt")
    with open(output_file, "w", encoding="utf-8") as f:
        f.write(page_text)
    
    print(f"Documento {doc_id} salvato in: {output_file}")
    return output_file


def main(start_id, end_id):
    csv_data = []
    print(f"Inizio lo scraping per i documenti dal {start_id} al {end_id}...")

    for doc_id in range(start_id, end_id + 1):
        print(f"Processo il documento {doc_id}...")
        file_path = scrape_and_save(doc_id)

        if file_path:
            csv_data.append({"ID_file": doc_id, "path_src": file_path})

        # Pausa per evitare di sovraccaricare il server (ad esempio 2-5 secondi)
        time.sleep(2 + (3 * doc_id % 5))  # Variamo la pausa per evitare un pattern troppo prevedibile

    # Salvataggio dei risultati nel file CSV
    csv_file = "csv_paths.csv"
    print(f"Salvataggio dei risultati nel file CSV: {csv_file}")
    with open(csv_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["ID_file", "path_src"])
        writer.writeheader()
        writer.writerows(csv_data)

    print("Completato! Tutti i documenti salvati nella cartella:", OUTPUT_FOLDER)

if __name__ == "__main__":
    main(start_id=47000, end_id=47500)
# Out:
# Inizio lo scraping per i documenti dal 47000 al 47500...
# Processo il documento 47000...
# Documento 47000 salvato in: ./downloads/47000.txt
# Processo il documento 47001...
# Documento 47001 salvato in: ./downloads/47001.txt
# Processo il documento 47002...
# Documento 47002 salvato in: ./downloads/47002.txt
# Processo il documento 47003...
# Documento 47003 salvato in: ./downloads/47003.txt
# Processo il documento 47004...
# Documento 47004 non trovato (HTTP 404).
# Processo il documento 47005...
# Documento 47005 non trovato (HTTP 404).
# Processo il documento 47006...
# Documento 47006 non trovato (HTTP 404).
# Processo il documento 47007...
# Documento 47007 non trovato (HTTP 404).
# Processo il documento 47008...
# Documento 47008 non trovato (HTTP 404).
# Processo il documento 47009...
# Documento 47009 non trovato (HTTP 404).
# Processo il documento 47010...
# Documento 47010 non trovato (HTTP 404).
# Processo il documento 47011...
# Documento 47011 non trovato (HTTP 404).
# Processo il documento 47012...
# Documento 47012 non trovato (HTTP 404).
# Processo il documento 47013...
# Documento 47013 non trovato (HTTP 404).
# Processo il documento 47014...
# Documento 47014 non trovato (HTTP 404).
# Processo il documento 47015...
# Documento 47015 non trovato (HTTP 404).
# Processo il documento 47016...
# Documento 47016 non trovato (HTTP 404).
# Processo il documento 47017...
# Documento 47017 non trovato (HTTP 404).
# Processo il documento 47018...
# Documento 47018 non trovato (HTTP 404).
# Processo il documento 47019...
# Documento 47019 non trovato (HTTP 404).
# Processo il documento 47020...
# Documento 47020 non trovato (HTTP 404).
# Processo il documento 47021...
# Documento 47021 salvato in: ./downloads/47021.txt
# Processo il documento 47022...
# Documento 47022 salvato in: ./downloads/47022.txt
# Processo il documento 47023...
# Documento 47023 salvato in: ./downloads/47023.txt
# Processo il documento 47024...
# Documento 47024 salvato in: ./downloads/47024.txt
# Processo il documento 47025...
# Documento 47025 salvato in: ./downloads/47025.txt
# Processo il documento 47026...
# Documento 47026 salvato in: ./downloads/47026.txt
# Processo il documento 47027...
# Documento 47027 salvato in: ./downloads/47027.txt
# Processo il documento 47028...
# Documento 47028 salvato in: ./downloads/47028.txt
# Processo il documento 47029...
# Documento 47029 salvato in: ./downloads/47029.txt
# Processo il documento 47030...
# Documento 47030 salvato in: ./downloads/47030.txt
# Processo il documento 47031...
# Documento 47031 salvato in: ./downloads/47031.txt
# Processo il documento 47032...
# Documento 47032 salvato in: ./downloads/47032.txt
# Processo il documento 47033...
# Documento 47033 salvato in: ./downloads/47033.txt
# Processo il documento 47034...
# Documento 47034 salvato in: ./downloads/47034.txt
# Processo il documento 47035...
# Documento 47035 salvato in: ./downloads/47035.txt
# Processo il documento 47036...
# Documento 47036 salvato in: ./downloads/47036.txt
# Processo il documento 47037...
# Documento 47037 salvato in: ./downloads/47037.txt
# Processo il documento 47038...
# Documento 47038 salvato in: ./downloads/47038.txt
# Processo il documento 47039...
# Documento 47039 salvato in: ./downloads/47039.txt
# Processo il documento 47040...
# Documento 47040 salvato in: ./downloads/47040.txt
# Processo il documento 47041...
# Documento 47041 salvato in: ./downloads/47041.txt
# Processo il documento 47042...
# Documento 47042 salvato in: ./downloads/47042.txt
# Processo il documento 47043...
# Documento 47043 salvato in: ./downloads/47043.txt
# Processo il documento 47044...
# Documento 47044 salvato in: ./downloads/47044.txt
# Processo il documento 47045...
# Documento 47045 salvato in: ./downloads/47045.txt
# Processo il documento 47046...
# Documento 47046 salvato in: ./downloads/47046.txt
# Processo il documento 47047...
# Documento 47047 salvato in: ./downloads/47047.txt
# Processo il documento 47048...
# Documento 47048 salvato in: ./downloads/47048.txt
# Processo il documento 47049...
# Documento 47049 salvato in: ./downloads/47049.txt
# Processo il documento 47050...
# Documento 47050 salvato in: ./downloads/47050.txt
# Processo il documento 47051...
# Documento 47051 salvato in: ./downloads/47051.txt
# Processo il documento 47052...
# Documento 47052 salvato in: ./downloads/47052.txt
# Processo il documento 47053...
# Documento 47053 salvato in: ./downloads/47053.txt
# Processo il documento 47054...
# Documento 47054 salvato in: ./downloads/47054.txt
# Processo il documento 47055...
# Documento 47055 salvato in: ./downloads/47055.txt
# Processo il documento 47056...
# Documento 47056 salvato in: ./downloads/47056.txt
# Processo il documento 47057...
# Documento 47057 salvato in: ./downloads/47057.txt
# Processo il documento 47058...
# Documento 47058 salvato in: ./downloads/47058.txt
# Processo il documento 47059...
# Documento 47059 salvato in: ./downloads/47059.txt
# Processo il documento 47060...
# Documento 47060 salvato in: ./downloads/47060.txt
# Processo il documento 47061...
# Documento 47061 salvato in: ./downloads/47061.txt
# Processo il documento 47062...
# Documento 47062 salvato in: ./downloads/47062.txt
# Processo il documento 47063...
# Documento 47063 salvato in: ./downloads/47063.txt
# Processo il documento 47064...
# Documento 47064 salvato in: ./downloads/47064.txt
# Processo il documento 47065...
# Documento 47065 salvato in: ./downloads/47065.txt
# Processo il documento 47066...
# Documento 47066 salvato in: ./downloads/47066.txt
# Processo il documento 47067...
# Documento 47067 salvato in: ./downloads/47067.txt
# Processo il documento 47068...
# Documento 47068 salvato in: ./downloads/47068.txt
# Processo il documento 47069...
# Documento 47069 non trovato (HTTP 404).
# Processo il documento 47070...
# Documento 47070 non trovato (HTTP 404).
# Processo il documento 47071...
# Documento 47071 non trovato (HTTP 404).
# Processo il documento 47072...
# Documento 47072 non trovato (HTTP 404).
# Processo il documento 47073...
# Documento 47073 non trovato (HTTP 404).
# Processo il documento 47074...
# Documento 47074 non trovato (HTTP 404).
# Processo il documento 47075...
# Documento 47075 non trovato (HTTP 404).
# Processo il documento 47076...
# Documento 47076 non trovato (HTTP 404).
# Processo il documento 47077...
# Documento 47077 non trovato (HTTP 404).
# Processo il documento 47078...
# Documento 47078 non trovato (HTTP 404).
# Processo il documento 47079...
# Documento 47079 non trovato (HTTP 404).
# Processo il documento 47080...
# Documento 47080 non trovato (HTTP 404).
# Processo il documento 47081...
# Documento 47081 salvato in: ./downloads/47081.txt
# Processo il documento 47082...
# Documento 47082 salvato in: ./downloads/47082.txt
# Processo il documento 47083...
# Documento 47083 salvato in: ./downloads/47083.txt
# Processo il documento 47084...
# Documento 47084 salvato in: ./downloads/47084.txt
# Processo il documento 47085...
# Documento 47085 non trovato (HTTP 404).
# Processo il documento 47086...
# Documento 47086 non trovato (HTTP 404).
# Processo il documento 47087...
# Documento 47087 non trovato (HTTP 404).
# Processo il documento 47088...
# Documento 47088 non trovato (HTTP 404).
# Processo il documento 47089...
# Documento 47089 non trovato (HTTP 404).
# Processo il documento 47090...
# Documento 47090 non trovato (HTTP 404).
# Processo il documento 47091...
# Documento 47091 non trovato (HTTP 404).
# Processo il documento 47092...
# Documento 47092 non trovato (HTTP 404).
# Processo il documento 47093...
# Documento 47093 non trovato (HTTP 404).
# Processo il documento 47094...
# Documento 47094 non trovato (HTTP 404).
# Processo il documento 47095...
# Documento 47095 non trovato (HTTP 404).
# Processo il documento 47096...
# Documento 47096 non trovato (HTTP 404).
# Processo il documento 47097...
# Documento 47097 non trovato (HTTP 404).
# Processo il documento 47098...
# Documento 47098 non trovato (HTTP 404).
# Processo il documento 47099...
# Documento 47099 non trovato (HTTP 404).
# Processo il documento 47100...
# Documento 47100 non trovato (HTTP 404).
# Processo il documento 47101...
# Documento 47101 salvato in: ./downloads/47101.txt
# Processo il documento 47102...
# Documento 47102 salvato in: ./downloads/47102.txt
# Processo il documento 47103...
# Documento 47103 salvato in: ./downloads/47103.txt
# Processo il documento 47104...
# Documento 47104 salvato in: ./downloads/47104.txt
# Processo il documento 47105...
# Documento 47105 salvato in: ./downloads/47105.txt
# Processo il documento 47106...
# Documento 47106 salvato in: ./downloads/47106.txt
# Processo il documento 47107...
# Documento 47107 salvato in: ./downloads/47107.txt
# Processo il documento 47108...
# Documento 47108 salvato in: ./downloads/47108.txt
# Processo il documento 47109...
# Documento 47109 salvato in: ./downloads/47109.txt
# Processo il documento 47110...
# Documento 47110 salvato in: ./downloads/47110.txt
# Processo il documento 47111...
# Documento 47111 salvato in: ./downloads/47111.txt
# Processo il documento 47112...
# Documento 47112 salvato in: ./downloads/47112.txt
# Processo il documento 47113...
# Documento 47113 salvato in: ./downloads/47113.txt
# Processo il documento 47114...
# Documento 47114 salvato in: ./downloads/47114.txt
# Processo il documento 47115...
# Documento 47115 salvato in: ./downloads/47115.txt
# Processo il documento 47116...
# Documento 47116 salvato in: ./downloads/47116.txt
# Processo il documento 47117...
# Documento 47117 salvato in: ./downloads/47117.txt
# Processo il documento 47118...
# Documento 47118 salvato in: ./downloads/47118.txt
# Processo il documento 47119...
# Documento 47119 salvato in: ./downloads/47119.txt
# Processo il documento 47120...
# Documento 47120 salvato in: ./downloads/47120.txt
# Processo il documento 47121...
# Documento 47121 salvato in: ./downloads/47121.txt
# Processo il documento 47122...
# Documento 47122 salvato in: ./downloads/47122.txt
# Processo il documento 47123...
# Documento 47123 salvato in: ./downloads/47123.txt
# Processo il documento 47124...
# Documento 47124 salvato in: ./downloads/47124.txt
# Processo il documento 47125...
# Documento 47125 salvato in: ./downloads/47125.txt
# Processo il documento 47126...
# Documento 47126 salvato in: ./downloads/47126.txt
# Processo il documento 47127...
# Documento 47127 salvato in: ./downloads/47127.txt
# Processo il documento 47128...
# Documento 47128 salvato in: ./downloads/47128.txt
# Processo il documento 47129...
# Documento 47129 salvato in: ./downloads/47129.txt
# Processo il documento 47130...
# Documento 47130 salvato in: ./downloads/47130.txt
# Processo il documento 47131...
# Documento 47131 salvato in: ./downloads/47131.txt
# Processo il documento 47132...
# Documento 47132 salvato in: ./downloads/47132.txt
# Processo il documento 47133...
# Documento 47133 salvato in: ./downloads/47133.txt
# Processo il documento 47134...
# Documento 47134 salvato in: ./downloads/47134.txt
# Processo il documento 47135...
# Documento 47135 salvato in: ./downloads/47135.txt
# Processo il documento 47136...
# Documento 47136 salvato in: ./downloads/47136.txt
# Processo il documento 47137...
# Documento 47137 salvato in: ./downloads/47137.txt
# Processo il documento 47138...
# Documento 47138 salvato in: ./downloads/47138.txt
# Processo il documento 47139...
# Documento 47139 salvato in: ./downloads/47139.txt
# Processo il documento 47140...
# Documento 47140 salvato in: ./downloads/47140.txt
# Processo il documento 47141...
# Documento 47141 salvato in: ./downloads/47141.txt
# Processo il documento 47142...
# Documento 47142 salvato in: ./downloads/47142.txt
# Processo il documento 47143...
# Documento 47143 salvato in: ./downloads/47143.txt
# Processo il documento 47144...
# Documento 47144 salvato in: ./downloads/47144.txt
# Processo il documento 47145...
# Documento 47145 salvato in: ./downloads/47145.txt
# Processo il documento 47146...
# Documento 47146 salvato in: ./downloads/47146.txt
# Processo il documento 47147...
# Documento 47147 salvato in: ./downloads/47147.txt
# Processo il documento 47148...
# Documento 47148 salvato in: ./downloads/47148.txt
# Processo il documento 47149...
# Documento 47149 salvato in: ./downloads/47149.txt
# Processo il documento 47150...
# Documento 47150 salvato in: ./downloads/47150.txt
# Processo il documento 47151...
# Documento 47151 salvato in: ./downloads/47151.txt
# Processo il documento 47152...
# Documento 47152 non trovato (HTTP 404).
# Processo il documento 47153...
# Documento 47153 non trovato (HTTP 404).
# Processo il documento 47154...
# Documento 47154 non trovato (HTTP 404).
# Processo il documento 47155...
# Documento 47155 non trovato (HTTP 404).
# Processo il documento 47156...
# Documento 47156 non trovato (HTTP 404).
# Processo il documento 47157...
# Documento 47157 non trovato (HTTP 404).
# Processo il documento 47158...
# Documento 47158 non trovato (HTTP 404).
# Processo il documento 47159...
# Documento 47159 non trovato (HTTP 404).
# Processo il documento 47160...
# Documento 47160 non trovato (HTTP 404).
# Processo il documento 47161...
# Documento 47161 salvato in: ./downloads/47161.txt
# Processo il documento 47162...
# Documento 47162 salvato in: ./downloads/47162.txt
# Processo il documento 47163...
# Documento 47163 salvato in: ./downloads/47163.txt
# Processo il documento 47164...
# Documento 47164 salvato in: ./downloads/47164.txt
# Processo il documento 47165...
# Documento 47165 salvato in: ./downloads/47165.txt
# Processo il documento 47166...
# Documento 47166 salvato in: ./downloads/47166.txt
# Processo il documento 47167...
# Documento 47167 salvato in: ./downloads/47167.txt
# Processo il documento 47168...
# Documento 47168 salvato in: ./downloads/47168.txt
# Processo il documento 47169...
# Documento 47169 salvato in: ./downloads/47169.txt
# Processo il documento 47170...
# Documento 47170 salvato in: ./downloads/47170.txt
# Processo il documento 47171...
# Documento 47171 salvato in: ./downloads/47171.txt
# Processo il documento 47172...
# Documento 47172 salvato in: ./downloads/47172.txt
# Processo il documento 47173...
# Documento 47173 salvato in: ./downloads/47173.txt
# Processo il documento 47174...
# Documento 47174 salvato in: ./downloads/47174.txt
# Processo il documento 47175...
# Documento 47175 salvato in: ./downloads/47175.txt
# Processo il documento 47176...
# Documento 47176 salvato in: ./downloads/47176.txt
# Processo il documento 47177...
# Documento 47177 salvato in: ./downloads/47177.txt
# Processo il documento 47178...
# Documento 47178 salvato in: ./downloads/47178.txt
# Processo il documento 47179...
# Documento 47179 salvato in: ./downloads/47179.txt
# Processo il documento 47180...
# Documento 47180 salvato in: ./downloads/47180.txt
# Processo il documento 47181...
# Documento 47181 salvato in: ./downloads/47181.txt
# Processo il documento 47182...
# Documento 47182 salvato in: ./downloads/47182.txt
# Processo il documento 47183...
# Documento 47183 salvato in: ./downloads/47183.txt
# Processo il documento 47184...
# Documento 47184 salvato in: ./downloads/47184.txt
# Processo il documento 47185...
# Documento 47185 salvato in: ./downloads/47185.txt
# Processo il documento 47186...
# Documento 47186 salvato in: ./downloads/47186.txt
# Processo il documento 47187...
# Documento 47187 salvato in: ./downloads/47187.txt
# Processo il documento 47188...
# Documento 47188 salvato in: ./downloads/47188.txt
# Processo il documento 47189...
# Documento 47189 salvato in: ./downloads/47189.txt
# Processo il documento 47190...
# Documento 47190 salvato in: ./downloads/47190.txt
# Processo il documento 47191...
# Documento 47191 salvato in: ./downloads/47191.txt
# Processo il documento 47192...
# Documento 47192 salvato in: ./downloads/47192.txt
# Processo il documento 47193...
# Documento 47193 salvato in: ./downloads/47193.txt
# Processo il documento 47194...
# Documento 47194 salvato in: ./downloads/47194.txt
# Processo il documento 47195...
# Documento 47195 salvato in: ./downloads/47195.txt
# Processo il documento 47196...
# Documento 47196 salvato in: ./downloads/47196.txt
# Processo il documento 47197...
# Documento 47197 salvato in: ./downloads/47197.txt
# Processo il documento 47198...
# Documento 47198 salvato in: ./downloads/47198.txt
# Processo il documento 47199...
# Documento 47199 salvato in: ./downloads/47199.txt
# Processo il documento 47200...
# Documento 47200 salvato in: ./downloads/47200.txt
# Processo il documento 47201...
# Documento 47201 salvato in: ./downloads/47201.txt
# Processo il documento 47202...
# Documento 47202 salvato in: ./downloads/47202.txt
# Processo il documento 47203...
# Documento 47203 salvato in: ./downloads/47203.txt
# Processo il documento 47204...
# Documento 47204 salvato in: ./downloads/47204.txt
# Processo il documento 47205...
# Documento 47205 salvato in: ./downloads/47205.txt
# Processo il documento 47206...
# Documento 47206 salvato in: ./downloads/47206.txt
# Processo il documento 47207...
# Documento 47207 salvato in: ./downloads/47207.txt
# Processo il documento 47208...
# Documento 47208 salvato in: ./downloads/47208.txt
# Processo il documento 47209...
# Documento 47209 salvato in: ./downloads/47209.txt
# Processo il documento 47210...
# Documento 47210 salvato in: ./downloads/47210.txt
# Processo il documento 47211...
# Documento 47211 salvato in: ./downloads/47211.txt
# Processo il documento 47212...
# Documento 47212 salvato in: ./downloads/47212.txt
# Processo il documento 47213...
# Documento 47213 salvato in: ./downloads/47213.txt
# Processo il documento 47214...
# Documento 47214 salvato in: ./downloads/47214.txt
# Processo il documento 47215...
# Documento 47215 salvato in: ./downloads/47215.txt
# Processo il documento 47216...
# Documento 47216 salvato in: ./downloads/47216.txt
# Processo il documento 47217...
# Documento 47217 salvato in: ./downloads/47217.txt
# Processo il documento 47218...
# Documento 47218 salvato in: ./downloads/47218.txt
# Processo il documento 47219...
# Documento 47219 salvato in: ./downloads/47219.txt
# Processo il documento 47220...
# Documento 47220 salvato in: ./downloads/47220.txt
# Processo il documento 47221...
# Documento 47221 salvato in: ./downloads/47221.txt
# Processo il documento 47222...
# Documento 47222 salvato in: ./downloads/47222.txt
# Processo il documento 47223...
# Documento 47223 salvato in: ./downloads/47223.txt
# Processo il documento 47224...
# Documento 47224 salvato in: ./downloads/47224.txt
# Processo il documento 47225...
# Documento 47225 salvato in: ./downloads/47225.txt
# Processo il documento 47226...
# Documento 47226 salvato in: ./downloads/47226.txt
# Processo il documento 47227...
# Documento 47227 salvato in: ./downloads/47227.txt
# Processo il documento 47228...
# Documento 47228 salvato in: ./downloads/47228.txt
# Processo il documento 47229...
# Documento 47229 salvato in: ./downloads/47229.txt
# Processo il documento 47230...
# Documento 47230 salvato in: ./downloads/47230.txt
# Processo il documento 47231...
# Documento 47231 salvato in: ./downloads/47231.txt
# Processo il documento 47232...
# Documento 47232 salvato in: ./downloads/47232.txt
# Processo il documento 47233...
# Documento 47233 salvato in: ./downloads/47233.txt
# Processo il documento 47234...
# Documento 47234 salvato in: ./downloads/47234.txt
# Processo il documento 47235...
# Documento 47235 salvato in: ./downloads/47235.txt
# Processo il documento 47236...
# Documento 47236 salvato in: ./downloads/47236.txt
# Processo il documento 47237...
# Documento 47237 salvato in: ./downloads/47237.txt
# Processo il documento 47238...
# Documento 47238 salvato in: ./downloads/47238.txt
# Processo il documento 47239...
# Documento 47239 salvato in: ./downloads/47239.txt
# Processo il documento 47240...
# Documento 47240 salvato in: ./downloads/47240.txt
# Processo il documento 47241...
# Documento 47241 salvato in: ./downloads/47241.txt
# Processo il documento 47242...
# Documento 47242 salvato in: ./downloads/47242.txt
# Processo il documento 47243...
# Documento 47243 salvato in: ./downloads/47243.txt
# Processo il documento 47244...
# Documento 47244 salvato in: ./downloads/47244.txt
# Processo il documento 47245...
# Documento 47245 salvato in: ./downloads/47245.txt
# Processo il documento 47246...
# Documento 47246 salvato in: ./downloads/47246.txt
# Processo il documento 47247...
# Documento 47247 salvato in: ./downloads/47247.txt
# Processo il documento 47248...
# Documento 47248 salvato in: ./downloads/47248.txt
# Processo il documento 47249...
# Documento 47249 salvato in: ./downloads/47249.txt
# Processo il documento 47250...
# Documento 47250 salvato in: ./downloads/47250.txt
# Processo il documento 47251...
# Documento 47251 salvato in: ./downloads/47251.txt
# Processo il documento 47252...
# Documento 47252 salvato in: ./downloads/47252.txt
# Processo il documento 47253...
# Documento 47253 salvato in: ./downloads/47253.txt
# Processo il documento 47254...
# Documento 47254 salvato in: ./downloads/47254.txt
# Processo il documento 47255...
# Documento 47255 salvato in: ./downloads/47255.txt
# Processo il documento 47256...
# Documento 47256 salvato in: ./downloads/47256.txt
# Processo il documento 47257...
# Documento 47257 salvato in: ./downloads/47257.txt
# Processo il documento 47258...
# Documento 47258 salvato in: ./downloads/47258.txt
# Processo il documento 47259...
# Documento 47259 salvato in: ./downloads/47259.txt
# Processo il documento 47260...
# Documento 47260 salvato in: ./downloads/47260.txt
# Processo il documento 47261...
# Documento 47261 salvato in: ./downloads/47261.txt
# Processo il documento 47262...
# Documento 47262 salvato in: ./downloads/47262.txt
# Processo il documento 47263...
# Documento 47263 salvato in: ./downloads/47263.txt
# Processo il documento 47264...
# Documento 47264 salvato in: ./downloads/47264.txt
# Processo il documento 47265...
# Documento 47265 salvato in: ./downloads/47265.txt
# Processo il documento 47266...
# Documento 47266 salvato in: ./downloads/47266.txt
# Processo il documento 47267...
# Documento 47267 salvato in: ./downloads/47267.txt
# Processo il documento 47268...
# Documento 47268 salvato in: ./downloads/47268.txt
# Processo il documento 47269...
# Documento 47269 salvato in: ./downloads/47269.txt
# Processo il documento 47270...
# Documento 47270 salvato in: ./downloads/47270.txt
# Processo il documento 47271...
# Documento 47271 salvato in: ./downloads/47271.txt
# Processo il documento 47272...
# Documento 47272 salvato in: ./downloads/47272.txt
# Processo il documento 47273...
# Documento 47273 salvato in: ./downloads/47273.txt
# Processo il documento 47274...
# Documento 47274 non trovato (HTTP 404).
# Processo il documento 47275...
# Documento 47275 non trovato (HTTP 404).
# Processo il documento 47276...
# Documento 47276 non trovato (HTTP 404).
# Processo il documento 47277...
# Documento 47277 non trovato (HTTP 404).
# Processo il documento 47278...
# Documento 47278 non trovato (HTTP 404).
# Processo il documento 47279...
# Documento 47279 non trovato (HTTP 404).
# Processo il documento 47280...
# Documento 47280 non trovato (HTTP 404).
# Processo il documento 47281...
# Documento 47281 salvato in: ./downloads/47281.txt
# Processo il documento 47282...
# Documento 47282 salvato in: ./downloads/47282.txt
# Processo il documento 47283...
# Documento 47283 salvato in: ./downloads/47283.txt
# Processo il documento 47284...
# Documento 47284 salvato in: ./downloads/47284.txt
# Processo il documento 47285...
# Documento 47285 salvato in: ./downloads/47285.txt
# Processo il documento 47286...
# Documento 47286 salvato in: ./downloads/47286.txt
# Processo il documento 47287...
# Documento 47287 salvato in: ./downloads/47287.txt
# Processo il documento 47288...
# Documento 47288 salvato in: ./downloads/47288.txt
# Processo il documento 47289...
# Documento 47289 salvato in: ./downloads/47289.txt
# Processo il documento 47290...
# Documento 47290 salvato in: ./downloads/47290.txt
# Processo il documento 47291...
# Documento 47291 salvato in: ./downloads/47291.txt
# Processo il documento 47292...
# Documento 47292 salvato in: ./downloads/47292.txt
# Processo il documento 47293...
# Documento 47293 salvato in: ./downloads/47293.txt
# Processo il documento 47294...
# Documento 47294 salvato in: ./downloads/47294.txt
# Processo il documento 47295...
# Documento 47295 salvato in: ./downloads/47295.txt
# Processo il documento 47296...
# Documento 47296 salvato in: ./downloads/47296.txt
# Processo il documento 47297...
# Documento 47297 salvato in: ./downloads/47297.txt
# Processo il documento 47298...
# Documento 47298 salvato in: ./downloads/47298.txt
# Processo il documento 47299...
# Documento 47299 salvato in: ./downloads/47299.txt
# Processo il documento 47300...
# Documento 47300 salvato in: ./downloads/47300.txt
# Processo il documento 47301...
# Documento 47301 salvato in: ./downloads/47301.txt
# Processo il documento 47302...
# Documento 47302 salvato in: ./downloads/47302.txt
# Processo il documento 47303...
# Documento 47303 salvato in: ./downloads/47303.txt
# Processo il documento 47304...
# Documento 47304 salvato in: ./downloads/47304.txt
# Processo il documento 47305...
# Documento 47305 salvato in: ./downloads/47305.txt
# Processo il documento 47306...
# Documento 47306 salvato in: ./downloads/47306.txt
# Processo il documento 47307...
# Documento 47307 salvato in: ./downloads/47307.txt
# Processo il documento 47308...
# Documento 47308 salvato in: ./downloads/47308.txt
# Processo il documento 47309...
# Documento 47309 salvato in: ./downloads/47309.txt
# Processo il documento 47310...
# Documento 47310 salvato in: ./downloads/47310.txt
# Processo il documento 47311...
# Documento 47311 salvato in: ./downloads/47311.txt
# Processo il documento 47312...
# Documento 47312 salvato in: ./downloads/47312.txt
# Processo il documento 47313...
# Documento 47313 salvato in: ./downloads/47313.txt
# Processo il documento 47314...
# Documento 47314 salvato in: ./downloads/47314.txt
# Processo il documento 47315...
# Documento 47315 salvato in: ./downloads/47315.txt
# Processo il documento 47316...
# Documento 47316 salvato in: ./downloads/47316.txt
# Processo il documento 47317...
# Documento 47317 salvato in: ./downloads/47317.txt
# Processo il documento 47318...
# Documento 47318 salvato in: ./downloads/47318.txt
# Processo il documento 47319...
# Documento 47319 salvato in: ./downloads/47319.txt
# Processo il documento 47320...
# Documento 47320 salvato in: ./downloads/47320.txt
# Processo il documento 47321...
# Documento 47321 salvato in: ./downloads/47321.txt
# Processo il documento 47322...
# Documento 47322 salvato in: ./downloads/47322.txt
# Processo il documento 47323...
# Documento 47323 salvato in: ./downloads/47323.txt
# Processo il documento 47324...
# Documento 47324 salvato in: ./downloads/47324.txt
# Processo il documento 47325...
# Documento 47325 salvato in: ./downloads/47325.txt
# Processo il documento 47326...
# Documento 47326 salvato in: ./downloads/47326.txt
# Processo il documento 47327...
# Documento 47327 salvato in: ./downloads/47327.txt
# Processo il documento 47328...
# Documento 47328 salvato in: ./downloads/47328.txt
# Processo il documento 47329...
# Documento 47329 non trovato (HTTP 404).
# Processo il documento 47330...
# Documento 47330 non trovato (HTTP 404).
# Processo il documento 47331...
# Documento 47331 non trovato (HTTP 404).
# Processo il documento 47332...
# Documento 47332 non trovato (HTTP 404).
# Processo il documento 47333...
# Documento 47333 non trovato (HTTP 404).
# Processo il documento 47334...
# Documento 47334 non trovato (HTTP 404).
# Processo il documento 47335...
# Documento 47335 non trovato (HTTP 404).
# Processo il documento 47336...
# Documento 47336 non trovato (HTTP 404).
# Processo il documento 47337...
# Documento 47337 non trovato (HTTP 404).
# Processo il documento 47338...
# Documento 47338 non trovato (HTTP 404).
# Processo il documento 47339...
# Documento 47339 non trovato (HTTP 404).
# Processo il documento 47340...
# Documento 47340 non trovato (HTTP 404).
# Processo il documento 47341...
# Documento 47341 salvato in: ./downloads/47341.txt
# Processo il documento 47342...
# Documento 47342 salvato in: ./downloads/47342.txt
# Processo il documento 47343...
# Documento 47343 salvato in: ./downloads/47343.txt
# Processo il documento 47344...
# Documento 47344 salvato in: ./downloads/47344.txt
# Processo il documento 47345...
# Documento 47345 salvato in: ./downloads/47345.txt
# Processo il documento 47346...
# Documento 47346 salvato in: ./downloads/47346.txt
# Processo il documento 47347...
# Documento 47347 salvato in: ./downloads/47347.txt
# Processo il documento 47348...
# Documento 47348 salvato in: ./downloads/47348.txt
# Processo il documento 47349...
# Documento 47349 salvato in: ./downloads/47349.txt
# Processo il documento 47350...
# Documento 47350 salvato in: ./downloads/47350.txt
# Processo il documento 47351...
# Documento 47351 salvato in: ./downloads/47351.txt
# Processo il documento 47352...
# Documento 47352 salvato in: ./downloads/47352.txt
# Processo il documento 47353...
# Documento 47353 salvato in: ./downloads/47353.txt
# Processo il documento 47354...
# Documento 47354 salvato in: ./downloads/47354.txt
# Processo il documento 47355...
# Documento 47355 salvato in: ./downloads/47355.txt
# Processo il documento 47356...
# Documento 47356 salvato in: ./downloads/47356.txt
# Processo il documento 47357...
# Documento 47357 salvato in: ./downloads/47357.txt
# Processo il documento 47358...
# Documento 47358 salvato in: ./downloads/47358.txt
# Processo il documento 47359...
# Documento 47359 salvato in: ./downloads/47359.txt
# Processo il documento 47360...
# Documento 47360 salvato in: ./downloads/47360.txt
# Processo il documento 47361...
# Documento 47361 salvato in: ./downloads/47361.txt
# Processo il documento 47362...
# Documento 47362 salvato in: ./downloads/47362.txt
# Processo il documento 47363...
# Documento 47363 salvato in: ./downloads/47363.txt
# Processo il documento 47364...
# Documento 47364 salvato in: ./downloads/47364.txt
# Processo il documento 47365...
# Documento 47365 salvato in: ./downloads/47365.txt
# Processo il documento 47366...
# Documento 47366 salvato in: ./downloads/47366.txt
# Processo il documento 47367...
# Documento 47367 salvato in: ./downloads/47367.txt
# Processo il documento 47368...
# Documento 47368 salvato in: ./downloads/47368.txt
# Processo il documento 47369...
# Documento 47369 salvato in: ./downloads/47369.txt
# Processo il documento 47370...
# Documento 47370 salvato in: ./downloads/47370.txt
# Processo il documento 47371...
# Documento 47371 salvato in: ./downloads/47371.txt
# Processo il documento 47372...
# Documento 47372 salvato in: ./downloads/47372.txt
# Processo il documento 47373...
# Documento 47373 salvato in: ./downloads/47373.txt
# Processo il documento 47374...
# Documento 47374 salvato in: ./downloads/47374.txt
# Processo il documento 47375...
# Documento 47375 salvato in: ./downloads/47375.txt
# Processo il documento 47376...
# Documento 47376 salvato in: ./downloads/47376.txt
# Processo il documento 47377...
# Documento 47377 salvato in: ./downloads/47377.txt
# Processo il documento 47378...
# Documento 47378 salvato in: ./downloads/47378.txt
# Processo il documento 47379...
# Documento 47379 salvato in: ./downloads/47379.txt
# Processo il documento 47380...
# Documento 47380 salvato in: ./downloads/47380.txt
# Processo il documento 47381...
# Documento 47381 salvato in: ./downloads/47381.txt
# Processo il documento 47382...
# Documento 47382 salvato in: ./downloads/47382.txt
# Processo il documento 47383...
# Documento 47383 salvato in: ./downloads/47383.txt
# Processo il documento 47384...
# Documento 47384 salvato in: ./downloads/47384.txt
# Processo il documento 47385...
# Documento 47385 salvato in: ./downloads/47385.txt
# Processo il documento 47386...
# Documento 47386 salvato in: ./downloads/47386.txt
# Processo il documento 47387...
# Documento 47387 salvato in: ./downloads/47387.txt
# Processo il documento 47388...
# Documento 47388 salvato in: ./downloads/47388.txt
# Processo il documento 47389...
# Documento 47389 salvato in: ./downloads/47389.txt
# Processo il documento 47390...
# Documento 47390 salvato in: ./downloads/47390.txt
# Processo il documento 47391...
# Documento 47391 salvato in: ./downloads/47391.txt
# Processo il documento 47392...
# Documento 47392 salvato in: ./downloads/47392.txt
# Processo il documento 47393...
# Documento 47393 salvato in: ./downloads/47393.txt
# Processo il documento 47394...
# Documento 47394 salvato in: ./downloads/47394.txt
# Processo il documento 47395...
# Documento 47395 salvato in: ./downloads/47395.txt
# Processo il documento 47396...
# Documento 47396 salvato in: ./downloads/47396.txt
# Processo il documento 47397...
# Documento 47397 salvato in: ./downloads/47397.txt
# Processo il documento 47398...
# Documento 47398 non trovato (HTTP 404).
# Processo il documento 47399...
# Documento 47399 non trovato (HTTP 404).
# Processo il documento 47400...
# Documento 47400 non trovato (HTTP 404).
# Processo il documento 47401...
# Documento 47401 salvato in: ./downloads/47401.txt
# Processo il documento 47402...
# Documento 47402 salvato in: ./downloads/47402.txt
# Processo il documento 47403...
# Documento 47403 salvato in: ./downloads/47403.txt
# Processo il documento 47404...
# Documento 47404 salvato in: ./downloads/47404.txt
# Processo il documento 47405...
# Documento 47405 salvato in: ./downloads/47405.txt
# Processo il documento 47406...
# Documento 47406 salvato in: ./downloads/47406.txt
# Processo il documento 47407...
# Documento 47407 salvato in: ./downloads/47407.txt
# Processo il documento 47408...
# Documento 47408 salvato in: ./downloads/47408.txt
# Processo il documento 47409...
# Documento 47409 salvato in: ./downloads/47409.txt
# Processo il documento 47410...
# Documento 47410 salvato in: ./downloads/47410.txt
# Processo il documento 47411...
# Documento 47411 salvato in: ./downloads/47411.txt
# Processo il documento 47412...
# Documento 47412 salvato in: ./downloads/47412.txt
# Processo il documento 47413...
# Documento 47413 salvato in: ./downloads/47413.txt
# Processo il documento 47414...
# Documento 47414 salvato in: ./downloads/47414.txt
# Processo il documento 47415...
# Documento 47415 salvato in: ./downloads/47415.txt
# Processo il documento 47416...
# Documento 47416 salvato in: ./downloads/47416.txt
# Processo il documento 47417...
# Documento 47417 salvato in: ./downloads/47417.txt
# Processo il documento 47418...
# Documento 47418 salvato in: ./downloads/47418.txt
# Processo il documento 47419...
# Documento 47419 salvato in: ./downloads/47419.txt
# Processo il documento 47420...
# Documento 47420 salvato in: ./downloads/47420.txt
# Processo il documento 47421...
# Documento 47421 salvato in: ./downloads/47421.txt
# Processo il documento 47422...
# Documento 47422 salvato in: ./downloads/47422.txt
# Processo il documento 47423...
# Documento 47423 salvato in: ./downloads/47423.txt
# Processo il documento 47424...
# Documento 47424 salvato in: ./downloads/47424.txt
# Processo il documento 47425...
# Documento 47425 salvato in: ./downloads/47425.txt
# Processo il documento 47426...
# Documento 47426 salvato in: ./downloads/47426.txt
# Processo il documento 47427...
# Documento 47427 salvato in: ./downloads/47427.txt
# Processo il documento 47428...
# Documento 47428 salvato in: ./downloads/47428.txt
# Processo il documento 47429...
# Documento 47429 salvato in: ./downloads/47429.txt
# Processo il documento 47430...
# Documento 47430 salvato in: ./downloads/47430.txt
# Processo il documento 47431...
# Documento 47431 salvato in: ./downloads/47431.txt
# Processo il documento 47432...
# Documento 47432 salvato in: ./downloads/47432.txt
# Processo il documento 47433...
# Documento 47433 salvato in: ./downloads/47433.txt
# Processo il documento 47434...
# Documento 47434 salvato in: ./downloads/47434.txt
# Processo il documento 47435...
# Documento 47435 salvato in: ./downloads/47435.txt
# Processo il documento 47436...
# Documento 47436 salvato in: ./downloads/47436.txt
# Processo il documento 47437...
# Documento 47437 salvato in: ./downloads/47437.txt
# Processo il documento 47438...
# Documento 47438 non trovato (HTTP 404).
# Processo il documento 47439...
# Documento 47439 non trovato (HTTP 404).
# Processo il documento 47440...
# Documento 47440 non trovato (HTTP 404).
# Processo il documento 47441...
# Documento 47441 salvato in: ./downloads/47441.txt
# Processo il documento 47442...
# Documento 47442 salvato in: ./downloads/47442.txt
# Processo il documento 47443...
# Documento 47443 salvato in: ./downloads/47443.txt
# Processo il documento 47444...
# Documento 47444 salvato in: ./downloads/47444.txt
# Processo il documento 47445...
# Documento 47445 salvato in: ./downloads/47445.txt
# Processo il documento 47446...
# Documento 47446 salvato in: ./downloads/47446.txt
# Processo il documento 47447...
# Documento 47447 salvato in: ./downloads/47447.txt
# Processo il documento 47448...
# Documento 47448 salvato in: ./downloads/47448.txt
# Processo il documento 47449...
# Documento 47449 salvato in: ./downloads/47449.txt
# Processo il documento 47450...
# Documento 47450 salvato in: ./downloads/47450.txt
# Processo il documento 47451...
# Documento 47451 salvato in: ./downloads/47451.txt
# Processo il documento 47452...
# Documento 47452 salvato in: ./downloads/47452.txt
# Processo il documento 47453...
# Documento 47453 salvato in: ./downloads/47453.txt
# Processo il documento 47454...
# Documento 47454 salvato in: ./downloads/47454.txt
# Processo il documento 47455...
# Documento 47455 salvato in: ./downloads/47455.txt
# Processo il documento 47456...
# Documento 47456 salvato in: ./downloads/47456.txt
# Processo il documento 47457...
# Documento 47457 salvato in: ./downloads/47457.txt
# Processo il documento 47458...
# Documento 47458 salvato in: ./downloads/47458.txt
# Processo il documento 47459...
# Documento 47459 salvato in: ./downloads/47459.txt
# Processo il documento 47460...
# Documento 47460 salvato in: ./downloads/47460.txt
# Processo il documento 47461...
# Documento 47461 salvato in: ./downloads/47461.txt
# Processo il documento 47462...
# Documento 47462 salvato in: ./downloads/47462.txt
# Processo il documento 47463...
# Documento 47463 salvato in: ./downloads/47463.txt
# Processo il documento 47464...
# Documento 47464 salvato in: ./downloads/47464.txt
# Processo il documento 47465...
# Documento 47465 salvato in: ./downloads/47465.txt
# Processo il documento 47466...
# Documento 47466 salvato in: ./downloads/47466.txt
# Processo il documento 47467...
# Documento 47467 salvato in: ./downloads/47467.txt
# Processo il documento 47468...
# Documento 47468 salvato in: ./downloads/47468.txt
# Processo il documento 47469...
# Documento 47469 salvato in: ./downloads/47469.txt
# Processo il documento 47470...
# Documento 47470 salvato in: ./downloads/47470.txt
# Processo il documento 47471...
# Documento 47471 salvato in: ./downloads/47471.txt
# Processo il documento 47472...
# Documento 47472 salvato in: ./downloads/47472.txt
# Processo il documento 47473...
# Documento 47473 salvato in: ./downloads/47473.txt
# Processo il documento 47474...
# Documento 47474 salvato in: ./downloads/47474.txt
# Processo il documento 47475...
# Documento 47475 salvato in: ./downloads/47475.txt
# Processo il documento 47476...
# Documento 47476 salvato in: ./downloads/47476.txt
# Processo il documento 47477...
# Documento 47477 salvato in: ./downloads/47477.txt
# Processo il documento 47478...
# Documento 47478 salvato in: ./downloads/47478.txt
# Processo il documento 47479...
# Documento 47479 salvato in: ./downloads/47479.txt
# Processo il documento 47480...
# Documento 47480 salvato in: ./downloads/47480.txt
# Processo il documento 47481...
# Documento 47481 salvato in: ./downloads/47481.txt
# Processo il documento 47482...
# Documento 47482 salvato in: ./downloads/47482.txt
# Processo il documento 47483...
# Documento 47483 salvato in: ./downloads/47483.txt
# Processo il documento 47484...
# Documento 47484 salvato in: ./downloads/47484.txt
# Processo il documento 47485...
# Documento 47485 salvato in: ./downloads/47485.txt
# Processo il documento 47486...
# Documento 47486 salvato in: ./downloads/47486.txt
# Processo il documento 47487...
# Documento 47487 salvato in: ./downloads/47487.txt
# Processo il documento 47488...
# Documento 47488 salvato in: ./downloads/47488.txt
# Processo il documento 47489...
# Documento 47489 salvato in: ./downloads/47489.txt
# Processo il documento 47490...
# Documento 47490 salvato in: ./downloads/47490.txt
# Processo il documento 47491...
# Documento 47491 salvato in: ./downloads/47491.txt
# Processo il documento 47492...
# Documento 47492 salvato in: ./downloads/47492.txt
# Processo il documento 47493...
# Documento 47493 salvato in: ./downloads/47493.txt
# Processo il documento 47494...
# Documento 47494 salvato in: ./downloads/47494.txt
# Processo il documento 47495...
# Documento 47495 salvato in: ./downloads/47495.txt
# Processo il documento 47496...
# Documento 47496 salvato in: ./downloads/47496.txt
# Processo il documento 47497...
# Documento 47497 salvato in: ./downloads/47497.txt
# Processo il documento 47498...
# Documento 47498 salvato in: ./downloads/47498.txt
# Processo il documento 47499...
# Documento 47499 salvato in: ./downloads/47499.txt
# Processo il documento 47500...
# Documento 47500 salvato in: ./downloads/47500.txt
# Salvataggio dei risultati nel file CSV: csv_paths.csv
# Completato! Tutti i documenti salvati nella cartella: ./downloads

# %%
def generate_csv_from_folder(folder_path, csv_file="csv_paths.csv"):
    csv_data = []
    
    # Verifica che la cartella esista
    if not os.path.exists(folder_path):
        print(f"La cartella {folder_path} non esiste.")
        return
    
    # Scansiona la cartella per trovare i file
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        
        if os.path.isfile(file_path):  # Assicuriamoci che sia un file e non una cartella
            file_id, _ = os.path.splitext(file_name)  # Rimuove l'estensione
            csv_data.append({"ID_file": file_id, "path_src": file_path})
    
    # Salvataggio dei dati in un file CSV
    with open(csv_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=["ID_file", "path_src"])
        writer.writeheader()
        writer.writerows(csv_data)
    
    print(f"File CSV creato con successo: {csv_file}")

# Esempio di utilizzo
folder_path = "./downloads"  # Modifica con il percorso della tua cartella
generate_csv_from_folder(folder_path)
# Out:
# File CSV creato con successo: csv_paths.csv

# %%
#funzione per pulire i file txt dalle parti inutili presenti nella pagina web del consiglio Valle
def first_clean(target_folder, keyword, mid_strings, end_keyword, csv_paths):
    df = pd.read_csv(csv_paths)

    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    df["path_clean"] = ""

    for idx, row in df.iterrows():
        source_path = row["path_src"]
        if source_path.endswith(".txt"):
            filename = os.path.basename(source_path)
            target_path = os.path.join(target_folder, filename)

            df.at[idx, "path_clean"] = target_path

            with open(source_path, "r", encoding="utf-8") as file:
                content = file.read()

            if keyword in content:
                content = keyword + content.split(keyword, 1)[1] 

            for mid_string in mid_strings:
                content = re.sub(re.escape(mid_string), "", content) 

            if end_keyword in content:
                content = content.split(end_keyword, 1)[0]  

            with open(target_path, "w", encoding="utf-8") as file:
                file.write(content)

    df.to_csv(csv_paths, index=False)

#funzione per estrarre informazioni dai file txt: oggetto, legislatura, data e classificazione
def extract_and_format_date(text):
    
    date_pattern = re.search(r"(\d{1,2})\s+([a-zA-Z]+)\s+(\d{4})", text)
    
    if date_pattern:
        day, month_name, year = date_pattern.groups()
        
        months = {
            "gennaio": "01", "febbraio": "02", "marzo": "03", "aprile": "04", "maggio": "05", "giugno": "06",
            "luglio": "07", "agosto": "08", "settembre": "09", "ottobre": "10", "novembre": "11", "dicembre": "12"
        }
        
        month = months.get(month_name.lower())
        
        if month:
            return f"{int(day):02d}/{month}/{year}"
    
    return None

def first_info(pattern1, pattern2, csv_paths):
    df_paths = pd.read_csv(csv_paths)

    df_paths['language'] = ""
    df_paths['object'] = ""
    df_paths['legislature'] = ""
    df_paths['date'] = ""
    df_paths['class'] = ""

    for idx, row in df_paths.iterrows():
        source_path = row["path_clean"]
        if source_path.endswith(".txt"):
            filename = os.path.basename(source_path)
            filenum = int(os.path.splitext(filename)[0])

            with open(source_path, "r", encoding="utf-8") as file:
                content = file.read()

            match1 = re.search(pattern1, content)

            if match1:
                stringa = match1.group(1).strip()
                ogg, leg = stringa.split("/", 1)

                df_paths.loc[df_paths['ID_file'] == filenum, 'object'] = ogg
                df_paths.loc[df_paths['ID_file'] == filenum, 'legislature'] = leg

            date = extract_and_format_date(content)
            df_paths.loc[df_paths['ID_file'] == filenum, 'date'] = date
            
            match2 = re.search(pattern2, content, re.DOTALL)
            
            if match2:
                classe = match2.group(1).strip()
                classe = classe.replace("\n", ", ").strip()
                df_paths.loc[df_paths['ID_file'] == filenum, 'class'] = classe

            try:
                lang = detect(content)
                if lang == 'fr':
                    df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'fr'
                elif lang == 'it':
                    df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'it'
                else:
                    df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'other'
            except:
                df_paths.loc[df_paths['ID_file'] == filenum, 'language'] = 'error'

    df_paths.to_csv(csv_paths, index=False)

def second_info(csv_paths):
    df = pd.read_csv(csv_paths)
    
    if "obj_pos" not in df.columns:
        df["obj_pos"] = 0
    
    df["object"] = pd.to_numeric(df["object"], errors="coerce")  # Converti in numero per ordinamento
    
    df.sort_values(by=["date", "object"], ascending=[True, True], inplace=True)
    
    df["obj_pos"] = df.groupby("date").cumcount() + 1  # Assegna numeri progressivi
    
    df.to_csv(csv_paths, index=False)

# %%
target_folder = "./clean"

csv_paths = "./csv_paths.csv"
csv_details = "./csv_details.csv"
csv_cons = "./csv_cons.csv"
csv_chunks = "./csv_chunks.csv"

# %%
keyword = "Classificazione"
mid_strings = ["Precedente", "Successivo", "Resoconto integrale del dibattito dell'aula. I documenti allegati sono reperibili nel link \"iter atto\"."]
end_keyword = "Informativa cookies"

first_clean(target_folder, keyword, mid_strings, end_keyword, csv_paths)

pattern1 = r'(?:OGGETTO N\.|OBJET N°)(.*?)\s*-'
pattern2 = r'Classificazione\s*(.*?)\s*Oggetto'

first_info(pattern1, pattern2, csv_paths)
second_info(csv_paths)

# %%
import pandas as pd
import re

def define_names(csv_cons, leg):
    df_cons = pd.read_csv(csv_cons)
    df_cons = df_cons.reset_index()  # Aggiunge l'indice come colonna ID_cons
    df_cons.rename(columns={'index': 'ID_cons'}, inplace=True)
    names = []
    
    print(f"Filtrando per legislatura: {leg}")
    filtered_cons = df_cons[df_cons['legislature'].str.contains(leg, case=False, na=False)]
    
    surname_counts = filtered_cons['surname'].value_counts()

    for idx, row in filtered_cons.iterrows():
        surname = row["surname"]
        name = row["name"]
        
        if surname_counts[surname] > 1:
            names.append(f"{surname} {name[0]}.")
        else:
            names.append(surname)
    
    print(f"Numero di nomi trovati per la legislatura {leg}: {len(names)}")
    return filtered_cons, names

def isolate_chunk(csv_paths, csv_cons):
    df_paths = pd.read_csv(csv_paths)
    chunk_list = []

    for idx, row in df_paths.iterrows():
        leg = row["legislature"]
        date = row["date"]
        language = row["language"]
        obj = row["obj_pos"]
        
        print(f"Processando file {row['path_clean']} per la legislatura {leg}...")
        
        try:
            df_cons, list_cons = define_names(csv_cons, leg)

            with open(row["path_clean"], 'r') as f:
                text = f.read()

                all_matches = []
                for name in list_cons:
                    pattern = r"(?i)" + re.escape(name) + r"\s?\([^)]*\)\s?-"
                    matches = list(re.finditer(pattern, text))
                    all_matches.extend(matches)
                
                president_pattern = r"(?i)Presidente\s?-"
                president_matches = list(re.finditer(president_pattern, text))
                all_matches.extend(president_matches)
                
                all_matches.sort(key=lambda match: match.start())
                
                president_data = None
                if all_matches:
                    first_match = all_matches[0]
                    if not re.match(president_pattern, first_match.group(0), re.IGNORECASE):
                        surname = first_match.group(0)
                        words = surname.split()
                        surname = " ".join(words[:2])
                        if words[1].endswith('.') or words[1].startswith('('):
                            surname = words[0]
                        person_info = df_cons[df_cons["surname"] == surname].iloc[0]
                        president_data = {
                            "ID_cons": person_info["ID_cons"],
                            "year_birth": person_info["year_birth"],
                            "gender": person_info["gender"],
                            "group": 'Presidente'
                        }

                chunk_idx = 1
                for i, match in enumerate(all_matches):
                    start_pos = match.end() 
                    end_pos = all_matches[i + 1].start() if i + 1 < len(all_matches) else len(text)

                    chunk = text[start_pos:end_pos].replace("\n", " ").strip()

                    if chunk:
                        if re.match(president_pattern, match.group(0), re.IGNORECASE):
                            if president_data:
                                ID_cons = president_data["ID_cons"]
                                year_birth = president_data["year_birth"]
                                gender = president_data["gender"]
                                group = president_data["group"]
                            else:
                                ID_cons = "N/A"
                                year_birth = "N/A"
                                gender = "N/A"
                                group = "N/A"
                        else:
                            surname = match.group(0)
                            party = re.search(r'\((.*?)\)', surname)
                            group = party.group(1) if party else "N/A"
                            words = surname.split()
                            surname = " ".join(words[:2])
                            if words[1].endswith('.') or words[1].startswith('('):
                                surname = words[0]
                            try:
                                person_info = df_cons[df_cons["surname"] == surname].iloc[0]
                                ID_cons = person_info["ID_cons"]
                                year_birth = person_info["year_birth"]
                                gender = person_info["gender"]
                            except IndexError:
                                ID_cons = "N/A"
                                year_birth = "N/A"
                                gender = "N/A"
                                group = "N/A"

                        chunk_list.append({
                            "ID_file": row["ID_file"],
                            "leg": leg,
                            "date": date,
                            "class": row["class"],
                            "obj_pos": obj,
                            "language": language,
                            "ID_cons": ID_cons,
                            "year_birth": year_birth,
                            "gender": gender,
                            "group": group,
                            "position": chunk_idx,
                            "length": len(chunk),
                            "chunk": chunk
                        })
                        
                        chunk_idx += 1
            print('File ok')

        except Exception as e:
            print(f"Errore nel file {row['path_clean']}: {e}. Saltando questa entry.")
            continue

    df_chunks = pd.DataFrame(chunk_list)
    print(f"Numero totale di chunk processati: {len(chunk_list)}")
    return df_chunks

df = isolate_chunk(csv_paths, csv_cons)

print("Salvataggio del file csv_chunks.csv...")
df.to_csv("csv_chunks.csv", index=False)
print("File salvato con successo!")
# Out:
# Processando file ./clean/47801.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47802.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47803.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47804.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47805.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47806.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47807.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47808.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47809.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47810.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47811.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47812.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47813.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47814.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47815.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47816.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47817.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47818.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47819.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47820.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47821.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47161.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47162.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47163.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47164.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47165.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47166.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47167.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47168.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47169.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47170.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47171.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47172.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47173.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47174.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47175.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47176.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47177.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47178.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47179.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47180.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47181.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47182.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47183.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47184.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47185.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47186.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47187.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47188.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47189.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47190.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47191.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47192.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47193.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47194.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47195.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47196.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47197.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47198.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47199.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47200.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47201.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47202.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47203.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47204.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47205.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47206.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47822.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47823.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47824.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47825.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47826.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47827.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47828.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47829.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47830.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47831.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47832.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47833.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47834.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47835.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47836.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47837.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47838.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47839.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47840.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47841.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47842.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47843.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47844.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47845.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47846.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47847.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47848.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47849.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47850.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47851.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47852.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47853.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47854.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47855.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47856.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47857.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47858.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47859.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47207.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47208.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47209.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47210.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47211.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47212.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47213.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47214.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47215.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47216.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47217.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47218.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47219.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47220.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47401.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47402.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47403.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47404.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47405.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47406.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47881.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47882.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47883.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47884.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47885.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47886.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47887.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47888.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47889.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47890.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47891.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47892.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47893.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47894.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47895.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47896.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47897.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47021.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47022.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47023.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47024.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47025.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47026.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47027.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47028.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47407.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47408.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47409.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47410.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47411.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47412.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47413.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47414.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47415.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47416.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47417.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47418.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47419.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47420.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47421.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47422.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47423.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47424.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47425.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47426.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47427.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47428.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47429.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47430.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47431.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47432.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47433.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47434.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47435.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47436.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47437.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47898.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47899.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47900.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47901.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47902.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47903.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47904.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47905.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47906.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47907.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47908.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47909.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47910.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47911.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47912.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47913.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47914.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47915.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47916.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47917.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47918.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47919.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47920.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47921.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47922.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47923.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47924.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47925.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47926.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47927.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47928.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47929.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47930.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47931.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47932.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47933.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47934.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47935.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47936.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47029.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47030.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47031.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47032.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47033.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47034.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47035.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47036.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47037.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47038.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47039.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47040.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47041.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47042.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47043.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47044.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47045.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47046.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47047.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47048.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47049.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47050.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47051.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47052.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47053.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47054.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47055.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47056.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47057.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47058.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47059.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47060.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47061.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47062.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47063.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47064.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47065.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47066.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47067.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47068.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47937.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47938.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47939.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47940.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47941.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47942.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47943.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47944.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47945.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47946.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47947.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47948.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47949.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47950.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47951.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# Errore nel file ./clean/47951.txt: single positional indexer is out-of-bounds. Saltando questa entry.
# Processando file ./clean/47952.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47953.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47954.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47955.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47956.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47957.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47958.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47959.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47960.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47961.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47962.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47963.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47964.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47965.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47966.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47967.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47968.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47969.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47970.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47971.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47281.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47282.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47283.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47284.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47285.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47286.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47287.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47288.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47289.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47290.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47291.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47292.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47293.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47294.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47295.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47296.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47297.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47298.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47299.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47300.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47301.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47302.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47303.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47304.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# ...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47372.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47373.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47374.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47375.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47376.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47377.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47378.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47379.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47380.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47346.txt per la legislatura nan...
# Filtrando per legislatura: nan
# Errore nel file ./clean/47346.txt: first argument must be string or compiled pattern. Saltando questa entry.
# Processando file ./clean/47381.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47382.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47383.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47384.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47385.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47386.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47387.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47388.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47389.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47390.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47391.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47392.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47393.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47394.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47395.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47396.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47397.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47601.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47602.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47603.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47604.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47605.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47606.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47607.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47608.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47609.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47610.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47611.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47621.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47622.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47623.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47624.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47625.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47626.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47627.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47628.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47629.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47630.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47631.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47632.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47633.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47634.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47635.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47636.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47637.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47638.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47639.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47640.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47641.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47642.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47661.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47662.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47663.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47664.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47665.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47666.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47667.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47668.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47669.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47670.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47671.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47672.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47673.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47674.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47675.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47676.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47677.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47678.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47679.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47680.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47681.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47682.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47683.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47684.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47685.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47686.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47687.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47688.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47689.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47690.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47691.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47692.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47701.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47702.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47703.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47704.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47705.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47706.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47707.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47708.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47709.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47710.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47711.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47712.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Processando file ./clean/47713.txt per la legislatura XVI...
# Filtrando per legislatura: XVI
# Numero di nomi trovati per la legislatura XVI: 38
# File ok
# Numero totale di chunk processati: 6642
# Salvataggio del file csv_chunks.csv...
# File salvato con successo!

# %%
df_chunks = pd.read_csv(csv_chunks)

df_outcomes = df_chunks.copy()
df_outcomes = df_outcomes.drop(columns=['ID_cons','year_birth','gender','group','position','length','chunk'])
df_outcomes = df_outcomes.drop_duplicates(subset=['ID_file'])

intervention_counts = df_chunks.groupby('ID_file').size().reset_index(name='# interventions')
df_outcomes = df_outcomes.merge(intervention_counts, on='ID_file', how='left')

df_chunks_filtered = df_chunks[df_chunks['group'] != 'Presidente']
intervention_counts_filtered = df_chunks_filtered.groupby('ID_file').size().reset_index(name='# interventions (w/o president)')
df_outcomes = df_outcomes.merge(intervention_counts_filtered, on='ID_file', how='left')

length_sum = df_chunks.groupby('ID_file')['length'].sum().reset_index(name='total_length')
df_outcomes = df_outcomes.merge(length_sum, on='ID_file', how='left')

length_sum_filtered = df_chunks_filtered.groupby('ID_file')['length'].sum().reset_index(name='total_length (w/o president)')
df_outcomes = df_outcomes.merge(length_sum_filtered, on='ID_file', how='left')

def extract_number(text, pattern):
    match = re.search(pattern, text)
    if match:
        return int(match.group(1))  
    return None

def get_count(id_file, pattern):
    chunks = df_chunks[(df_chunks['ID_file'] == id_file) & (df_chunks['group'] == 'Presidente')]
    
    for chunk in chunks['chunk']:
        number = extract_number(chunk, pattern)
        if number is not None:
            return number
    
    return None

presenti = r"Presenti: (\d+)"
votanti = r"Votanti: (\d+)"
favorevoli = r"Favorevoli: (\d+)"
contrari = r"Contrari: (\d+)"
astenuti = r"Astenuti: (\d+)"

df_outcomes['presenti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, presenti))
df_outcomes['votanti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, votanti))
df_outcomes['favorevoli'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, favorevoli))
df_outcomes['contrari'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, contrari))
df_outcomes['astenuti'] = df_outcomes['ID_file'].apply(lambda id_file: get_count(id_file, astenuti))

def determine_outcome(row):
    favorevoli = row['favorevoli'] if pd.notna(row['favorevoli']) else 0
    contrari = row['contrari'] if pd.notna(row['contrari']) else 0
    astenuti = row['astenuti'] if pd.notna(row['astenuti']) else 0

    if pd.isna(row['favorevoli']) and pd.isna(row['contrari']) and pd.isna(row['astenuti']):
        return np.nan

    if favorevoli > contrari and favorevoli > astenuti:
        return 'approvato'
    else:
        return 'non approvato'

df_outcomes['outcome'] = df_outcomes.apply(determine_outcome, axis=1)

df_outcomes.to_csv("csv_outcomes.csv", index=False)

# %%
df = pd.read_csv("csv_chunks.csv")

df_filtered = df[df['group'] != 'Presidente']

df_filtered.to_csv("csv_chunks_filtered.csv", index=False)

# %%
valid_outcomes = df_outcomes[df_outcomes['outcome'].notna()]['ID_file']

df = pd.read_csv("csv_chunks.csv")
df_filtered = df[df['ID_file'].isin(valid_outcomes)]

df_filtered.to_csv("csv_chunks_outcomes.csv", index=False)

df = pd.read_csv("csv_chunks_outcomes.csv")

df_filtered = df[df['group'] != 'Presidente']

df_filtered.to_csv("csv_chunks_outcomes_filtered.csv", index=False)
